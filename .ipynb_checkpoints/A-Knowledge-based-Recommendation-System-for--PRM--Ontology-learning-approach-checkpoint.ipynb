# %% [markdown]
# # A Knowledge based Recommendation System for Project Mangement Ontology learning approach

# %% [markdown]
# The procedure of ontology construction can be done in one of three ways: manual construction; cooperative construction (need the human intervention during the constructing process) and (semi-) automatic construction which considered the Ontology Learning (OL) approach. OL from text is the process for acquiring and representing knowledge from text [structured (database), semi-structured (XML file) and unstructured (.txt, pdf, etc)] to be in machine-understandable form [OWL, RDF (Resource Description Framework), or RDFS (Resource Description Framework Schema)], by applying a set of methods and techniques (NLP, data mining, and machine learning).
#
# -Natural Language Processing via NLTK and Spacy matcher linguistic-based preprocessing technique: (1)Tokénization and normalization (2) part-of –speech tagging (POS), (3)posTagger, (4) stopwords, Lemmatization (Stemming), (5) chunking. levenshetein measure, TF-IDF measure, leveithen measure, cosine similarity measure, topic modeling LDA, n-gram, -Recommenadtions techniques based on ML : hiaachical clutering, classification, KNN, etc -Performance measures: Precision, Recall and F measure, -Programmation: Python, java; -Semantic web language/Tool: OWL2, RDF and SWRL

# %% [markdown]
# # Imports

# %%
import sys, fitz
import pandas as pd
import re
import string
import pandas as pd
import numpy as np

import spacy
from spacy.matcher import Matcher
from spacy.tokens import span
from spacy import displacy


import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer,SnowballStemmer
from nltk.corpus import wordnet, stopwords
from nltk import pos_tag, RegexpParser

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer 


from nltk.corpus import stopwords

from rdflib.namespace import DC, DCTERMS, DOAP, FOAF, OWL, RDF, RDFS, SKOS, VOID, XMLNS
from rdflib import URIRef, BNode, Literal, Namespace, Graph
from rdflib.extras import describer
from rdflib.namespace import XSD


nltk.download('conll2000')
from nltk.corpus import conll2000
from nltk.tag import UnigramTagger, BigramTagger
from nltk.chunk import ChunkParserI

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from keybert import KeyBERT


#kw_model = KeyBERT(model='all-mpnet-base-v2')


#stop = stopwords.words('english')

#nltk.download('omw-1.4')
#nltk.download('wordnet')
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\Farjo\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!

# %% [markdown]
# # Util Funtions For Text-Preprocessing

# %%
def remove_punctuation(text):
    """
        Remove the punctuation
    """
    return re.sub(r'[]"$%&\'()*+/=#@[\\^_`{|}~-]+', " ", text)

# %%
def remove_number(text):
    """
        Remove the number
    """
    pattern = r'[0-9]'
    # Match all digits in the string and replace them with an empty string
    new_string = re.sub(pattern, ' ', text)

    return new_string

# %%
def remove_non_ascii(text):
    """
        Remove non-ASCII characters 
    """
    return re.sub(r'[^\x00-\x7f]',r' ', text)

# %%
def remove_lineBreak(text):
    """
        Remove line break
    """
    return re.sub("\n"," ",text)

# %%
def lowerCase(text):
    """
        Transform all the text to lower case
    """
    return text.lower()

# %%
def remove_extra_whitespaces_func(text):
    '''
    Removes extra whitespaces from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without extra whitespaces
    ''' 
    return re.sub(r'^\s*|\s\s*', ' ', text).strip()

# %%
def remove_uu(text):
    """
        Remove the uu  
    """
    return re.sub(r'u u',' ', text)

# %%
def find_title(text):
    '''
    Find the title presented in the text with the regex pattern (Exp: 5.1 Plan scope mangement)
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        the title found in the text 
    '''
    return re.findall("[0-9].*[A-Z]\n",text)

# %%
def get_section(text):
    '''
    Get the sections in a text (Exp: section 4.1.2)
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        the list of the section founded in the paragraph 
    '''
    return re.findall('Section\s[0-9].{1,7}',text)

# %%
def get_figure(text):
    '''
    Get the figures in a text (Exp: section 4.1.2)
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        the list of the figures founded in the paragraph 
    '''
    return re.findall("Figure\s[0-9]-[0-9]{1,2}.\s[A-Z]{1}.*",text)

# %%
def get_def(text):
    if re.findall('^Described in Section',text)  :
        return ''
    else : 
        return re.sub('The inputs, tools and techniques, and outputs of this process are depicted in (.*) [0-9]{3}',' ',text)
    #return text

# %%
def get_clean_figure(text):
    return re.sub('(Figure\s\d-\d{1,2}.\sFigure\s[0-9].*)', ' ', text)

# %%
def get_process_of_concept(df):
    '''
    Get the topic of each concept  (Exp: concept = PROJECT CHARTER -- topic = PLAN SCOPE MANAGEMENT )
    
    Args:
        df (str): the concept column to which the function is to be applied, string
    
    Returns:
        the topic of the concept passed 
    '''
    index = []
    for i in range(0,len(df['content'])) :
        if df['content'][i] == ' ':
            index.append(i)
    df['topic'] = ''
    for j in range(0,len(index)):
        if j == len(index)-1:
            df['topic'][index[j]:] = df['concept'][index[j]]
            break;
        else :
            df['topic'][index[j]:index[j+1]] = df['concept'][index[j]]
    return df['topic']

# %%
def create_columns_from_each_chapter(text,title,content,figures):
    '''
    Creation of the dataframe from the text passed
    
    Args:
        text (str): the text from the pmbok that will be preprocced, string
        title (list): the list that will contain the title 
        content (str): the str that will contain the content
        figures (list): the list that contain the figures
    Returns:
        A dataframe with the following columns : concept, topic, figure, section, type,content 
    '''
    dic = {}
    title = find_title(text)
    for i in range(0,len(title)):
        value = re.sub('\n',' ',title[i])
        title[i] = value.strip()
    
    text = remove_lineBreak(text)
    
    for i in range(0,len(title)):
        if i == (len(title)-1) : 
            content.append(re.findall(title[-1]+'(.*)'+'endchapter',text))
            break;
        else:
            content.append(re.findall(title[i]+'(.*)'+title[i+1],text))
    for i in range(0,len(content)):
        dic[title[i]] = content[i][0]
        
    df = pd.DataFrame(list(dic.items()),columns=['concept','content'])
    
    df['section'] = df['content'].apply(lambda x : get_section(x))
    df['figure'] = None
    for i in range(0,len(figures)):
        df['figure'][i] = figures[i] #df['definition'].apply(lambda x : get_figure(x))
    df['type'] = get_type(df)
    
    
    
    return df #title,content

# %%
def get_type(df):
    
    '''
    Get the type of each concept  (Exp: concept = PROJECT CHARTER -- type =  inputs of PLAN SCOPE MANAGEMENT )
    
    Args:
        df (str): the concept column to which the function is to be applied, string
    
    Returns:
        the type of each concept passed 
    '''
    
    start_input = []
    start_tools_and_techniques = []
    start_output = []
    
    title_list = df['concept'].apply(lambda x : lowerCase(x))
    for i in range(0,len(title_list)):
        if 'inputs' in title_list[i] :
            start_input.append(i)
        if 'tools and techniques' in title_list[i] :
            start_tools_and_techniques.append(i)
        if 'outputs' in title_list[i] :
            start_output.append(i)
    for i in range(0,len(start_input)) :
        if i == len(start_input)-1 :
            df.loc[start_input[-1]:start_tools_and_techniques[-1],'type'] = 'inputs'
            df.loc[start_tools_and_techniques[-1]:start_output[-1],'type'] = 'tools_and_techniques'
            df.loc[start_output[-1]:,'type'] = 'outputs'
            break
        df.loc[start_input[i]:start_tools_and_techniques[i],'type'] = 'inputs'
        df.loc[start_tools_and_techniques[i]:start_output[i],'type'] = 'tools_and_techniques'
        df.loc[start_output[i]:start_input[i+1],'type'] = 'outputs'
    return df['type']

# %%
def clean_topic(text):
    '''
    remove the unwanted word from the topics
    
    Args:
        text (str): the concept column to which the function is to be applied, string
    
    Returns:
        the cleaned text 
    '''
    if re.findall(': INPUTS',text)  :
        return re.sub(': INPUTS',' ',text)
    elif re.findall(': OUTPUTS',text) :
        return re.sub(': OUTPUTS',' ',text)
    elif re.findall(': TOOLS AND TECHNIQUES',text) :
        return re.sub(': TOOLS AND TECHNIQUES',' ',text)
    else :
        return text

# %%
def clean_dataFrame(df,columns):
    
    
    for col in columns:
        df[col] = df[col].apply(lambda x : remove_punctuation(x))
        df[col] = df[col].apply(lambda x : remove_non_ascii(x))
        df[col] = df[col].apply(lambda x : remove_number(x))
        df[col] = df[col].apply(lambda x : remove_extra_whitespaces_func(x))
        df[col] = df[col].apply(lambda x : lowerCase(x))
    
    #df = df.apply(lambda x : remove_point(x))
    return df

# %% [markdown]
# # Import Data From The PDF File

# %% [markdown]
# ## 1. Retrive The Text From The PMBOK

# %%
# Get The text from the pdf file with the library fitz
fdoc = fitz.open("PMBOK6-2017.pdf")
header = "Header"  # text in header
footer = "Page %i of %i"  # text in footer
page = []
for i  in range(0,573):
    page.append(fdoc[i].get_text())  # insert header

# %% [markdown]
# ## 2. Get the text for each chapter

# %% [markdown]
# ### 2.1 Initialize Variables

# %%
# variable represent each chapter that we will work with 
scope = []
schedule = []
cost = []

# variable represent title that we get from each chapter and the variable with contient the whole text that we will work with 
scope_title = []
scope_title_without_number = []
scope_text = ' '
scope_content = []

schedule_title = []
schedule_title_without_number = []
schedule_text = ' '
schedule_content = []

cost_title = []
cost_title_without_number = []
cost_text = ' '
cost_content = []

figures_scope = []
figures_schedule = []
figures_cost = []

# %% [markdown]
# ### 2.2 Project scope management

# %%
for i in range(164,207):
    p = re.sub('Not For Distribution, Sale or Reproduction.', ' ', page[i])
    p = re.sub('Part 1 - Guide', ' ', p)
    scope.append(p)
    scope_title.append(re.findall("[0-9].*[A-Z]\n",p))
    figures_scope.append(re.findall("Figure\s[0-9]-[0-9]{1,2}.\s[A-Z]{1}.*",p))

# %%
for i in range(0,len(scope)):
    scope_text = scope_text + scope[i]
scope_text = scope_text + ' endchapter'

# %%
df_scope = create_columns_from_each_chapter(scope_text,scope_title,scope_content,figures_scope)
df_scope['topic'] = ''
df_scope['topic'] = get_process_of_concept(df_scope)
df_scope['content'] = df_scope['content'].apply(lambda x : remove_extra_whitespaces_func(x))
df_scope['def'] = df_scope['content'].apply(lambda x : get_def(x))
df_scope['ref'] = df_scope['section'] + df_scope['figure']

# %%
df_scope.head()
# Out:
#                                concept  \
# 0                       5.4 Create WBS
# 1            5.1 PLAN SCOPE MANAGEMENT
# 2  5.1.1 PLAN SCOPE MANAGEMENT: INPUTS
# 3              5.1.1.1 PROJECT CHARTER
# 4      5.1.1.2 PROJECT MANAGEMENT PLAN
#
#                                              content  \
# 0  —The process of subdividing project deliverabl...
# 1  Plan Scope Management is the process of creati...
# 2
# 3  Described in Section 4.1.3.1. The project char...
# 4  Described in Section 4.2.3.1. Project manageme...
#
#                                              section  \
# 0                                                 []
# 1  [Section 4.2.3.1), Section 2.3), an, Section 2...
# 2                                                 []
# 3                                 [Section 4.1.3.1.]
# 4               [Section 4.2.3.1., Section 8.1.3.1.]
#
#                                             figure    type  \
# 0                                               []     NaN
# 1  [Figure 5-1. Project Scope Management Overview]     NaN
# 2                                               []  inputs
# 3                                               []  inputs
# 4                                               []  inputs
#
#                                  topic  \
# 0
# 1
# 2  5.1.1 PLAN SCOPE MANAGEMENT: INPUTS
# 3  5.1.1 PLAN SCOPE MANAGEMENT: INPUTS
# 4  5.1.1 PLAN SCOPE MANAGEMENT: INPUTS
#
#                                                  def  \
# 0  —The process of subdividing project deliverabl...
# 1  Plan Scope Management is the process of creati...
# 2
# 3
# 4
#
#                                                  ref
# 0                                                 []
# 1  [Section 4.2.3.1), Section 2.3), an, Section 2...
# 2                                                 []
# 3                                 [Section 4.1.3.1.]
# 4               [Section 4.2.3.1., Section 8.1.3.1.]

# %%
columns_to_clean = ['concept','topic']

df_scope['topic'] = df_scope['topic'].apply(lambda x : clean_topic(x))
df_scope['def'] = df_scope['def'].apply(lambda x : remove_non_ascii(x))

df_scope = clean_dataFrame(df_scope,columns_to_clean)

# %%
df_scope.head()
# Out:
#                              concept  \
# 0                       . create wbs
# 1            . plan scope management
# 2  . . plan scope management: inputs
# 3              . . . project charter
# 4      . . . project management plan
#
#                                              content  \
# 0  —The process of subdividing project deliverabl...
# 1  Plan Scope Management is the process of creati...
# 2
# 3  Described in Section 4.1.3.1. The project char...
# 4  Described in Section 4.2.3.1. Project manageme...
#
#                                              section  \
# 0                                                 []
# 1  [Section 4.2.3.1), Section 2.3), an, Section 2...
# 2                                                 []
# 3                                 [Section 4.1.3.1.]
# 4               [Section 4.2.3.1., Section 8.1.3.1.]
#
#                                             figure    type  \
# 0                                               []     NaN
# 1  [Figure 5-1. Project Scope Management Overview]     NaN
# 2                                               []  inputs
# 3                                               []  inputs
# 4                                               []  inputs
#
#                        topic  \
# 0
# 1
# 2  . . plan scope management
# 3  . . plan scope management
# 4  . . plan scope management
#
#                                                  def  \
# 0   The process of subdividing project deliverabl...
# 1  Plan Scope Management is the process of creati...
# 2
# 3
# 4
#
#                                                  ref
# 0                                                 []
# 1  [Section 4.2.3.1), Section 2.3), an, Section 2...
# 2                                                 []
# 3                                 [Section 4.1.3.1.]
# 4               [Section 4.2.3.1., Section 8.1.3.1.]

# %%
df_scope['topic'].unique()
# Out:
# array(['', '. . plan scope management', '. . collect requirements',
#        '. . define scope', '. . create wbs', '. . validate scope',
#        '. . control scope'], dtype=object)

# %% [markdown]
# ### 2.3 Project schedule management

# %%
for i in range(208,265):
    p = re.sub('Not For Distribution, Sale or Reproduction.', ' ', page[i])
    p = re.sub('Part 1 - Guide', ' ', p) 
    schedule.append(p)
    schedule_title.append(re.findall("[0-9].*[A-Z]\n",p))
    figures_schedule.append(re.findall("Figure\s[0-9]-[0-9]{1,2}.\s[A-Z]{1}.*",p))

# %%
for i in range(0,len(schedule)):
    schedule_text = schedule_text + schedule[i]
schedule_text = schedule_text + ' endchapter'

# %%
df_schedule = create_columns_from_each_chapter(schedule_text,schedule_title,schedule_content,figures_schedule)
df_schedule['topic'] = ''
df_schedule['topic'] = get_process_of_concept(df_schedule)
df_schedule['content'] = df_schedule['content'].apply(lambda x : remove_extra_whitespaces_func(x))
df_schedule['def'] = df_schedule['content'].apply(lambda x : get_def(x))
df_schedule['ref'] = df_schedule['section'] + df_schedule['figure']

# %%
df_schedule.head()
# Out:
#                                     concept  \
# 0              6.1 PLAN SCHEDULE MANAGEMENT
# 1    6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS
# 2                   6.1.1.1 PROJECT CHARTER
# 3           6.1.1.2 PROJECT MANAGEMENT PLAN
# 4  6.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS
#
#                                              content  \
# 0  Plan Schedule Management is the process of est...
# 1
# 2  Described in Section 4.1.3.1. The project char...
# 3  Described in Section 4.3.2.1. Project manageme...
# 4  The enterprise environmental factors that can ...
#
#                                              section  \
# 0                                                 []
# 1                                                 []
# 2                                 [Section 4.1.3.1.]
# 3  [Section 4.3.2.1., Section 5.1.3.1., Section 4...
# 4                                                 []
#
#                                               figure    type  \
# 0                                                 []     NaN
# 1  [Figure 6-1. Project Schedule Management Overv...  inputs
# 2                                                 []  inputs
# 3                  [Figure 6-2. Scheduling Overview]  inputs
# 4                                                 []  inputs
#
#                                     topic  \
# 0
# 1  6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS
# 2  6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS
# 3  6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS
# 4  6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS
#
#                                                  def  \
# 0  Plan Schedule Management is the process of est...
# 1
# 2
# 3
# 4  The enterprise environmental factors that can ...
#
#                                                  ref
# 0                                                 []
# 1  [Figure 6-1. Project Schedule Management Overv...
# 2                                 [Section 4.1.3.1.]
# 3  [Section 4.3.2.1., Section 5.1.3.1., Section 4...
# 4                                                 []

# %%
columns_to_clean = ['concept','topic']

df_schedule['topic'] = df_schedule['topic'].apply(lambda x : clean_topic(x))
df_schedule['def'] = df_schedule['def'].apply(lambda x : remove_non_ascii(x))

df_schedule = clean_dataFrame(df_schedule,columns_to_clean)

# %%
df_schedule.head()
# Out:
#                                   concept  \
# 0              . plan schedule management
# 1    . . plan schedule management: inputs
# 2                   . . . project charter
# 3           . . . project management plan
# 4  . . . enterprise environmental factors
#
#                                              content  \
# 0  Plan Schedule Management is the process of est...
# 1
# 2  Described in Section 4.1.3.1. The project char...
# 3  Described in Section 4.3.2.1. Project manageme...
# 4  The enterprise environmental factors that can ...
#
#                                              section  \
# 0                                                 []
# 1                                                 []
# 2                                 [Section 4.1.3.1.]
# 3  [Section 4.3.2.1., Section 5.1.3.1., Section 4...
# 4                                                 []
#
#                                               figure    type  \
# 0                                                 []     NaN
# 1  [Figure 6-1. Project Schedule Management Overv...  inputs
# 2                                                 []  inputs
# 3                  [Figure 6-2. Scheduling Overview]  inputs
# 4                                                 []  inputs
#
#                           topic  \
# 0
# 1  . . plan schedule management
# 2  . . plan schedule management
# 3  . . plan schedule management
# 4  . . plan schedule management
#
#                                                  def  \
# 0  Plan Schedule Management is the process of est...
# 1
# 2
# 3
# 4  The enterprise environmental factors that can ...
#
#                                                  ref
# 0                                                 []
# 1  [Figure 6-1. Project Schedule Management Overv...
# 2                                 [Section 4.1.3.1.]
# 3  [Section 4.3.2.1., Section 5.1.3.1., Section 4...
# 4                                                 []

# %%
df_schedule['topic'].unique()
# Out:
# array(['', '. . plan schedule management', '. . define activities',
#        '. . sequence activities', '. . estimate activity durations',
#        '. . develop schedule', '. . .d', '. . .b', '. . .g', '. . .p',
#        '. . control schedule'], dtype=object)

# %%
index_p = df_schedule.index[df_schedule['topic']== 'p'].tolist()
index_b = df_schedule.index[df_schedule['topic']== 'b'].tolist()
index_d = df_schedule.index[df_schedule['topic']== 'd'].tolist()
index_g = df_schedule.index[df_schedule['topic']== 'g'].tolist()
index = index_p + index_d + index_b + index_g
index
# Out:
# []

# %%
df_schedule = df_schedule.drop(index = index, axis=1)
df_schedule.head()
# Out:
#                                   concept  \
# 0              . plan schedule management
# 1    . . plan schedule management: inputs
# 2                   . . . project charter
# 3           . . . project management plan
# 4  . . . enterprise environmental factors
#
#                                              content  \
# 0  Plan Schedule Management is the process of est...
# 1
# 2  Described in Section 4.1.3.1. The project char...
# 3  Described in Section 4.3.2.1. Project manageme...
# 4  The enterprise environmental factors that can ...
#
#                                              section  \
# 0                                                 []
# 1                                                 []
# 2                                 [Section 4.1.3.1.]
# 3  [Section 4.3.2.1., Section 5.1.3.1., Section 4...
# 4                                                 []
#
#                                               figure    type  \
# 0                                                 []     NaN
# 1  [Figure 6-1. Project Schedule Management Overv...  inputs
# 2                                                 []  inputs
# 3                  [Figure 6-2. Scheduling Overview]  inputs
# 4                                                 []  inputs
#
#                           topic  \
# 0
# 1  . . plan schedule management
# 2  . . plan schedule management
# 3  . . plan schedule management
# 4  . . plan schedule management
#
#                                                  def  \
# 0  Plan Schedule Management is the process of est...
# 1
# 2
# 3
# 4  The enterprise environmental factors that can ...
#
#                                                  ref
# 0                                                 []
# 1  [Figure 6-1. Project Schedule Management Overv...
# 2                                 [Section 4.1.3.1.]
# 3  [Section 4.3.2.1., Section 5.1.3.1., Section 4...
# 4                                                 []

# %%
df_schedule['topic'].unique()
# Out:
# array(['', '. . plan schedule management', '. . define activities',
#        '. . sequence activities', '. . estimate activity durations',
#        '. . develop schedule', '. . .d', '. . .b', '. . .g', '. . .p',
#        '. . control schedule'], dtype=object)

# %% [markdown]
# ### 2.4 Project cost management

# %%
for i in range(266,306):
    p = re.sub('Not For Distribution, Sale or Reproduction.', ' ', page[i])
    p = re.sub('Part 1 - Guide', ' ', p)
    cost.append(p)
    cost_title.append(re.findall("[0-9].*[A-Z]\n",p))
    figures_cost.append(re.findall("Figure\s[0-9]-[0-9]{1,2}.\s[A-Z]{1}.*",p))

# %%
for i in range(0,len(cost)):
    cost_text = cost_text + cost[i]
cost_text = cost_text + ' endchapter'

# %%
df_cost = create_columns_from_each_chapter(cost_text,cost_title,cost_content,figures_cost)
df_cost['topic'] = ''
df_cost['topic'] = get_process_of_concept(df_cost)
df_cost['content'] = df_cost['content'].apply(lambda x : remove_extra_whitespaces_func(x))
df_cost['def'] = df_cost['content'].apply(lambda x : get_def(x))
df_cost['ref'] = df_cost['section'] + df_cost['figure']

# %%
df_cost.head()
# Out:
#                                     concept  \
# 0                  7.1 PLAN COST MANAGEMENT
# 1        7.1.1 PLAN COST MANAGEMENT: INPUTS
# 2                   7.1.1.1 PROJECT CHARTER
# 3           7.1.1.2 PROJECT MANAGEMENT PLAN
# 4  7.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS
#
#                                              content  \
# 0  Plan Cost Management is the process of deﬁning...
# 1
# 2  Described in Section 4.2.3.1. The project char...
# 3  Described in Section 4.2.3.1. Project manageme...
# 4  The enterprise environmental factors that can ...
#
#                                              section  \
# 0                                                 []
# 1                                                 []
# 2                                 [Section 4.2.3.1.]
# 3  [Section 4.2.3.1., Section 6.1.3.1., Section 1...
# 4                                                 []
#
#                                               figure    type  \
# 0                                                 []     NaN
# 1     [Figure 7-1. Project Cost Management Overview]  inputs
# 2                                                 []  inputs
# 3                                                 []  inputs
# 4  [Figure 7-2. Figure 7-3 depicts the data ﬂow ,...  inputs
#
#                                 topic  \
# 0
# 1  7.1.1 PLAN COST MANAGEMENT: INPUTS
# 2  7.1.1 PLAN COST MANAGEMENT: INPUTS
# 3  7.1.1 PLAN COST MANAGEMENT: INPUTS
# 4  7.1.1 PLAN COST MANAGEMENT: INPUTS
#
#                                                  def  \
# 0  Plan Cost Management is the process of deﬁning...
# 1
# 2
# 3
# 4  The enterprise environmental factors that can ...
#
#                                                  ref
# 0                                                 []
# 1     [Figure 7-1. Project Cost Management Overview]
# 2                                 [Section 4.2.3.1.]
# 3  [Section 4.2.3.1., Section 6.1.3.1., Section 1...
# 4  [Figure 7-2. Figure 7-3 depicts the data ﬂow ,...

# %%
columns_to_clean = ['concept','topic']

df_cost['topic'] = df_cost['topic'].apply(lambda x : clean_topic(x))
df_cost['def'] = df_cost['def'].apply(lambda x : remove_non_ascii(x))

df_cost = clean_dataFrame(df_cost,columns_to_clean)

# %%
df_cost.head()
# Out:
#                                   concept  \
# 0                  . plan cost management
# 1        . . plan cost management: inputs
# 2                   . . . project charter
# 3           . . . project management plan
# 4  . . . enterprise environmental factors
#
#                                              content  \
# 0  Plan Cost Management is the process of deﬁning...
# 1
# 2  Described in Section 4.2.3.1. The project char...
# 3  Described in Section 4.2.3.1. Project manageme...
# 4  The enterprise environmental factors that can ...
#
#                                              section  \
# 0                                                 []
# 1                                                 []
# 2                                 [Section 4.2.3.1.]
# 3  [Section 4.2.3.1., Section 6.1.3.1., Section 1...
# 4                                                 []
#
#                                               figure    type  \
# 0                                                 []     NaN
# 1     [Figure 7-1. Project Cost Management Overview]  inputs
# 2                                                 []  inputs
# 3                                                 []  inputs
# 4  [Figure 7-2. Figure 7-3 depicts the data ﬂow ,...  inputs
#
#                       topic  \
# 0
# 1  . . plan cost management
# 2  . . plan cost management
# 3  . . plan cost management
# 4  . . plan cost management
#
#                                                  def  \
# 0  Plan Cost Management is the process of de ning...
# 1
# 2
# 3
# 4  The enterprise environmental factors that can ...
#
#                                                  ref
# 0                                                 []
# 1     [Figure 7-1. Project Cost Management Overview]
# 2                                 [Section 4.2.3.1.]
# 3  [Section 4.2.3.1., Section 6.1.3.1., Section 1...
# 4  [Figure 7-2. Figure 7-3 depicts the data ﬂow ,...

# %%
df_cost['topic'].unique()
# Out:
# array(['', '. . plan cost management', '. . estimate costs',
#        '. . determine budget', '. . control costs'], dtype=object)

# %% [markdown]
# ### 2.5 Merge All three DataFrame:

# %%
final_df = df_scope.append(df_schedule)
final_df = final_df.append(df_cost)
final_df = final_df.drop(index=0,axis=1)
final_df = final_df.reset_index(drop=True)

# %%
final_df.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 1       . . plan scope management: inputs
# 2                   . . . project charter
# 3           . . . project management plan
# 4  . . . enterprise environmental factors
#
#                                              content  \
# 0  Plan Scope Management is the process of creati...
# 1
# 2  Described in Section 4.1.3.1. The project char...
# 3  Described in Section 4.2.3.1. Project manageme...
# 4  The enterprise environmental factors that can ...
#
#                                              section  \
# 0  [Section 4.2.3.1), Section 2.3), an, Section 2...
# 1                                                 []
# 2                                 [Section 4.1.3.1.]
# 3               [Section 4.2.3.1., Section 8.1.3.1.]
# 4                                                 []
#
#                                               figure    type  \
# 0    [Figure 5-1. Project Scope Management Overview]     NaN
# 1                                                 []  inputs
# 2                                                 []  inputs
# 3                                                 []  inputs
# 4  [Figure 5-2. Figure 5-3 depicts , Figure 5-2. ...  inputs
#
#                        topic  \
# 0
# 1  . . plan scope management
# 2  . . plan scope management
# 3  . . plan scope management
# 4  . . plan scope management
#
#                                                  def  \
# 0  Plan Scope Management is the process of creati...
# 1
# 2
# 3
# 4  The enterprise environmental factors that can ...
#
#                                                  ref
# 0  [Section 4.2.3.1), Section 2.3), an, Section 2...
# 1                                                 []
# 2                                 [Section 4.1.3.1.]
# 3               [Section 4.2.3.1., Section 8.1.3.1.]
# 4  [Figure 5-2. Figure 5-3 depicts , Figure 5-2. ...

# %%
final_df = final_df.fillna(value='')
final_df
# Out:
#                                     concept  \
# 0                   . plan scope management
# 1         . . plan scope management: inputs
# 2                     . . . project charter
# 3             . . . project management plan
# 4    . . . enterprise environmental factors
# ..                                      ...
# 260      . . . work performance information
# 261                    . . . cost forecasts
# 262                   . . . change requests
# 263   . . . project management plan updates
# 264         . . . project documents updates
#
#                                                content  \
# 0    Plan Scope Management is the process of creati...
# 1
# 2    Described in Section 4.1.3.1. The project char...
# 3    Described in Section 4.2.3.1. Project manageme...
# 4    The enterprise environmental factors that can ...
# ..                                                 ...
# 260  Described in Section 4.5.1.3. Work performance...
# 261  Either a calculated EAC value or a bottom-up E...
# 262  Described in Section 4.3.3.4. Analysis of proj...
# 263  Any change to the project management plan goes...
# 264  Project documents that may be updated as a res...
#
#                                                section  \
# 0    [Section 4.2.3.1), Section 2.3), an, Section 2...
# 1                                                   []
# 2                                   [Section 4.1.3.1.]
# 3                 [Section 4.2.3.1., Section 8.1.3.1.]
# 4                                                   []
# ..                                                 ...
# 260               [Section 4.5.1.3., Section 4.5.3.1)]
# 261                                                 []
# 262                 [Section 4.3.3.4., Section 4.6). ]
# 263  [Section 7.1.3.1., Section 7.3.3.1., Section 4...
# 264  [Section 4.1.3.2., Section 6.4.3.2., Section 7...
#
#                                                 figure     type  \
# 0      [Figure 5-1. Project Scope Management Overview]
# 1                                                   []   inputs
# 2                                                   []   inputs
# 3                                                   []   inputs
# 4    [Figure 5-2. Figure 5-3 depicts , Figure 5-2. ...   inputs
# ..                                                 ...      ...
# 260                                                     outputs
# 261                                                     outputs
# 262                                                     outputs
# 263                                                     outputs
# 264                                                     outputs
#
#                          topic  \
# 0
# 1    . . plan scope management
# 2    . . plan scope management
# 3    . . plan scope management
# 4    . . plan scope management
# ..                         ...
# 260          . . control costs
# 261          . . control costs
# 262          . . control costs
# 263          . . control costs
# 264          . . control costs
#
#                                                    def  \
# 0    Plan Scope Management is the process of creati...
# 1
# 2
# 3
# 4    The enterprise environmental factors that can ...
# ..                                                 ...
# 260
# 261  Either a calculated EAC value or a bottom-up E...
# 262
# 263  Any change to the project management plan goes...
# 264  Project documents that may be updated as a res...
#
#                                                    ref
# 0    [Section 4.2.3.1), Section 2.3), an, Section 2...
# 1                                                   []
# 2                                   [Section 4.1.3.1.]
# 3                 [Section 4.2.3.1., Section 8.1.3.1.]
# 4    [Figure 5-2. Figure 5-3 depicts , Figure 5-2. ...
# ..                                                 ...
# 260
# 261
# 262
# 263
# 264
#
# [265 rows x 8 columns]

# %%
final_df['topic'].unique()
# Out:
# array(['', '. . plan scope management', '. . collect requirements',
#        '. . define scope', '. . create wbs', '. . validate scope',
#        '. . control scope', '. . plan schedule management',
#        '. . define activities', '. . sequence activities',
#        '. . estimate activity durations', '. . develop schedule',
#        '. . .d', '. . .b', '. . .g', '. . .p', '. . control schedule',
#        '. . plan cost management', '. . estimate costs',
#        '. . determine budget', '. . control costs'], dtype=object)

# %%
final_df['concept'].unique()
# Out:
# array(['. plan scope management', '. . plan scope management: inputs',
#        '. . . project charter', '. . . project management plan',
#        '. . . enterprise environmental factors',
#        '. . . organizational process assets',
#        '. . plan scope management: tools and techniques',
#        '. . . expert judgment', '. . . data analysis', '. . . meetings',
#        '. . plan scope management: outputs',
#        '. . . scope management plan',
#        '. . . requirements management plan', '. collect requirements',
#        '. . collect requirements: inputs', '. . . project documents',
#        '. . . business documents', '. . . agreements',
#        '. . collect requirements: tools and techniques',
#        '. . . data gathering', '. . . decision making',
#        '. . . data representation', '. . . interpersonal and team skills',
#        '. . . context diagram', '. . . prototypes',
#        '. . collect requirements: outputs',
#        '. . . requirements documentation',
#        '. . . requirements traceability matrix', '. define scope',
#        '. . define scope: inputs',
#        '. . define scope: tools and techniques', '. . . product analysis',
#        '. . define scope: outputs', '. . . project scope statement',
#        '. . . project documents updates', '. create wbs',
#        '. . create wbs: inputs', '. . create wbs: tools and techniques',
#        '. . . decomposition', '. . create wbs: outputs',
#        '. . . scope baseline', '. validate scope',
#        '. . validate scope: inputs', '. . . verified deliverables',
#        '. . . work performance data',
#        '. . validate scope: tools and techniques', '. . . inspection',
#        '. . validate scope: outputs', '. . . accepted deliverables',
#        '. . . work performance information', '. . . change requests',
#        '. control scope', '. . control scope: inputs',
#        '. . control scope: tools and techniques',
#        '. . control scope: outputs',
#        '. . . project management plan updates',
#        '. . plan schedule management: inputs',
#        '. . plan schedule management: tools and techniques',
#        '. . plan schedule management: outputs',
#        '. . . schedule management plan', '. define activities',
#        '. . define activities: inputs',
#        '. . define activities: tools and techniques',
#        '. . . rolling wave planning', '. . define activities: outputs',
#        '. . . activity list', '. . . activity attributes',
#        '. . . milestone list', '. sequence activities',
#        '. . sequence activities: inputs',
#        '. . sequence activities: tools and techniques',
#        '. . . precedence diagramming method',
#        '. . . dependency determination and integration',
#        '. . . leads and lags', '. . sequence activities: outputs',
#        '. . . project schedule network diagrams',
#        '. estimate activity durations',
#        '. . estimate activity durations: inputs',
#        '. . estimate activity durations: tools and techniques',
#        '. . . analogous estimating', '. . . parametric estimating',
#        '. . . three point estimating', '. . . bottom up estimating',
#        '. . estimate activity durations: outputs',
#        '. . . duration estimates', '. . . basis of estimates',
#        '. develop schedule', '. . develop schedule: inputs',
#        '. . develop schedule: tools and techniques',
#        '. . . schedule network analysis', '. . . critical path method',
#        '. . . resource optimization', '. . . schedule compression',
#        '. . . agile release planning', '. . develop schedule: outputs',
#        '. . . schedule baseline', '. . . project schedule', '. .mb',
#        '. . .mf', '. . .t', '. . .d', '. . .b', '. . .g', '. . .p',
#        'and as product z', '. . . schedule data',
#        '. . . project calendars', '. control schedule',
#        '. . control schedule: inputs',
#        '. . control schedule: tools and techniques',
#        '. . control schedule: outputs', '. . . schedule forecasts',
#        '. . plan cost management: inputs',
#        '. . plan cost management: tools and techniques',
#        '. . plan cost management: outputs', '. . . cost management plan',
#        '. estimate costs', '. . estimate costs: inputs',
#        '. . estimate costs: tools and techniques',
#        '. . estimate costs: outputs', '. . . cost estimates',
#        '. determine budget', '. . determine budget: inputs',
#        '. . determine budget: tools and techniques',
#        '. . . cost aggregation', '. . . historical information review',
#        '. . . funding limit reconciliation', '. . . financing',
#        '. . determine budget: outputs', '. . . cost baseline',
#        '. . . project funding requirements', '. control costs',
#        '. . control costs: inputs', '. . . . project documents',
#        '. . control costs: tools and techniques',
#        '. . . to complete performance index',
#        '. . control costs: outputs', '. . . cost forecasts'], dtype=object)

# %%
index = final_df.index[final_df['content'] == ''].tolist()
final_df = final_df.drop(index = index, axis=1)

# %%
final_df['concept'].unique()
# Out:
# array(['. plan scope management', '. . . project charter',
#        '. . . project management plan',
#        '. . . enterprise environmental factors',
#        '. . . organizational process assets', '. . . expert judgment',
#        '. . . data analysis', '. . . meetings',
#        '. . . scope management plan',
#        '. . . requirements management plan', '. collect requirements',
#        '. . . project documents', '. . . business documents',
#        '. . . agreements', '. . . data gathering',
#        '. . . decision making', '. . . data representation',
#        '. . . interpersonal and team skills', '. . . context diagram',
#        '. . . prototypes', '. . . requirements documentation',
#        '. . . requirements traceability matrix', '. define scope',
#        '. . . product analysis', '. . . project scope statement',
#        '. . . project documents updates', '. create wbs',
#        '. . . decomposition', '. . . scope baseline', '. validate scope',
#        '. . . verified deliverables', '. . . work performance data',
#        '. . . inspection', '. . . accepted deliverables',
#        '. . . work performance information', '. . . change requests',
#        '. control scope', '. . . project management plan updates',
#        '. . . schedule management plan', '. define activities',
#        '. . . rolling wave planning', '. . . activity list',
#        '. . . activity attributes', '. . . milestone list',
#        '. sequence activities', '. . . precedence diagramming method',
#        '. . . dependency determination and integration',
#        '. . . leads and lags', '. . . project schedule network diagrams',
#        '. estimate activity durations', '. . . analogous estimating',
#        '. . . parametric estimating', '. . . three point estimating',
#        '. . . bottom up estimating', '. . . duration estimates',
#        '. . . basis of estimates', '. develop schedule',
#        '. . . schedule network analysis', '. . . critical path method',
#        '. . . resource optimization', '. . . schedule compression',
#        '. . . agile release planning', '. . . schedule baseline',
#        '. . . project schedule', '. .mb', '. . .mf', '. . .t', '. . .b',
#        'and as product z', '. . . schedule data',
#        '. . . project calendars', '. control schedule',
#        '. . . schedule forecasts', '. . . cost management plan',
#        '. estimate costs', '. . . cost estimates', '. determine budget',
#        '. . . cost aggregation', '. . . historical information review',
#        '. . . funding limit reconciliation', '. . . financing',
#        '. . . cost baseline', '. . . project funding requirements',
#        '. control costs', '. . . . project documents',
#        '. . . to complete performance index', '. . . cost forecasts'],
#       dtype=object)

# %%
final_df.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 2                   . . . project charter
# 3           . . . project management plan
# 4  . . . enterprise environmental factors
# 5     . . . organizational process assets
#
#                                              content  \
# 0  Plan Scope Management is the process of creati...
# 2  Described in Section 4.1.3.1. The project char...
# 3  Described in Section 4.2.3.1. Project manageme...
# 4  The enterprise environmental factors that can ...
# 5  The organizational process assets that can inﬂ...
#
#                                              section  \
# 0  [Section 4.2.3.1), Section 2.3), an, Section 2...
# 2                                 [Section 4.1.3.1.]
# 3               [Section 4.2.3.1., Section 8.1.3.1.]
# 4                                                 []
# 5                                                 []
#
#                                               figure    type  \
# 0    [Figure 5-1. Project Scope Management Overview]
# 2                                                 []  inputs
# 3                                                 []  inputs
# 4  [Figure 5-2. Figure 5-3 depicts , Figure 5-2. ...  inputs
# 5                                                 []  inputs
#
#                        topic  \
# 0
# 2  . . plan scope management
# 3  . . plan scope management
# 4  . . plan scope management
# 5  . . plan scope management
#
#                                                  def  \
# 0  Plan Scope Management is the process of creati...
# 2
# 3
# 4  The enterprise environmental factors that can ...
# 5  The organizational process assets that can in ...
#
#                                                  ref
# 0  [Section 4.2.3.1), Section 2.3), an, Section 2...
# 2                                 [Section 4.1.3.1.]
# 3               [Section 4.2.3.1., Section 8.1.3.1.]
# 4  [Figure 5-2. Figure 5-3 depicts , Figure 5-2. ...
# 5                                                 []

# %%
final_df['content'][0]
# Out:
# 'Plan Scope Management is the process of creating a scope management plan that documents how the project and product scope will be deﬁned, validated, and controlled. The key beneﬁt of this process is that it provides guidance and direction on how scope will be managed throughout the project. This process is performed once or at predeﬁned points in the project. The inputs, tools and techniques, and outputs of this process are depicted in Figure 5-2. Figure 5-3 depicts the data ﬂow diagram of the process. Figure 5-2. Plan Scope Management: Inputs, Tools & Techniques, and Outputs Figure 5-3. Plan Scope Management: Data Flow Diagram Tools & Techniques Inputs Outputs Plan Scope Management .1 Expert judgment .2 Data analysis • Alternatives analysis .3 Meetings .1 Project charter .2 Project management plan • Quality management plan • Project life cycle description • Development approach .3 Enterprise environmental factors .4 Organizational process assets .1 Scope management plan .2 Requirements management plan • Project charter 5.1 Plan Scope Management Enterprise/ Organization 4.1 Develop Project Charter • Scope management plan • Requirements management plan • Project charter • Quality management plan • Project life cycle description • Development approach • Enterprise environmental factors • Organizational process assets Project Management Plan Project Management Plan 135 The scope management plan is a component of the project or program management plan that describes how the scope will be deﬁned, developed, monitored, controlled, and validated. The development of the scope management plan and the detailing of the project scope begin with the analysis of information contained in the project charter (Section 4.1.3.1), the latest approved subsidiary plans of the project management plan (Section 4.2.3.1), historical information contained in the organizational process assets (Section 2.3), and any other relevant enterprise environmental factors (Section 2.2).'

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# ## 1. Prepare the data ( Removing stop words, lowercasing ,etc....)

# %%
data_to_process = final_df[['concept','def']]
data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('include but are not limited to','include',x))
data_to_process.head()
# Out:
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/3932753283.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('include but are not limited to','include',x))
#                                   concept  \
# 0                 . plan scope management
# 2                   . . . project charter
# 3           . . . project management plan
# 4  . . . enterprise environmental factors
# 5     . . . organizational process assets
#
#                                                  def
# 0  Plan Scope Management is the process of creati...
# 2
# 3
# 4  The enterprise environmental factors that can ...
# 5  The organizational process assets that can in ...

# %%
# remove bias u u 
data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_uu(x))
# lower cassing 
data_to_process['def'] = data_to_process['def'].apply(lambda x : lowerCase(x))
# remove number
data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_number(x))
# remove line break 
data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_lineBreak(x))
# remove extra white space 
data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_extra_whitespaces_func(x))
# remove non ascii text
data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_non_ascii(x))
# remove non ascii text
data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_punctuation(x))
# remove extra white space 
data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_extra_whitespaces_func(x))

data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('(section [\.{,6}\s\.]{,6})',' ',x))
data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('that can in uence','influence',x))
data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('scope','Scope',x))
data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('de ned','defined',x))
data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('bene t','benefit',x))
# Out:
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_uu(x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : lowerCase(x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_number(x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_lineBreak(x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_extra_whitespaces_func(x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_non_ascii(x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_punctuation(x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : remove_extra_whitespaces_func(x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('(section [\.{,6}\s\.]{,6})',' ',x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('that can in uence','influence',x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('scope','Scope',x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('de ned','defined',x))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/4051881670.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['def'] = data_to_process['def'].apply(lambda x : re.sub('bene t','benefit',x))

# %% [markdown]
# ## 2. Extract each sentence from content

# %%
# intialize nlp
nlp = spacy.load("en_core_web_sm")

# %%
def extract_sentence(text):
    sentence = []
    doc = nlp(text)
    for sent in doc.sents :
        sentence.append(sent.text)
    return sentence

# %%
def lemm(text):
    stop = stopwords.words('english')
    text = nlp(text)
    l = []
    for word in text:
        lemma = word.lemma_
        l.append(lemma)
    return l

# %%
data_to_process['lemma_def'] = data_to_process['def'].apply(lambda x : ' '.join(lemm(x)))
data_to_process['lemma_sentence'] = data_to_process['lemma_def'].apply(lambda x : extract_sentence(x))
# Out:
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/1730997909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['lemma_def'] = data_to_process['def'].apply(lambda x : ' '.join(lemm(x)))
# C:\Users\Farjo\AppData\Local\Temp/ipykernel_22896/1730997909.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_process['lemma_sentence'] = data_to_process['lemma_def'].apply(lambda x : extract_sentence(x))

# %%
data_to_process.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 2                   . . . project charter
# 3           . . . project management plan
# 4  . . . enterprise environmental factors
# 5     . . . organizational process assets
#
#                                                  def  \
# 0  plan Scope management is the process of creati...
# 2
# 3
# 4  the enterprise environmental factors influence...
# 5  the organizational process assets influence th...
#
#                                            lemma_def  \
# 0  plan Scope management be the process of create...
# 2
# 3
# 4  the enterprise environmental factor influence ...
# 5  the organizational process asset influence the...
#
#                                       lemma_sentence
# 0  [plan Scope management be the process of creat...
# 2                                                 []
# 3                                                 []
# 4  [the enterprise environmental factor influence...
# 5  [the organizational process asset influence th...

# %%
final_df['def'][0]
# Out:
# 'Plan Scope Management is the process of creating a scope management plan that documents how the project and product scope will be de ned, validated, and controlled. The key bene t of this process is that it provides guidance and direction on how scope will be managed throughout the project. This process is performed once or at prede ned points in the project.   The scope management plan is a component of the project or program management plan that describes how the scope will be de ned, developed, monitored, controlled, and validated. The development of the scope management plan and the detailing of the project scope begin with the analysis of information contained in the project charter (Section 4.1.3.1), the latest approved subsidiary plans of the project management plan (Section 4.2.3.1), historical information contained in the organizational process assets (Section 2.3), and any other relevant enterprise environmental factors (Section 2.2).'

# %%
data_to_process['def'][0]
# Out:
# 'plan Scope management is the process of creating a Scope management plan that documents how the project and product Scope will be defined, validated, and controlled. the key benefit of this process is that it provides guidance and direction on how Scope will be managed throughout the project. this process is performed once or at predefined points in the project. the Scope management plan is a component of the project or program management plan that describes how the Scope will be defined, developed, monitored, controlled, and validated. the development of the Scope management plan and the detailing of the project Scope begin with the analysis of information contained in the project charter  , the latest approved subsidiary plans of the project management plan  , historical information contained in the organizational process assets  and any other relevant enterprise environmental factors  '

# %% [markdown]
# ## 3. Extract verbs and noun with Chuncking

# %%
'''
the following funtion represent the chunking model that will be used for the 
relation extraction between the concept
'''

def conll_tag_chunks(chunk_sents):
    tagged_sents = [tree2conlltags(tree) for tree in chunk_sents]
    return [[(t, c) for (w, t, c) in sent] for sent in tagged_sents]
def combined_tagger(train_data, taggers, backoff=None):
    for tagger in taggers:
        backoff = tagger(train_data, backoff=backoff)
    return backoff
#Define the chunker class
class NGramTagChunker(ChunkParserI):
    def __init__(self,train_sentences,tagger_classes=[UnigramTagger,BigramTagger]):
        train_sent_tags=conll_tag_chunks(train_sentences)
        self.chunk_tagger=combined_tagger(train_sent_tags,tagger_classes)
    def parse(self,tagged_sentence):
        if not tagged_sentence:
            return None
        pos_tags=[tag for word, tag in tagged_sentence]
        chunk_pos_tags=self.chunk_tagger.tag(pos_tags)
        chunk_tags=[chunk_tag for (pos_tag,chunk_tag) in chunk_pos_tags]
        wpc_tags=[(word,pos_tag,chunk_tag) for ((word,pos_tag),chunk_tag) in zip(tagged_sentence,chunk_tags)]
        return conlltags2tree(wpc_tags)

# %%
#Here conll2000 corpus for training shallow parser model
data= conll2000.chunked_sents()
train_data=data[:10900]
test_data=data[10900:]

from nltk.chunk.util import tree2conlltags,conlltags2tree
wtc=tree2conlltags(train_data[1])
wtc
tree=conlltags2tree(wtc)

#train chunker model
ntc=NGramTagChunker(train_data)
#evaluate chunker model performance
print(ntc.evaluate(test_data))
# Out:
# ChunkParse score:
#     IOB Accuracy:  90.0%%
#     Precision:     82.1%%
#     Recall:        86.3%%
#     F-Measure:     84.1%%

# %%
t = tuple()
def get_the_rigth_chunking(chunk_tree):
    try :
        begin = len(chunk_tree)-1
        for i in range(begin,0,-1):
            if type(chunk_tree[i]) == type(t):
                chunk_tree.pop(i)
    except IndexError:
        return chunk_tree
            
    return chunk_tree

# %%
data_to_process = data_to_process.reset_index(drop=True)
data_to_process.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 1                   . . . project charter
# 2           . . . project management plan
# 3  . . . enterprise environmental factors
# 4     . . . organizational process assets
#
#                                                  def  \
# 0  plan Scope management is the process of creati...
# 1
# 2
# 3  the enterprise environmental factors influence...
# 4  the organizational process assets influence th...
#
#                                            lemma_def  \
# 0  plan Scope management be the process of create...
# 1
# 2
# 3  the enterprise environmental factor influence ...
# 4  the organizational process asset influence the...
#
#                                       lemma_sentence
# 0  [plan Scope management be the process of creat...
# 1                                                 []
# 2                                                 []
# 3  [the enterprise environmental factor influence...
# 4  [the organizational process asset influence th...

# %%
data_to_process['lemma_sentence'][0][0]
# Out:
# 'plan Scope management be the process of create a Scope management plan that document how the project and product Scope will be define , validate , and control .'

# %%
stop = stopwords.words('english')
stop.remove('be')
stop.remove('have')
stop.remove('not')
stop.remove('will')
stop.append('to')
stop.append('not')

# %%
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'been', 'being', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'to', 'not']

# %%
sent = ' '.join(word for word in data_to_process['lemma_sentence'][0][0].split() if word not in stop)
sent
# Out:
# 'plan Scope management be process create Scope management plan document project product Scope will be define , validate , control .'

# %%
data_to_process['lemma_sentence'][0][0]
# Out:
# 'plan Scope management be the process of create a Scope management plan that document how the project and product Scope will be define , validate , and control .'

# %%
from spacy import displacy

doc = nlp(sent)
# in Jupyter Notebook
displacy.render(doc, style="dep", options={'compact': True, 'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="74f6a70dc5fe4e428a48c935c04d46a1-0" class="displacy" width="2210" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">plan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Scope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">management</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">process</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">create</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Scope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">management</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">plan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">document</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">project</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">product</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Scope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">define ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">validate ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">control .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-0" stroke-width="2px" d="M62,182.0 62,142.0 287.0,142.0 287.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,184.0 L58,176.0 66,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-1" stroke-width="2px" d="M182,182.0 182,162.0 284.0,162.0 284.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M182,184.0 L178,176.0 186,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-2" stroke-width="2px" d="M302,182.0 302,162.0 404.0,162.0 404.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,184.0 L298,176.0 306,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-3" stroke-width="2px" d="M422,182.0 422,162.0 524.0,162.0 524.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M524.0,184.0 L528.0,176.0 520.0,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-4" stroke-width="2px" d="M422,182.0 422,142.0 647.0,142.0 647.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M647.0,184.0 L651.0,176.0 643.0,176.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74f6a70dc5fe4e428a48c935c04d46a1-0-5" stroke-width="2px" d="M782,182.0 782,162.0 884.0,162.0 884.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing:

# %%
doc = nlp(data_to_process['lemma_sentence'][0][0])
# in Jupyter Notebook
displacy.render(doc, style="dep", options={'compact': True, 'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f3019c8c634c42df82c38d3801c56774-0" class="displacy" width="3170" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">plan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Scope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">management</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">process</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">create</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Scope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">management</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">plan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">document</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">project</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">product</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">Scope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">define ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">validate ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">control .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3019c8c634c42df82c38d3801c56774-0-0" stroke-width="2px" d="M62,302.0 62,262.0 281.0,262.0 281.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3019c8c634c42df82c38d3801c56774-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3019c8c634c42df82c38d3801c56774-0-1" stroke-width="2px" d="M182,302.0 182,282.0 278.0,282.0 278.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3019c8c634c42df82c38d3801c56774-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M182,304.0 L178,296.0 186,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class=

# %%
#data_to_process['lemma_sentence'] = data_to_process['lemma_sentence'].apply(lambda x : remove_punctuation(x) for i in len(x) )
for i in range(0,len(data_to_process['lemma_sentence'])):
    for j in range(0,len(data_to_process['lemma_sentence'][i])):
        
        data_to_process['lemma_sentence'][i][j] = remove_punctuation(data_to_process['lemma_sentence'][i][j])
        data_to_process['lemma_sentence'][i][j] = remove_number(data_to_process['lemma_sentence'][i][j])
        data_to_process['lemma_sentence'][i][j] = remove_extra_whitespaces_func(data_to_process['lemma_sentence'][i][j])

# %%
data_to_process.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 1                   . . . project charter
# 2           . . . project management plan
# 3  . . . enterprise environmental factors
# 4     . . . organizational process assets
#
#                                                  def  \
# 0  plan Scope management is the process of creati...
# 1
# 2
# 3  the enterprise environmental factors influence...
# 4  the organizational process assets influence th...
#
#                                            lemma_def  \
# 0  plan Scope management be the process of create...
# 1
# 2
# 3  the enterprise environmental factor influence ...
# 4  the organizational process asset influence the...
#
#                                       lemma_sentence
# 0  [plan Scope management be the process of creat...
# 1                                                 []
# 2                                                 []
# 3  [the enterprise environmental factor influence...
# 4  [the organizational process asset influence th...

# %%
t = tuple()  
def get_relation_from_definition(text,NP,VB):
    nltk_pos_tagged = nltk.pos_tag(text.split())
    chunk_tree = ntc.parse(nltk_pos_tagged)
    chunk_tree = get_the_rigth_chunking(chunk_tree)
    try :
        for k in range(len(chunk_tree)):
            chunk = chunk_tree[k]
            #print(chunk)
            if chunk.label() == 'NP':
                noun = ' '.join(word for word, pos in chunk.leaves())
                NP.append(noun)
            elif chunk.label() == 'VP':
                verb = ' '.join(word for word, pos in chunk.leaves())
                VB.append(verb)
    except AttributeError:
        pass
    return NP,VB

# %%
data_to_process['noun'] = [[] for _ in range(len(data_to_process))]
data_to_process['verb'] = [[] for _ in range(len(data_to_process))]

# %%
data_to_process.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 1                   . . . project charter
# 2           . . . project management plan
# 3  . . . enterprise environmental factors
# 4     . . . organizational process assets
#
#                                                  def  \
# 0  plan Scope management is the process of creati...
# 1
# 2
# 3  the enterprise environmental factors influence...
# 4  the organizational process assets influence th...
#
#                                            lemma_def  \
# 0  plan Scope management be the process of create...
# 1
# 2
# 3  the enterprise environmental factor influence ...
# 4  the organizational process asset influence the...
#
#                                       lemma_sentence noun verb
# 0  [plan Scope management be the process of creat...   []   []
# 1                                                 []   []   []
# 2                                                 []   []   []
# 3  [the enterprise environmental factor influence...   []   []
# 4  [the organizational process asset influence th...   []   []

# %%
for i in range(0,len(data_to_process['lemma_sentence'])):
    NP=[]
    VB=[]
    for j in range(0,len(data_to_process['lemma_sentence'][i])):
        if data_to_process['lemma_sentence'][i][j] == '':
            pass
        else:
            NP,VP = get_relation_from_definition(data_to_process['lemma_sentence'][i][j],NP,VB)
    data_to_process['noun'][i] = NP 
    data_to_process['verb'][i] = VP

# %%
data_to_process.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 1                   . . . project charter
# 2           . . . project management plan
# 3  . . . enterprise environmental factors
# 4     . . . organizational process assets
#
#                                                  def  \
# 0  plan Scope management is the process of creati...
# 1
# 2
# 3  the enterprise environmental factors influence...
# 4  the organizational process assets influence th...
#
#                                            lemma_def  \
# 0  plan Scope management be the process of create...
# 1
# 2
# 3  the enterprise environmental factor influence ...
# 4  the organizational process asset influence the...
#
#                                       lemma_sentence  \
# 0  [plan Scope management be the process of creat...
# 1                                                 []
# 2                                                 []
# 3  [the enterprise environmental factor influence...
# 4  [the organizational process asset influence th...
#
#                                                 noun  \
# 0  [plan Scope management, the process, create a ...
# 1                                                 []
# 2                                                 []
# 3  [the enterprise environmental factor influence...
# 4  [the organizational process asset influence, t...
#
#                                                 verb
# 0  [be, document, will be, be, provide, will be m...
# 1  [be, document, will be, be, provide, will be m...
# 2  [be, document, will be, be, provide, will be m...
# 3                                          [include]
# 4                                   [include, learn]

# %%
verb_list = []
for i in range(0, len(data_to_process['verb'])-1):
    verb_list +=  data_to_process['verb'][i]

# %%
verb_list
# Out:
# ['be',
#  'document',
#  'will be',
#  'be',
#  'provide',
#  'will be manage',
#  'be perform',
#  'be',
#  'describe',
#  'will be',
#  'develop',
#  'be',
#  'document',
#  'will be',
#  'be',
#  'provide',
#  'will be manage',
#  'be perform',
#  'be',
#  'describe',
#  'will be',
#  'develop',
#  'be',
#  'document',
#  'will be',
#  'be',
#  'provide',
#  'will be manage',
#  'be perform',
#  'be',
#  'describe',
#  'will be',
#  'develop',
#  'include',
#  'include',
#  'learn',
#  'include',
#  'learn',
#  'can be',
#  'include but be',
#  'limit to',
#  'elaborate',
#  'create',
#  'validate',
#  'control',
#  'be',
#  'may attend',
#  'to develop',
#  'may include',
#  'be',
#  'describe',
#  'will be',
#  'develop',
#  'include',
#  'enable',
#  'will be',
#  'maintain',
#  'es',
#  'will be obtain',
#  'can be',
#  'be',
#  'describe',
#  'will be',
#  'to',
#  'refer to',
#  'can include',
#  'will be',
#  'will be',
#  'will be',
#  'will be',
#  'to approve',
#  'will be',
#  're ect',
#  'be',
#  'documenting',
#  'to meet',
#  'be',
#  'provide',
#  'be perform',
#  'do not speci',
#  'be',
#  'provide',
#  's',
#  'be directly',
#  'documenting',
#  'manage',
#  'include',
#  'to be',
#  'to satisfy',
#  'include',
#  'to be',
#  'to be include',
#  'to be',
#  'become',
#  'be',
#  'be',
#  'documenting',
#  'to meet',
#  'be',
#  'provide',
#  'be perform',
#  'do not speci',
#  'be',
#  'provide',
#  's',
#  'be directly',
#  'documenting',
#  'manage',
#  'include',
#  'to be',
#  'to satisfy',
#  'include',
#  'to be',
#  'to be include',
#  'to be',
#  'become',
#  'be',
#  'be',
#  'documenting',
#  'to meet',
#  'be',
#  'provide',
#  'be perform',
#  'do not speci',
#  'be',
#  'provide',
#  's',
#  'be directly',
#  'documenting',
#  'manage',
#  'include',
#  'to be',
#  'to satisfy',
#  'include',
#  'to be',
#  'to be include',
#  'to be',
#  'become',
#  'be',
#  'can be consider',
#  'include',
#  'learn',
#  'be',
#  'to provide',
#  'be',
#  'to identify',
#  'can provide',
#  'capture',
#  'have',
#  'can be consider',
#  'include',
#  'learn',
#  'be',
#  'to provide',
#  'be',
#  'to identify',
#  'can provide',
#  'capture',
#  'have',
#  'can be consider',
#  'include',
#  'learn',
#  'be',
#  'to provide',
#  'be',
#  'to identify',
#  'can provide',
#  'capture',
#  'have',
#  'include',
#  'include',
#  'learn',
#  'include',
#  'learn',
#  'can be',
#  'include',
#  'brainstorming be',
#  'to generate and collect',
#  'to',
#  'be',
#  'to elicit',
#  'to',
#  'be typically perform',
#  'be often',
#  'may involve',
#  'experienced',
#  'can aid',
#  'identifying and',
#  'be also',
#  'bring together',
#  'to learn',
#  'to be',
#  'be',
#  'to quickly accumulate',
#  'be',
#  'be need',
#  'be geographically',
#  'could be',
#  'benchmarking',
#  'compare',
#  'to',
#  'to identify',
#  'provide',
#  'can be',
#  'can be',
#  'include',
#  'brainstorming be',
#  'to generate and collect',
#  'to',
#  'be',
#  'to elicit',
#  'to',
#  'be typically perform',
#  'be often',
#  'may involve',
#  'experienced',
#  'can aid',
#  'identifying and',
#  'be also',
#  'bring together',
#  'to learn',
#  'to be',
#  'be',
#  'to quickly accumulate',
#  'be',
#  'be need',
#  'be geographically',
#  'could be',
#  'benchmarking',
#  'compare',
#  'to',
#  'to identify',
#  'provide',
#  'can be',
#  'make',
#  'can be',
#  'include',
#  'voting be',
#  'have multiple',
#  'can be',
#  'to generate',
#  'classify',
#  'prioritize',
#  'include',
#  'be reach',
#  'be reach',
#  'obtain',
#  'have',
#  'can ensure',
#  'will be reach',
#  'be reach',
#  'be not achieve',
#  'be generally use',
#  'be',
#  'make',
#  'use',
#  'to provide',
#  'to evaluate and rank',
#  'can be',
#  'include',
#  'allow',
#  'to be',
#  'to re',
#  'understanding and to generate',
#  'can be',
#  'include',
#  'allow',
#  'to be',
#  'to re',
#  'understanding and to generate',
#  'be',
#  'depict',
#  'to',
#  's',
#  's receive',
#  'hr',
#  'legend',
#  'posting',
#  'posting',
#  'prototyping be',
#  'build',
#  'be',
#  'mock',
#  'to experiment',
#  'to discuss',
#  'storyboarding be',
#  'describe',
#  'meet',
#  'may start',
#  'become progressively',
#  'be know',
#  'to be',
#  'to key',
#  'may range',
#  'to',
#  'contain',
#  'categorize',
#  'to stakeholder',
#  'will be',
#  'can be',
#  'allow',
#  'be',
#  'describe',
#  'have be',
#  'need',
#  'will meet',
#  'be far',
#  'describe',
#  'include',
#  'should execute',
#  'describe',
#  'require',
#  'to be',
#  'include',
#  'need to transition',
#  'to',
#  'describe',
#  'to meet',
#  'include',
#  'need to validate',
#  'include',
#  'be',
#  'link',
#  'to',
#  'ensure',
#  'to',
#  'provide',
#  'to track',
#  'to ensure',
#  'approve',
#  'be deliver',
#  'include but be',
#  'to',
#  'to',
#  'can be record',
#  'to de',
#  'may include',
#  'add',
#  'approve',
#  'assign',
#  'to ensure',
#  'have meet',
#  'may include',
#  'provide',
#  'd',
#  'be',
#  'be',
#  'describe',
#  'be',
#  'be',
#  'describe',
#  'be',
#  'be',
#  'describe',
#  'can be consider',
#  'include',
#  'will be',
#  'contain',
#  'may affect',
#  'change',
#  'to avoid or mitigate',
#  'le',
#  'learn',
#  'le',
#  'learn',
#  'can be',
#  'include but be',
#  'limit to',
#  'can be',
#  'to evaluate',
#  'to meet',
#  'can be',
#  'include but be',
#  'limit to',
#  'can be',
#  'to evaluate',
#  'to meet',
#  'can be',
#  'include but be',
#  'limit to',
#  'can be',
#  'to evaluate',
#  'to meet',
#  'can be',
#  'to de',
#  'include',
#  'form',
#  'to describe',
#  'be go to be',
#  'have',
#  'accept',
#  'be',
#  'decompose to',
#  'to design',
#  'include',
#  'be',
#  'document',
#  'include',
#  'describe',
#  's',
#  'provide',
#  'may contain',
#  'can assist',
#  'enable',
#  'to perform',
#  'guide',
#  'provide',
#  'be contain',
#  's',
#  'to',
#  'will be',
#  'be exclude',
#  'can help determine',
#  'can control',
#  'to',
#  'include',
#  'to perform',
#  'be require to be produce to complete',
#  'include',
#  'may be describe',
#  'to be meet',
#  'be accept',
#  'es',
#  'be exclude',
#  'be sometimes',
#  'be',
#  'contain',
#  'be progressively',
#  'describe',
#  'summary',
#  'decide',
#  'be',
#  'sign',
#  'be',
#  'to be meet',
#  'to close or to cancel',
#  'authorize',
#  'may be',
#  'include',
#  'be',
#  'may be',
#  'changed',
#  'may be',
#  'to re',
#  'be',
#  'subdividing',
#  'be',
#  'provide',
#  'have to be',
#  'be perform',
#  'be',
#  'to be carry',
#  'to accomplish',
#  'create',
#  'de',
#  'represent',
#  'be contain',
#  'be',
#  'can be',
#  'to',
#  'be',
#  'to work',
#  'to',
#  'be not limit to',
#  'document',
#  'will be',
#  'can be consider',
#  'describe',
#  'will be',
#  'be exclude',
#  'describe',
#  'meet',
#  'include',
#  'be',
#  'to',
#  'speci',
#  'may serve',
#  'include',
#  'le',
#  'learn',
#  'include',
#  'le',
#  'learn',
#  'be',
#  'dividing and subdivide',
#  'be',
#  'can be',
#  'be often guide',
#  'need to',
#  'manage',
#  'will vary',
#  'involve',
#  'analyze',
#  'organize',
#  'decompose',
#  'develop and assign',
#  'to',
#  'verify',
#  'be',
#  'decompose down',
#  'be show',
#  'decompose',
#  'be',
#  'be not intend to represent',
#  'to imply',
#  'be',
#  'to organize',
#  'may be create',
#  'include',
#  'can be',
#  'to',
#  'can be represent',
#  'incorporate',
#  'may be develop',
#  'develop',
#  'organize',
#  'meeting',
#  'training',
#  'be',
#  'be not intend to represent',
#  'to imply',
#  'be',
#  'to organize',
#  'training',
#  'training train',
#  'mock',
#  'be',
#  'be not intend to represent',
#  'to imply',
#  'be',
#  'to organize',
#  'be',
#  'can be',
#  'may be',
#  'es',
#  'verify',
#  'require',
#  'be',
#  'can have',
#  'to arrive',
#  'to be',
#  'to',
#  'need',
#  'be',
#  'to',
#  'to',
#  'control',
#  'be',
#  'may not be',
#  'will be',
#  'wait',
#  'be agree',
#  'can be develop',
#  'be sometimes refer to',
#  'rolling',
#  'include',
#  'should roll',
#  'to',
#  'be leave',
#  'be perform',
#  'be sometimes call',
#  'refer to',
#  'speci',
#  'can be tailor to speci',
#  'be',
#  'can be change',
#  'be',
#  'be',
#  'include',
#  'be',
#  'to be carry',
#  'to accomplish',
#  'create',
#  'descend',
#  'represent',
#  'be',
#  'provide',
#  'form',
#  'be',
#  'be',
#  'be',
#  'to',
#  'have',
#  'be',
#  'may include',
#  'be',
#  'be',
#  'provide',
#  'scheduling',
#  'be',
#  'support',
#  'include',
#  'be create',
#  'add to',
#  'may include but be',
#  'to',
#  'may be',
#  'include',
#  'be',
#  'may be',
#  'to include approve',
#  'be',
#  'formalizing',
#  'be',
#  'to',
#  'increase',
#  'be perform',
#  'be',
#  'formalizing',
#  'be',
#  'to',
#  'increase',
#  'be perform',
#  'can be consider',
#  'include',
#  'learn',
#  'learn early',
#  'can be',
#  'to later',
#  'to improve',
#  'may include',
#  'nding',
#  'be review',
#  'to',
#  'be compare to',
#  'to determine',
#  'be',
#  'include',
#  'will be',
#  'be',
#  'check',
#  'be',
#  'check',
#  'be',
#  'check',
#  'be',
#  'check',
#  'meet',
#  'be formally sign',
#  'approve',
#  'acknowledge',
#  's',
#  'be forward to',
#  'include',
#  'have be accept and',
#  'have not be',
#  'be document',
#  'to stakeholder',
#  'have not be',
#  'be',
#  'may require',
#  'may be',
#  'include',
#  'learn',
#  'learn',
#  'be',
#  'could have be avoid',
#  'may be',
#  'be',
#  'be well',
#  'be',
#  'be',
#  'include',
#  'be',
#  'to',
#  'be',
#  'be maintain',
#  'be perform',
#  'be',
#  'to',
#  'be',
#  'be maintain',
#  'be perform',
#  'can be consider',
#  'include',
#  'learn',
#  'learn early',
#  'can be',
#  'to later',
#  'to improve',
#  'be',
#  'to detect',
#  'to detect',
#  'may also provide',
#  'be',
#  'can include',
#  'to be',
#  'can be',
#  'be',
#  'to compare',
#  'to',
#  'be',
#  'be',
#  'to determine',
#  'be',
#  'include determine',
#  'to',
#  'decide',
#  'be require',
#  'produce include',
#  'contextualize',
#  'be perform',
#  'to',
#  'can include',
#  'impact',
#  'produce include',
#  'contextualize',
#  'be perform',
#  'to',
#  'can include',
#  'impact',
#  'to',
#  'go',
#  'may require',
#  'include',
#  'may be',
#  'to re ect',
#  'be',
#  'to',
#  'be',
#  'to approve',
#  'can be',
#  'be need to provide',
#  'to',
#  'be',
#  'to approve',
#  'can be',
#  'be need to provide',
#  'to',
#  'be',
#  'to approve',
#  'can be',
#  'be need to provide',
#  'to',
#  'be',
#  'to approve',
#  'can be',
#  'be put',
#  'to revise',
#  'to provide',
#  'may be',
#  'include',
#  'learn',
#  'learn',
#  'can be',
#  'be',
#  'include',
#  'may be',
#  'changed',
#  'may be',
#  'to re',
#  'may be',
#  'include',
#  'learn',
#  'learn',
#  'can be',
#  'be',
#  'include',
#  'may be',
#  'changed',
#  'may be',
#  'to re',
#  'may be',
#  'include',
#  'learn',
#  'learn',
#  'can be',
#  'be',
#  'include',
#  'may be',
#  'changed',
#  'may be',
#  'to re',
#  'include',
#  'scheduling',
#  'to satisfy',
#  'c',
#  'include',
#  'learn',
#  'control',
#  'include',
#  'learn',
#  'control',
#  'can be',
#  'include but be',
#  'limit to',
#  'can include determine',
#  'to use',
#  'to combine',
#  'can also include determine',
#  'to be',
#  'should be',
#  'to manage',
#  'take to keep',
#  'to',
#  'to be reach',
#  'may hold planning meeting to develop',
#  'may include',
#  'be',
#  'establish',
#  'control',
#  'may be',
#  'include',
#  'can establish',
#  'to be',
#  'be',
#  'be',
#  'to minimize',
#  'force',
#  'to process',
#  'es',
#  'may include',
#  'be define',
#  'provide',
#  'allow',
#  'to update',
#  'be',
#  'may be',
#  'to indicate',
#  'to be',
#  'need to be take',
#  'earn',
#  'be set',
#  'may specify',
#  'to be employ',
#  'to',
#  'to assess',
#  'to',
#  'be',
#  'be',
#  'document',
#  'c',
#  'to be perform to produce',
#  'be',
#  'decompose',
#  'provide',
#  'executing',
#  'control',
#  'be perform',
#  'be',
#  'document',
#  'c',
#  'to be perform to produce',
#  'be',
#  'decompose',
#  'provide',
#  'executing',
#  'control',
#  'be perform',
#  'include',
#  'include',
#  'learn',
#  'contain',
#  'exist',
#  'include',
#  'learn',
#  'contain',
#  'exist',
#  'include',
#  'learn',
#  'contain',
#  'exist',
#  'rolling',
#  'be',
#  'to be',
#  'be plan',
#  'be plan',
#  'be',
#  'to work',
#  'planning',
#  'be',
#  'may be',
#  'to',
#  'be know',
#  'can be',
#  'may be',
#  'to',
#  'may be hold',
#  'to de',
#  'need to complete',
#  'include',
#  'require',
#  'use rolling',
#  'will be',
#  'include',
#  'to ensure',
#  'understand',
#  'be require to be',
#  'extend',
#  'evolve',
#  'include',
#  'can be',
#  'to identify',
#  'have to be perform',
#  'calendar',
#  'be assign to',
#  'be',
#  'ordering',
#  'sort',
#  'be',
#  'can not point or',
#  'indicate',
#  'be',
#  'have zero',
#  'represent',
#  'can not point or',
#  'be',
#  'can not point or',
#  'indicate',
#  'be',
#  'have zero',
#  'represent',
#  'can not point or',
#  'to',
#  'go',
#  'may require',
#  'include',
#  'be progressively',
#  'may reveal',
#  'be not',
#  'necessitate',
#  'to',
#  'be',
#  'to',
#  'be',
#  'to approve',
#  'be',
#  'documenting',
#  'be',
#  'de',
#  'to obtain',
#  'give',
#  'be perform',
#  'should be',
#  'to',
#  'should be',
#  'to create',
#  'may be',
#  'to use',
#  'to support',
#  'can be perform',
#  'to',
#  'to act',
#  'to publish',
#  'be',
#  'documenting',
#  'be',
#  'de',
#  'to obtain',
#  'give',
#  'be perform',
#  'should be',
#  'to',
#  'should be',
#  'to create',
#  'may be',
#  'to use',
#  'to support',
#  'can be perform',
#  'to',
#  'to act',
#  'to publish',
#  'can be consider',
#  'include',
#  'may describe',
#  'contain',
#  'require',
#  'be to be',
#  'can',
#  'may',
#  'be',
#  'may give',
#  'to',
#  'may impact',
#  'may have',
#  'may',
#  'be',
#  'include',
#  'scheduling',
#  'include',
#  'be consider',
#  'can be',
#  'to expedite',
#  'can also contain',
#  'learn',
#  'can help optimize',
#  'be',
#  'be represent',
#  'be graphically link',
#  'to show',
#  'be to be',
#  'include',
#  'be',
#  'come',
#  'be',
#  'come',
#  'be define',
#  'to start',
#  'can not start',
#  'have nishe',
#  ...]

# %%
verbs = []
for word in verb_list:
    split = word.split()
    for w in split :
        if w.lower() not in stop:
            verbs.append(w)

# %%
from collections import Counter
counter = Counter(verb_list)
sorted_counter = counter.most_common()
sorted_counter
# Out:
# [('be', 407),
#  ('to', 202),
#  ('include', 140),
#  ('can be', 98),
#  ('may be', 66),
#  ('learn', 45),
#  ('to be', 41),
#  ('will be', 40),
#  ('provide', 36),
#  ('be perform', 34),
#  ('to complete', 31),
#  ('have', 23),
#  ('describe', 22),
#  ('can be consider', 20),
#  ('should be', 20),
#  ('s', 19),
#  ('to approve', 18),
#  ('may require', 18),
#  ('may include', 17),
#  ('to determine', 17),
#  ('remain', 17),
#  ('to meet', 14),
#  ('contain', 14),
#  ('make', 12),
#  ('to re', 12),
#  ('to improve', 12),
#  ('show', 12),
#  ('learn early', 11),
#  ('to later', 11),
#  ('exist', 11),
#  ('to calculate', 11),
#  ('include but be', 10),
#  ('refer to', 10),
#  ('to provide', 10),
#  ('be often', 10),
#  ('use', 10),
#  ('scheduling', 10),
#  ('to assess', 10),
#  ('indicate', 10),
#  ('may have', 10),
#  ('develop', 9),
#  ('require', 9),
#  ('represent', 9),
#  ('be exactly', 9),
#  ('control', 8),
#  ('can include', 8),
#  ('documenting', 8),
#  ('become', 8),
#  ('allow', 8),
#  ('be require', 8),
#  ('may impact', 8),
#  ('to finish', 8),
#  ('determine', 8),
#  ('be base', 8),
#  ('to account', 8),
#  ('document', 7),
#  ('to identify', 7),
#  ('go', 7),
#  ('may', 7),
#  ('to start', 7),
#  ('to aggregate', 7),
#  ('to predict', 7),
#  ('limit to', 6),
#  ('to develop', 6),
#  ('es', 6),
#  ('manage', 6),
#  ('approve', 6),
#  ('to evaluate', 6),
#  ('decide', 6),
#  ('be maintain', 6),
#  ('c', 6),
#  ('to indicate', 6),
#  ('earn', 6),
#  ('be not', 6),
#  ('can affect', 6),
#  ('versus', 6),
#  ('to bring', 6),
#  ('create', 5),
#  ('build', 5),
#  ('ensure', 5),
#  ('involve', 5),
#  ('may not be', 5),
#  ('to re ect', 5),
#  ('be need to provide', 5),
#  ('be put', 5),
#  ('to revise', 5),
#  ('establish', 5),
#  ('to update', 5),
#  ('extend', 5),
#  ('may give', 5),
#  ('be include', 5),
#  ('start and', 5),
#  ('minus', 5),
#  ('bottom', 5),
#  ('to satisfy', 4),
#  ('could be', 4),
#  ('meet', 4),
#  ('to de', 4),
#  ('le', 4),
#  ('changed', 4),
#  ('de', 4),
#  ('decompose', 4),
#  ('can have', 4),
#  ('be sometimes refer to', 4),
#  ('check', 4),
#  ('be assign to', 4),
#  ('can not point or', 4),
#  ('to create', 4),
#  ('reduce', 4),
#  ('be generally', 4),
#  ('begin', 4),
#  ('be estimate', 4),
#  ('buy', 4),
#  ('be develop', 4),
#  ('to establish', 4),
#  ('identify', 4),
#  ('to nd', 4),
#  ('bring', 4),
#  ('to change', 4),
#  ('occur', 4),
#  ('to allow', 4),
#  ('funding', 4),
#  ('do so', 4),
#  ('must be maintain', 4),
#  ('will be manage', 3),
#  ('enable', 3),
#  ('maintain', 3),
#  ('do not speci', 3),
#  ('be directly', 3),
#  ('to be include', 3),
#  ('can provide', 3),
#  ('capture', 3),
#  ('be also', 3),
#  ('compare', 3),
#  ('prioritize', 3),
#  ('be reach', 3),
#  ('need', 3),
#  ('to track', 3),
#  ('to ensure', 3),
#  ('change', 3),
#  ('be exclude', 3),
#  ('to be meet', 3),
#  ('be not limit to', 3),
#  ('organize', 3),
#  ('be show', 3),
#  ('be not intend to represent', 3),
#  ('to imply', 3),
#  ('to organize', 3),
#  ('be document', 3),
#  ('to compare', 3),
#  ('to use', 3),
#  ('can establish', 3),
#  ('be plan', 3),
#  ('need to complete', 3),
#  ('to obtain', 3),
#  ('give', 3),
#  ('can be perform', 3),
#  ('be to be', 3),
#  ('can', 3),
#  ('can not start', 3),
#  ('adjust', 3),
#  ('eliminate', 3),
#  ('be reserve', 3),
#  ('be intend to address', 3),
#  ('be not include', 3),
#  ('to estimate', 3),
#  ('to reduce', 3),
#  ('be use to calculate', 3),
#  ('to adjust', 3),
#  ('do not exceed', 3),
#  ('start', 3),
#  ('to address', 3),
#  ('will nish', 3),
#  ('see', 3),
#  ('be display', 3),
#  ('track', 3),
#  ('remain to be', 3),
#  ('be use to analyze', 3),
#  ('take', 3),
#  ('be then', 3),
#  ('be then calculate to forecast', 3),
#  ('be determine', 3),
#  ('estimate', 3),
#  ('could impact', 3),
#  ('should specify', 3),
#  ('be aggregated to obtain', 3),
#  ('be plan to be', 3),
#  ('to consider', 3),
#  ('planned', 3),
#  ('be ahead or', 3),
#  ('to plan', 3),
#  ('to forecast', 3),
#  ('to display', 3),
#  ('should consider', 3),
#  ('be provide', 3),
#  ('to monitor', 3),
#  ('validate', 2),
#  ('brainstorming be', 2),
#  ('to generate and collect', 2),
#  ('to elicit', 2),
#  ('be typically perform', 2),
#  ('may involve', 2),
#  ('experienced', 2),
#  ('can aid', 2),
#  ('identifying and', 2),
#  ('bring together', 2),
#  ('to learn', 2),
#  ('to quickly accumulate', 2),
#  ('be need', 2),
#  ('be geographically', 2),
#  ('benchmarking', 2),
#  ('have multiple', 2),
#  ('to generate', 2),
#  ('understanding and to generate', 2),
#  ('posting', 2),
#  ('mock', 2),
#  ('be know', 2),
#  ('to stakeholder', 2),
#  ('have be', 2),
#  ('link', 2),
#  ('d', 2),
#  ('form', 2),
#  ('accept', 2),
#  ('can assist', 2),
#  ('to perform', 2),
#  ('be contain', 2),
#  ('be progressively', 2),
#  ('to be carry', 2),
#  ('to accomplish', 2),
#  ('to work', 2),
#  ('speci', 2),
#  ('verify', 2),
#  ('incorporate', 2),
#  ('may be develop', 2),
#  ('training', 2),
#  ('rolling', 2),
#  ('be sometimes call', 2),
#  ('can be change', 2),
#  ('formalizing', 2),
#  ('increase', 2),
#  ('be compare to', 2),
#  ('have not be', 2),
#  ('be well', 2),
#  ('to detect', 2),
#  ('include determine', 2),
#  ('produce include', 2),
#  ('contextualize', 2),
#  ('impact', 2),
#  ('may hold planning meeting to develop', 2),
#  ('be define', 2),
#  ('need to be take', 2),
#  ('be set', 2),
#  ('to be employ', 2),
#  ('to be perform to produce', 2),
#  ('executing', 2),
#  ('understand', 2),
#  ('have zero', 2),
#  ('may reveal', 2),
#  ('to support', 2),
#  ('to act', 2),
#  ('to publish', 2),
#  ('may describe', 2),
#  ('be consider', 2),
#  ('come', 2),
#  ('have nishe', 2),
#  ('can not nish', 2),
#  ('be establish', 2),
#  ('to construct', 2),
#  ('include scheduling', 2),
#  ('illustrate', 2),
#  ('be call', 2),
#  ('may need to be', 2),
#  ('will take to complete', 2),
#  ('have be assign to', 2),
#  ('will have', 2),
#  ('estimating be', 2),
#  ('automated', 2),
#  ('to weigh', 2),
#  ('may also be', 2),
#  ('will take', 2),
#  ('generate', 2),
#  ('can require', 2),
#  ('can serve', 2),
#  ('identify and sequence', 2),
#  ('be still', 2),
#  ('be then analyze to determine', 2),
#  ('be approve and', 2),
#  ('to sustain', 2),
#  ('continue', 2),
#  ('to build', 2),
#  ('will be include', 2),
#  ('will be require to complete', 2),
#  ('use to create', 2),
#  ('affect', 2),
#  ('review', 2),
#  ('to produce', 2),
#  ('happen', 2),
#  ('to compute', 2),
#  ('introduce', 2),
#  ('model', 2),
#  ('develop and deliver', 2),
#  ('integrate', 2),
#  ('shift', 2),
#  ('should be do to ensure', 2),
#  ('see be', 2),
#  ('crash', 2),
#  ('be forecast', 2),
#  ('accounting', 2),
#  ('can also include', 2),
#  ('will be perform', 2),
#  ('weight', 2),
#  ('know', 2),
#  ('to initiate and complete', 2),
#  ('to achieve', 2),
#  ('will increase', 2),
#  ('can be make and', 2),
#  ('nancing', 2),
#  ('nancing include', 2),
#  ('to cover', 2),
#  ('report', 2),
#  ('be aggregate', 2),
#  ('be add to', 2),
#  ('update', 2),
#  ('can only be approve', 2),
#  ('monitor', 2),
#  ('be act', 2),
#  ('to isolate and understand', 2),
#  ('unapproved', 2),
#  ('inform', 2),
#  ('to control', 2),
#  ('measure', 2),
#  ('consider', 2),
#  ('to be achieve', 2),
#  ('to nish', 2),
#  ('be achieve', 2),
#  ('be conceptually display', 2),
#  ('left', 2),
#  ('remaining', 2),
#  ('can be either', 2),
#  ('will need to be', 2),
#  ('to stay', 2),
#  ('must be achieve', 2),
#  ('to complete to complete', 2),
#  ('pv', 2),
#  ('tcpi', 2),
#  ('mean', 2),
#  ('to be do', 2),
#  ('eac', 2),
#  ('be proceed', 2),
#  ('reestimate', 2),
#  ('elaborate', 1),
#  ('may attend', 1),
#  ('will be obtain', 1),
#  ('re ect', 1),
#  ('voting be', 1),
#  ('classify', 1),
#  ('obtain', 1),
#  ('can ensure', 1),
#  ('will be reach', 1),
#  ('be not achieve', 1),
#  ('be generally use', 1),
#  ('to evaluate and rank', 1),
#  ('depict', 1),
#  ('s receive', 1),
#  ('hr', 1),
#  ('legend', 1),
#  ('prototyping be', 1),
#  ('to experiment', 1),
#  ('to discuss', 1),
#  ('storyboarding be', 1),
#  ('may start', 1),
#  ('become progressively', 1),
#  ('to key', 1),
#  ('may range', 1),
#  ('categorize', 1),
#  ('will meet', 1),
#  ('be far', 1),
#  ('should execute', 1),
#  ('need to transition', 1),
#  ('need to validate', 1),
#  ('be deliver', 1),
#  ('can be record', 1),
#  ('add', 1),
#  ('assign', 1),
#  ('have meet', 1),
#  ('may affect', 1),
#  ('to avoid or mitigate', 1),
#  ('to describe', 1),
#  ('be go to be', 1),
#  ('decompose to', 1),
#  ('to design', 1),
#  ('may contain', 1),
#  ('guide', 1),
#  ('can help determine', 1),
#  ('can control', 1),
#  ('be require to be produce to complete', 1),
#  ('may be describe', 1),
#  ('be accept', 1),
#  ('be sometimes', 1),
#  ('summary', 1),
#  ('sign', 1),
#  ('to close or to cancel', 1),
#  ('authorize', 1),
#  ('subdividing', 1),
#  ('have to be', 1),
#  ('may serve', 1),
#  ('dividing and subdivide', 1),
#  ('be often guide', 1),
#  ('need to', 1),
#  ('will vary', 1),
#  ('analyze', 1),
#  ('develop and assign', 1),
#  ('decompose down', 1),
#  ('may be create', 1),
#  ('can be represent', 1),
#  ('meeting', 1),
#  ('training train', 1),
#  ('to arrive', 1),
#  ('wait', 1),
#  ('be agree', 1),
#  ('can be develop', 1),
#  ('should roll', 1),
#  ('be leave', 1),
#  ('can be tailor to speci', 1),
#  ('descend', 1),
#  ('support', 1),
#  ('be create', 1),
#  ('add to', 1),
#  ('may include but be', 1),
#  ('to include approve', 1),
#  ('nding', 1),
#  ('be review', 1),
#  ('be formally sign', 1),
#  ('acknowledge', 1),
#  ('be forward to', 1),
#  ('have be accept and', 1),
#  ('could have be avoid', 1),
#  ('may also provide', 1),
#  ('can include determine', 1),
#  ('to combine', 1),
#  ('can also include determine', 1),
#  ('to manage', 1),
#  ('take to keep', 1),
#  ('to be reach', 1),
#  ('to minimize', 1),
#  ('force', 1),
#  ('to process', 1),
#  ('may specify', 1),
#  ('planning', 1),
#  ('may be hold', 1),
#  ('use rolling', 1),
#  ('be require to be', 1),
#  ('evolve', 1),
#  ('have to be perform', 1),
#  ('calendar', 1),
#  ('ordering', 1),
#  ('sort', 1),
#  ('necessitate', 1),
#  ('to expedite', 1),
#  ('can also contain', 1),
#  ('can help optimize', 1),
#  ('be represent', 1),
#  ('be graphically link', 1),
#  ('to show', 1),
#  ('instal', 1),
#  ('write', 1),
#  ('be require to nish', 1),
#  ('can nish', 1),
#  ('can not begin', 1),
#  ('have to start', 1),
#  ('can be shut', 1),
#  ('be very', 1),
#  ('be include to present', 1),
#  ('be not recommend', 1),
#  ('have to be make to select', 1),
#  ('to start ss', 1),
#  ('may be characterize', 1),
#  ('require or inherent', 1),
#  ('to erect', 1),
#  ('have be build', 1),
#  ('have to be build', 1),
#  ('should not be confuse', 1),
#  ('be desire', 1),
#  ('recommend', 1),
#  ('should start', 1),
#  ('may occur', 1),
#  ('perform', 1),
#  ('can create', 1),
#  ('can limit', 1),
#  ('be usually', 1),
#  ('may need to be hold', 1),
#  ('can begin', 1),
#  ('can not test', 1),
#  ('assemble', 1),
#  ('could be schedule to start', 1),
#  ('would be show', 1),
#  ('lag', 1),
#  ('lead', 1),
#  ('will be delay', 1),
#  ('may begin edit', 1),
#  ('begin write', 1),
#  ('can be show', 1),
#  ('can also be', 1),
#  ('lag even', 1),
#  ('be not show', 1),
#  ('to accurately de', 1),
#  ('should not replace', 1),
#  ('to help', 1),
#  ('insert', 1),
#  ('differentiate', 1),
#  ('j', 1),
#  ('be produce', 1),
#  ('can accompany', 1),
#  ('to sequence', 1),
#  ('be affect', 1),
#  ('k be call', 1),
#  ('may be impact', 1),
#  ('may describe define', 1),
#  ('will signi', 1),
#  ('may be reduce', 1),
#  ('to increase', 1),
#  ('estimating', 1),
#  ('use to estimate', 1),
#  ('prepare', 1),
#  ('multiply', 1),
#  ('to be perform', 1),
#  ('drawing', 1),
#  ('to install', 1),
#  ('can produce', 1),
#  ('depend', 1),
#  ('may be improve', 1),
#  ('to tm', 1),
#  ('clarify', 1),
#  ('aggregate', 1),
#  ('be then aggregate', 1),
#  ('may or', 1),
#  ('may not have', 1),
#  ('be re', 1),
#  ('may hold', 1),
#  ('break', 1),
#  ('be usually hold', 1),
#  ('be attend', 1),
#  ('do not include', 1),
#  ('assess', 1),
#  ('to see', 1),
#  ('would necessitate', 1),
#  ('be employ', 1),
#  ('calculate', 1),
#  ('be measure', 1),
#  ('can be delay or extend', 1),
#  ('violate', 1),
#  ('be normally characterize', 1),
#  ('be calculate', 1),
#  ('be later', 1),
#  ('have be calculate', 1),
#  ('be violate', 1),
#  ('to begin', 1),
#  ('finish', 1),
#  ('to or', 1),
#  ('to demand and supply', 1),
#  ('to keep', 1),
#  ('can often cause', 1),
#  ('to resource', 1),
#  ('may only be delay', 1),
#  ('to optimize', 1),
#  ('to shorten or accelerate', 1),
#  ('to violate', 1),
#  ('imposed', 1),
#  ('can become', 1),
#  ('be compare', 1),
#  ('to shorten', 1),
#  ('include approve', 1),
#  ('pay to expedite', 1),
#  ('will shorten', 1),
#  ('crashing do', 1),
#  ('produce', 1),
#  ('may result', 1),
#  ('do', 1),
#  ('be construct', 1),
#  ('fast track', 1),
#  ('expedite', 1),
#  ('to decide', 1),
#  ('to be develop and', 1),
#  ('will take to have', 1),
#  ('be look', 1),
#  ('release', 1),
#  ('to deliver', 1),
#  ('be accept and approve', 1),
#  ('have occur', 1),
#  ('be do', 1),
#  ('have be con', 1),
#  ('may also be develop', 1),
#  ('be relatively', 1),
#  ('to read and be', 1),
#  ('structured', 1),
#  ('to bar', 1),
#  ('be commonly', 1),
#  ('be optimize to show', 1),
#  ('may appear', 1),
#  ('.mb', 1),
#  ('deliver', 1),
#  ('resource', 1),
#  ('apply', 1),
#  ('could also include', 1),
#  ('be develop and', 1),
#  ('to include', 1),
#  ('can result', 1),
#  ('will likely need to be', 1),
#  ('can not', 1),
#  ('perceive', 1),
#  ('be apply', 1),
#  ('can adjust', 1),
#  ('be write', 1),
#  ('decrease', 1),
#  ('can include review', 1),
#  ('to acquire', 1),
#  ('making', 1),
#  ('renting', 1),
#  ('leasing', 1),
#  ('lump', 1),
#  ('will be round', 1),
#  ('link directly to', 1),
#  ('u', 1),
#  ('specify', 1),
#  ('will affect', 1),
#  ('be charge', 1),
#  ('have be identi', 1),
#  ('provide detailed', 1),
#  ('to select', 1),
#  ('to use to execute and perform', 1),
#  ('would be evaluate', 1),
#  ('to prepare', 1),
#  ('evaluate', 1),
#  ('to assist', 1),
#  ('simplify', 1),
#  ('facilitate', 1),
#  ('be apply to', 1),
#  ('be not limit to direct', 1),
#  ('can be include', 1),
#  ('to cost', 1),
#  ('may be make', 1),
#  ('be then aggregated', 1),
#  ('limit to reserve', 1),
#  ('costing', 1),
#  ('can vary', 1),
#  ('be readily', 1),
#  ('work', 1),
#  ('will sometimes necessitate', 1),
#  ('to level', 1),
#  ('acquire', 1),
#  ('to seek', 1),
#  ('be fund', 1),
#  ('exclude', 1),
#  ('can only be change', 1),
#  ('be use', 1),
#  ('be directly tie to', 1),
#  ('be typically display', 1),
#  ('use earn', 1),
#  ('be refer to', 1),
#  ('warrant', 1),
#  ('to move', 1),
#  ('account', 1),
#  ('will include', 1),
#  ('appear', 1),
#  ('to record', 1),
#  ('to form', 1),
#  ('be allocate', 1),
#  ('should have be', 1),
#  ('be also know', 1),
#  ('can not be', 1),
#  ('should be establish', 1),
#  ('to measure', 1),
#  ('n', 1),
#  ('to correspond', 1),
#  ('direct', 1),
#  ('be spend to achieve', 1),
#  ('cost', 1),
#  ('can be perform to determine', 1),
#  ('will tend to decrease', 1),
#  ('can indicate', 1),
#  ('be fall', 1),
#  ('will ultimately', 1),
#  ('will have be earn', 1),
#  ('be particularly', 1),
#  ('to recover', 1),
#  ('spi be', 1),
#  ('be sometimes use', 1),
#  ('need to be analyze to determine', 1),
#  ('may develop', 1),
#  ('may differ', 1),
#  ('forecast', 1),
#  ('reissue', 1),
#  ('be execute', 1),
#  ('cover', 1),
#  ('be incumbent', 1),
#  ('may encounter to perform', 1),
#  ('ev', 1),
#  ('be quickly compare', 1),
#  ('be describe', 1),
#  ('predict', 1),
#  ('assume', 1),
#  ('have experience to', 1),
#  ('to continue', 1),
#  ('be assume to be perform', 1),
#  ('reserve', 1),
#  ('be still need or', 1),
#  ('to request', 1),
#  ('be incorporate', 1),
#  ('to feedback', 1)]

# %%
noun_list = []
for i in range(0, len(data_to_process['noun'])-1):
    noun_list +=  data_to_process['noun'][i]

# %%
noun = []
for word in noun_list:
    if len(word.split()) >= 3:
        noun.append(word)

# %%
noun
# Out:
# ['plan Scope management',
#  'create a Scope management plan',
#  'the key benefit',
#  'the Scope management plan',
#  'program management plan',
#  'the Scope management plan',
#  'the project Scope begin',
#  'the project charter',
#  'the late approve subsidiary plan',
#  'the project management plan',
#  'historical information contain',
#  'the organizational process asset',
#  'any other relevant enterprise environmental factor',
#  'the enterprise environmental factor influence',
#  'the plan Scope management process',
#  'organization s culture',
#  'the organizational process asset influence',
#  'the plan Scope management process',
#  'a data analysis technique',
#  'the Scope management plan',
#  'the project manager',
#  'the project sponsor',
#  'select project team member',
#  'the Scope management process',
#  'the Scope management plan',
#  'the project management plan',
#  'a Scope management plan',
#  'prepare a project Scope statement',
#  'the detailed project Scope statement',
#  'the Scope baseline',
#  'the complete project deliverable',
#  'the Scope management plan',
#  'the requirement management plan',
#  'the project management plan',
#  'a practice guide',
#  'a business analysis plan',
#  'the requirement management plan',
#  'guration management activity such',
#  'the authorization level require',
#  'requirement prioritization process',
#  'the requirement attribute capture',
#  'the traceability matrix',
#  'manage stakeholder need',
#  'the key benefit',
#  'the product Scope',
#  'the pmbok guide',
#  'address product requirement',
#  'industry speci c. note',
#  'a practice guide',
#  'active stakeholder involvement',
#  'the care take',
#  'impose speci cation',
#  'the quanti ed',
#  'these requirement need',
#  'the Scope baseline',
#  'project execution begin',
#  'the assumption log identi ed assumption',
#  'other factor influence requirement',
#  'lesson learn register',
#  'effective requirement collection technique',
#  'adaptive product development methodology',
#  'the stakeholder register',
#  'the enterprise environmental factor influence',
#  'the collect requirement process',
#  'organization s culture',
#  'the organizational process asset influence',
#  'the collect requirement process',
#  'datum gathering technique',
#  'a technique use',
#  'multiple idea relate',
#  'record the response',
#  'an individual basis',
#  'subject matter expert',
#  'the desire product deliverable',
#  'obtain con dential information',
#  'prequali ed stakeholder',
#  'subject matter expert',
#  'a propose product',
#  'a train moderator',
#  'an interactive discussion design',
#  'a large number',
#  'a quick turnaround',
#  'the organization compare',
#  'the collect requirement process',
#  'a collective decision making technique',
#  'an assessment process',
#  'an expect outcome',
#  'u n unanimity',
#  'a single course',
#  'u n majority',
#  'a group size',
#  'an uneven number',
#  'u n plurality',
#  'the large block',
#  'a group decide',
#  'autocratic decision making',
#  'one individual take responsibility',
#  'multicriteria decision analysis',
#  'a decision matrix',
#  'a systematic analytical approach',
#  'datum representation technique',
#  'af nity diagram',
#  'mind mapping consolidate idea create',
#  'individual brainstorming session',
#  'a single map',
#  'the context diagram',
#  'a Scope model',
#  'the product Scope',
#  'show a business system process',
#  'context diagram show input',
#  'the business system',
#  'the business system',
#  'context diagram hire manager internal associate internal full time',
#  'part time contractor recruit agency job seeker',
#  'talent management system',
#  'abc company external job website external user internal user external user internal user internal user internal datum flow external user',
#  'external datum flow external job',
#  'external user profile internal job',
#  'internal user profile',
#  'obtain early feedback',
#  'provide a model',
#  'the expect product',
#  'small scale product',
#  'computer generate d',
#  'prototype allow stakeholder',
#  'the nal product',
#  'a prototyping technique show sequence',
#  'storyboard use mock',
#  'show navigation path',
#  'other user interface',
#  'the business need',
#  'a high level',
#  'the requirement document',
#  'a simple document list all',
#  'the requirement categorize',
#  'an executive summary',
#  'the former refer',
#  'further re nement',
#  'these classi cation include',
#  'the high level need',
#  'the business issue',
#  'these describe feature',
#  'u n functional requirement',
#  'u n nonfunctional requirement',
#  'nonfunctional requirement supplement functional requirement',
#  'the environmental condition',
#  'these describe temporary capability',
#  'the desire future state',
#  'the project need',
#  'the successful completion',
#  'a project deliverable',
#  'other project requirement',
#  'the requirement traceability matrix',
#  'a requirement traceability matrix help',
#  'each requirement add business value',
#  'the project life cycle',
#  'the requirement documentation',
#  'high level requirement',
#  'more detailed requirement',
#  'the requirement traceability matrix',
#  'these attribute help',
#  'ne key information',
#  'typical attribute use',
#  'the requirement traceability matrix',
#  'a unique identi er',
#  'a textual description',
#  'current status such',
#  'a requirement traceability matrix',
#  'its associate attribute',
#  'a requirement traceability matrix requirement traceability matrix requirement description',
#  'i d business need',
#  'objective project objective associate',
#  'wb deliverable product design product development test case program portfolio project name',
#  'develop a detailed description',
#  'the key benefit',
#  'the assumption log identi es assumption',
#  'other factor influence',
#  'requirement documentation identi es requirement',
#  'the risk register',
#  'the project Scope',
#  'the enterprise environmental factor influence',
#  'the de ne Scope process include',
#  'organization s culture',
#  'the organizational process asset influence',
#  'the de ne Scope process include',
#  'a project Scope statement',
#  'a data analysis technique',
#  'the objective identi ed',
#  'other relevant aspect',
#  'each application area',
#  'translate high level product',
#  'a high level',
#  'the nal product',
#  'product analysis technique',
#  'the project Scope statement',
#  'the project Scope',
#  'the project Scope statement',
#  'the entire Scope',
#  'a common understanding',
#  'the project Scope',
#  'explicit scope exclusion',
#  'manage stakeholder expectation',
#  'the project team',
#  'more detailed planning',
#  'the project team s work',
#  'which the project Scope statement',
#  'ne the work',
#  'the project management team',
#  'the overall project Scope',
#  'the detailed project Scope statement',
#  'product Scope description',
#  'project management report',
#  'a summary level',
#  'the project charter',
#  'the project Scope statement',
#  'contain a certain degree',
#  'the project charter',
#  'high level information',
#  'the project Scope statement contain',
#  'a detailed description',
#  'the Scope component',
#  'the key element',
#  'project charter project purpose measurable project objective',
#  'related success criterion high level requirement high level project description',
#  'key deliverable overall project risk',
#  'financial resource key stakeholder list project approval requirement i.e.',
#  'what constitute success',
#  'the project project exit criterion i.e.',
#  'phase assign project manager',
#  'authority level name',
#  'other person s',
#  'the project charter project Scope statement project Scope description',
#  'elaborate project deliverable acceptance criterion project exclusion table',
#  'the project charter',
#  'project Scope statement',
#  'the assumption log',
#  'be identi ed',
#  'requirement traceability matrix',
#  'the requirement traceability matrix',
#  'the key benefit',
#  'a hierarchical decomposition',
#  'the total Scope',
#  'the project team',
#  'the project objective',
#  'the require deliverable',
#  'the wbs organize',
#  'ne the total Scope',
#  'the work speci ed',
#  'the current approve project Scope statement',
#  'the plan work',
#  'the low level',
#  'call work package',
#  'a work package',
#  'group the activity',
#  'be the result',
#  'a project management plan component include',
#  'the Scope management plan',
#  'the Scope management plan',
#  'the project Scope statement',
#  'this process include',
#  'project Scope statement',
#  'the project Scope statement',
#  'the business need',
#  'the enterprise environmental factor influence',
#  'the create wbs process',
#  'industry speci c wbs standard',
#  'external reference source',
#  'create the wbs',
#  'the organizational process asset influence',
#  'the create wbs process',
#  'a technique use',
#  'the project Scope',
#  'the work package',
#  'the work define',
#  'the low level',
#  'the total project work',
#  'the follow activity',
#  'the upper wbs level',
#  'low level detailed component',
#  'identi cation code',
#  'the wbs component',
#  'the work package level',
#  'value management system project',
#  'the full project Scope',
#  'any specific project',
#  'the only way',
#  'system requirement development',
#  'current system audit',
#  'requirement change identification',
#  'a wbs structure',
#  'the popular method',
#  'organization speci c guideline',
#  'the wbs structure',
#  'the project life cycle',
#  'the second level',
#  'project deliverable insert',
#  'the third level',
#  'use major deliverable',
#  'the second level',
#  'the project team',
#  'the support contract wb',
#  'the contract work',
#  'phase planning software product release',
#  'detail design construct integration',
#  'test project management product requirement software software software software',
#  'user documentation user documentation',
#  'user documentation user documentation administration',
#  'program material training program material training program material training program material',
#  'the full project Scope',
#  'any specific project',
#  'the only way',
#  'system engineering management support pm activity aircraft system project management equipment',
#  'facility training service',
#  'technical order engineering data management data datum air vehicle organizational level se intermediate level se depot level se support equipment airframe engine communication system navigation system fire control system base building maintenance facility facility',
#  'operational test developmental test test test',
#  'evaluation the wbs',
#  'the full project Scope',
#  'any specific project',
#  'the only way',
#  'major deliverable decomposition',
#  'the upper level',
#  'wbs component require',
#  'its most fundamental component',
#  'the wbs component represent veri able product',
#  'an agile approach',
#  'an organizational chart',
#  'a hierarchical breakdown',
#  'the low level wbs component',
#  'the correspond high level deliverable',
#  'a work package',
#  'some deliverable need',
#  'the next level',
#  'the project management team',
#  'the wbs represent',
#  'the project management work',
#  'the low level',
#  'the high level',
#  'no extra work',
#  'the percent rule',
#  'speci c information',
#  'the practice standard',
#  'work breakdown structure second edition',
#  'this standard contain industry',
#  'a particular application area',
#  'the Scope baseline',
#  'the approve version',
#  'a Scope statement',
#  'its associate wb dictionary',
#  'formal change control procedure',
#  'the project management plan',
#  'the Scope baseline include',
#  'project Scope statement',
#  'the project Scope statement',
#  'the project Scope',
#  'a hierarchical decomposition',
#  'the total Scope',
#  'the project team',
#  'the project objective',
#  'the require deliverable',
#  'detailed de nition',
#  'the project work',
#  'the low level',
#  'a work package',
#  'a unique identi er',
#  'these identi er',
#  'each work package',
#  'a control account',
#  'a control account',
#  'a management control point',
#  'the earn value',
#  'a control account',
#  'each work package',
#  'a single control account',
#  'a control account',
#  'a planning package',
#  'a work breakdown structure component',
#  'the control account',
#  'the work package',
#  'know work content',
#  'detailed schedule activity',
#  'the wbs dictionary',
#  'the wbs dictionary',
#  'the wbs dictionary',
#  'a later stage',
#  'the wbs dictionary',
#  'u n code',
#  'account identi er',
#  'u n description',
#  'u n assumption',
#  'u n responsible organization',
#  'u n schedule milestone',
#  'u n associate schedule activity',
#  'u n resource require',
#  'u n cost estimate',
#  'u n quality requirement',
#  'u n acceptance criterion',
#  'u n agreement information',
#  'u n assumption log',
#  'the assumption log',
#  'be identi ed',
#  'the create wbs process',
#  'u n requirement documentation',
#  'the create wbs process',
#  'the complete project deliverable',
#  'the key benefit',
#  'it bring objectivity',
#  'the acceptance process',
#  'validate each deliverable',
#  'the ef ciency',
#  'the information present',
#  'the quality report',
#  'all quality assurance issue manage',
#  'the control quality process',
#  'the actual result',
#  'requirement traceability matrix',
#  'the requirement traceability matrix contain information',
#  'the control quality process',
#  'the acceptance criterion',
#  'formal documentation receive',
#  'formal stakeholder acceptance',
#  'the close project',
#  'work performance information',
#  'the complete deliverable',
#  'a change request',
#  'the change request describe',
#  'the perform integrate change control process',
#  'the requirement documentation',
#  'the actual result',
#  'the actual result',
#  'requirement traceability matrix',
#  'the requirement traceability matrix',
#  'the method use',
#  'monitor the status',
#  'the Scope baseline',
#  'the key benefit',
#  'the Scope baseline',
#  'requirement traceability matrix',
#  'the requirement traceability matrix help',
#  'the Scope baseline',
#  'the project objective',
#  'work performance datum',
#  'change request receive',
#  'deliverable veri ed',
#  'the organizational process asset influence',
#  'the control Scope process include',
#  'control related policy',
#  'datum analysis technique',
#  'the control Scope process include',
#  'the actual result',
#  'the threshold amount',
#  'trend analysis examine project performance',
#  'project Scope control',
#  'the Scope baseline',
#  'work performance information',
#  'the Scope baseline',
#  'the change receive',
#  'the identi ed Scope variance',
#  'the future Scope performance',
#  'the project management plan',
#  'the organization s change control process',
#  'a change request',
#  'a change request',
#  'the project management plan',
#  'scope management plan',
#  'the Scope management plan',
#  'the Scope baseline',
#  'the wbs dictionary',
#  'a revise Scope baseline',
#  'a realistic basis',
#  'the schedule baseline',
#  'a revise schedule baseline',
#  'a realistic basis',
#  'the cost baseline',
#  'a revise cost baseline',
#  'a realistic basis',
#  'performance measurement baseline',
#  'the performance measurement baseline',
#  'the performance variance',
#  'a change request',
#  'the performance measurement baseline',
#  'a realistic basis',
#  'corrective action choose',
#  'requirement traceability matrix',
#  'the requirement traceability matrix',
#  'the enterprise environmental factor influence',
#  'the plan schedule management process',
#  'team resource availability',
#  'physical resource availability',
#  'tailor the organization s set',
#  'standardized estimate datum',
#  'the organizational process asset influence',
#  'the plan schedule management process',
#  'informal schedule development',
#  'a data analysis technique',
#  'which schedule methodology',
#  'detailed the schedule need',
#  'roll wave planning',
#  'an appropriate balance',
#  'the schedule management plan',
#  'the project manager',
#  'the project sponsor',
#  'select project team member',
#  'the schedule management plan',
#  'the project management plan',
#  'the schedule management plan',
#  'appropriate control threshold',
#  'the schedule management plan',
#  'project schedule model development',
#  'the scheduling methodology',
#  'the scheduling tool',
#  'the project schedule model',
#  'time box period',
#  'which the team work',
#  'time boxing help',
#  'essential feature rst',
#  'the acceptable range use',
#  'determine realistic activity duration estimate',
#  'organizational procedure link',
#  'the work breakdown structure',
#  'the schedule management plan',
#  'project schedule model maintenance',
#  'the process use',
#  'the schedule model',
#  'monitor schedule performance',
#  'an agree upon amount',
#  'value management evm rule',
#  'other physical measurement rule',
#  'the schedule management plan',
#  'u n rule',
#  'establish percent complete',
#  'u n evm technique e.g.',
#  'more speci c information',
#  'the practice standard',
#  'earn value management',
#  'u n schedule performance measurement such',
#  'schedule variance sv',
#  'schedule performance index spi use',
#  'the original schedule baseline',
#  'the various schedule report',
#  'de ne activity',
#  'the project deliverable',
#  'the key benefit',
#  'the project work',
#  'enterprise environmental factor',
#  'uence the de ne activity process',
#  'publish commercial information',
#  'project management information system pmis',
#  'the organizational process asset influence',
#  'the de ne activity process',
#  'repository contain historical information regard activity list use',
#  'previous similar project',
#  'a standard activity list',
#  'an activity list',
#  'a previous project',
#  'informal activity plan relate policy',
#  'the scheduling methodology',
#  'develop the activity',
#  'an iterative planning technique',
#  'which the work',
#  'the near term',
#  'a high level',
#  'progressive elaboration applicable',
#  'use an agile',
#  'early strategic planning',
#  'the know level',
#  'the upcoming event',
#  'the near term',
#  'subject matter expert',
#  'the activity list',
#  'the schedule activity',
#  'the activity list',
#  'the project progress',
#  'the activity list',
#  'an activity identi er',
#  'suf cient detail',
#  'project team member',
#  'identify multiple component associate',
#  'the initial stage',
#  'the unique activity identi',
#  'er i d',
#  'wbs i d',
#  'the plan schedule activity',
#  'a milestone list identi',
#  'all project milestone',
#  'the project management plan',
#  'the organization s change control process',
#  'a change request',
#  'a change request',
#  'the project management plan',
#  'the initial schedule baseline',
#  'other significant schedule milestone',
#  'the schedule baseline',
#  'the cost baseline',
#  'the project activity',
#  'the key benefit',
#  'ne the logical sequence',
#  'the great ef ciency',
#  'all project constraint',
#  'one successor activity',
#  'an appropriate logical relationship',
#  'a realistic project schedule',
#  'achievable project schedule',
#  'use project management software',
#  'the sequence activity process concentrate',
#  'convert the project activity',
#  'a rst step',
#  'the schedule baseline',
#  'a necessary sequence',
#  'the activity list',
#  'all schedule activity',
#  'uence the sequencing',
#  'the assumption log',
#  'the way activity',
#  'individual project risk',
#  'the project schedule',
#  'the milestone list',
#  'speci c milestone',
#  'uence the way activity',
#  'the enterprise environmental factor influence',
#  'the sequence activity process',
#  'project management information system pmis',
#  'organization work authorization system',
#  'the organizational process asset influence',
#  'the sequence activity process',
#  'informal activity plan relate policy',
#  'the scheduling methodology',
#  'develop logical relationship',
#  'relate activity attribute information',
#  'additional descriptive information useful',
#  'repository contain historical information',
#  'the sequencing process',
#  'the precedence diagram method pdm',
#  'a technique use',
#  'construct a schedule model',
#  'which the activity',
#  'a predecessor activity',
#  'a dependent activity',
#  'a successor activity',
#  'a dependent activity',
#  'a logical relationship',
#  'which a successor activity',
#  'a predecessor activity',
#  'the operating system',
#  'a pc successor',
#  'the pc hardware',
#  'a logical relationship',
#  'which a successor activity',
#  'a predecessor activity',
#  'a document predecessor',
#  'edit the document successor',
#  'a logical relationship',
#  'which a successor activity',
#  'a predecessor activity',
#  'level concrete successor',
#  'pour foundation predecessor begin',
#  'a logical relationship',
#  'which a successor activity',
#  'a predecessor activity',
#  'a new account payable system successor',
#  'the old account payable system',
#  'the sf relationship',
#  'a complete list',
#  'the pdm relationship type',
#  'two logical relationship',
#  'the same time',
#  'the same activity',
#  'the high impact',
#  'precedence diagram method pdm relationship type activity',
#  'a activity b activity',
#  'a activity b activity b activity',
#  'a activity b finish',
#  'the follow attribute',
#  'the same time',
#  'the follow way',
#  'mandatory external dependency',
#  'mandatory internal dependency',
#  'discretionary external dependency',
#  'discretionary internal dependency',
#  'involve physical limitation',
#  'a construction project',
#  'an electronic project',
#  'the project team determine',
#  'sequence the activity',
#  'assign schedule constraint',
#  'the scheduling tool',
#  'a particular application area',
#  'some unusual aspect',
#  'a speci c sequence',
#  'other acceptable sequence',
#  'the electrical work',
#  'nishe the plumbing work',
#  'the same time',
#  'the overall project risk',
#  'arbitrary total oat value',
#  'the project team determine',
#  'sequence the activity',
#  'non project activity',
#  'the project team',
#  'the testing activity',
#  'a software project',
#  'an external source',
#  'governmental environmental hearing',
#  'a construction project',
#  'the project management team determine',
#  'sequence the activity',
#  'a precedence relationship',
#  'the project team',
#  'an internal mandatory dependency',
#  'the project management team determine',
#  'sequence the activity',
#  'time a successor activity',
#  'a predecessor activity',
#  'the schedule punch list completion',
#  'a week lead',
#  'a negative value',
#  'lag complete punch list write draft landscape building lot edit draft ss day',
#  'time a successor activity',
#  'a predecessor activity',
#  'a technical writing team',
#  'a large document day',
#  'a day lag',
#  'project schedule network diagram',
#  'the nomenclature ss start',
#  'the project management team',
#  'the logical relationship',
#  'their relate assumption',
#  'project schedule network diagram',
#  'project management information system pmis describe',
#  'project management information system',
#  'the logical relationship',
#  'the different type',
#  'a b c d e',
#  'k l ff fs ss ss',
#  'a project schedule network diagram',
#  'a graphical representation',
#  'the logical relationship',
#  'the project schedule activity',
#  'a project schedule network diagram',
#  'a project schedule network diagram',
#  'use project management software',
#  'full project detail',
#  'a summary narrative',
#  'the basic approach use',
#  'any unusual activity sequence',
#  'multiple predecessor activity',
#  'a path convergence',
#  'multiple successor activity',
#  'a path divergence',
#  'a path convergence',
#  'a path divergence',
#  'a necessary sequence',
#  'the activity list',
#  'the project activity',
#  'the sequencing activity',
#  'the assumption log',
#  'individual project risk',
#  'the project schedule',
#  'the schedule date',
#  'speci c milestone',
#  'the project activity',
#  'the sequencing activity',
#  'estimate activity duration',
#  'estimate the number',
#  'the key benefit',
#  'time each activity',
#  'the activity list',
#  'all schedule activity',
#  'uence the duration estimate',
#  'the assumption log',
#  'individual project risk',
#  'the project schedule',
#  'lesson learn register',
#  'the milestone list',
#  'speci c milestone',
#  'the duration estimate',
#  'project team assignment',
#  'the appropriate people',
#  'resource breakdown structure',
#  'the resource breakdown structure',
#  'a hierarchical structure',
#  'the identi ed resource',
#  'the resource calendar',
#  'uence the duration',
#  'schedule activity due',
#  'speci c resource',
#  'speci c attribute',
#  'resource calendar specify',
#  'long identi ed project resource',
#  'the estimate activity resource requirement',
#  'which the resource assign',
#  'uence the duration',
#  'low skilled resource',
#  'a long duration estimate',
#  'individual project risk',
#  'the risk register',
#  'project document update',
#  'plan risk response',
#  'the enterprise environmental factor influence',
#  'the estimate activity duration process',
#  'duration estimate database',
#  'other reference datum',
#  'publish commercial information',
#  'the organizational process asset influence',
#  'the estimate activity duration process',
#  'historical duration information',
#  'estimate the duration',
#  'a project use historical datum',
#  'a similar activity',
#  'analogous estimating use parameter',
#  'estimate the same parameter',
#  'a future project',
#  'a gross value',
#  'a limited amount',
#  'less time consume',
#  'analogous duration estimate',
#  'a total project',
#  'other estimating method',
#  'the previous activity',
#  'the project team member',
#  'the need expertise',
#  'an estimating technique',
#  'which an algorithm',
#  'parametric estimating use',
#  'a statistical relationship',
#  'other variable e.g.',
#  'a design project',
#  'a cable installation',
#  'the assign resource',
#  'the duration require',
#  'underlie datum build',
#  'parametric schedule estimate',
#  'a total project',
#  'other estimating method',
#  'single point duration estimate',
#  'consider estimation uncertainty',
#  'use three point estimate help',
#  'ne an approximate range',
#  'an activity s duration',
#  'most likely tm',
#  'the resource likely',
#  'the activity duration base',
#  'the good case scenario',
#  'the duration base',
#  'the bad case scenario',
#  'the assumed distribution',
#  'the three estimate',
#  'the expect duration',
#  'insuf cient historical datum',
#  'use judgmental datum',
#  'duration estimate base',
#  'an assumed distribution',
#  'an expect duration',
#  'the expect duration',
#  'estimate project duration',
#  'the low level component',
#  'the detail duration',
#  'a total quantity',
#  'the activity s duration',
#  'the estimate requirement',
#  'datum analysis technique',
#  'compression technique describe',
#  'different tool manual versus',
#  'an optimal approach',
#  'accomplish project work',
#  'management reserve need',
#  'the estimate duration',
#  'the schedule baseline',
#  'identi ed risk',
#  'the know unknown',
#  'this unknown amount',
#  'the contingency reserve',
#  'the estimate activity duration',
#  'a xed number',
#  'the individual activity',
#  'more precise information',
#  'the project become available',
#  'the contingency reserve',
#  'the schedule documentation',
#  'a speci ed amount',
#  'the project budget withhold',
#  'management control purpose',
#  'the unknown unknown',
#  'the schedule baseline',
#  'the overall project duration requirement',
#  'the schedule baseline',
#  'the project team',
#  'low level task',
#  'the duration iteration',
#  'the rst day',
#  'the product owner',
#  'the scrum team',
#  'the project manager',
#  'an iteration backlog',
#  'the likely number',
#  'assume a day work week',
#  'a high probability',
#  'additional detail support',
#  'the duration estimate vary',
#  'the estimate i.e.',
#  'any know constraint',
#  'possible estimate e.g.',
#  'the con dence level',
#  'the nal estimate',
#  'individual project risk',
#  'uence this estimate',
#  'activity duration estimate produce',
#  'the activity attribute',
#  'develop the duration estimate',
#  'resource skill level',
#  'lesson learn register',
#  'analyze activity sequence',
#  'a schedule model',
#  'the key benefit',
#  'a schedule model',
#  'complete project activity',
#  'an acceptable project schedule',
#  'an iterative process',
#  'the schedule model',
#  'the well available information',
#  'an approve project schedule',
#  'ne the project milestone',
#  'the staff con rm',
#  'nish date present',
#  'no con ict',
#  'the project schedule model',
#  'a realistic schedule',
#  'more speci c information regard scheduling',
#  'the practice standard',
#  'the activity attribute',
#  'the detail use',
#  'the schedule model',
#  'the activity list identi',
#  'the schedule model',
#  'the assumption log',
#  'individual project risk',
#  'the project schedule',
#  'additional detail support',
#  'the duration estimate vary',
#  'the duration estimate',
#  'the quantitative assessment',
#  'the likely number',
#  'the schedule model',
#  'the schedule model',
#  'the milestone list',
#  'speci c milestone',
#  'project schedule network diagram',
#  'the project schedule network diagram',
#  'the logical relationship',
#  'project team assignment',
#  'the project team assignment specify',
#  'the resource calendar contain information',
#  'the activity resource requirement',
#  'the schedule model',
#  'the risk register',
#  'all identi ed risk',
#  'the schedule model',
#  'risk information relevant',
#  'mean risk impact',
#  'the enterprise environmental factor influence',
#  'the develop schedule process include',
#  'the organizational process asset influence',
#  'the develop schedule process',
#  'the policy govern schedule model development',
#  'project calendar s',
#  'schedule network analysis',
#  'the overarching technique use',
#  'the project schedule model',
#  'several other technique such',
#  'critical path method describe',
#  'resource optimization technique describe',
#  'model technique describe',
#  'a schedule slip',
#  'multiple path converge',
#  'a single point',
#  'multiple path diverge',
#  'a single point',
#  'a schedule slip',
#  'the critical path',
#  'high risk activity',
#  'long lead item',
#  'the critical path',
#  'schedule network analysis',
#  'an iterative process',
#  'a viable schedule model',
#  'the critical path method',
#  'the minimum project duration',
#  'the logical network path',
#  'the schedule model',
#  'this schedule network analysis technique',
#  'the early start',
#  'late nish date',
#  'any resource limitation',
#  'perform a forward',
#  'backward pass analysis',
#  'the schedule network',
#  'the long path',
#  'a c d',
#  'the critical path',
#  'the critical path',
#  'the long path',
#  ...]

# %%
from collections import Counter

counter = Counter(noun)
sorted_counter_noun = counter.most_common()
sorted_counter_noun
# Out:
# [('the cost baseline', 24),
#  ('the project management plan', 19),
#  ('the project schedule', 17),
#  ('the organizational process asset influence', 15),
#  ('the key benefit', 14),
#  ('a change request', 14),
#  ('the schedule baseline', 13),
#  ('the schedule model', 12),
#  ('the enterprise environmental factor influence', 11),
#  ('the Scope baseline', 10),
#  ('the risk register', 10),
#  ('the project team', 10),
#  ('the critical path', 10),
#  ('the performance measurement baseline', 9),
#  ('the Scope management plan', 8),
#  ('the project manager', 8),
#  ('the assumption log', 8),
#  ('a realistic basis', 8),
#  ('the schedule management plan', 8),
#  ('individual project risk', 8),
#  ('a predecessor activity', 7),
#  ('the cost management plan', 7),
#  ('the estimate cost process', 7),
#  ('the actual cost', 7),
#  ('the requirement traceability matrix', 6),
#  ('the project Scope statement', 6),
#  ('each work package', 6),
#  ('datum analysis technique', 6),
#  ('the activity list', 6),
#  ('a schedule model', 6),
#  ('a give point', 6),
#  ('a data analysis technique', 5),
#  ('lesson learn register', 5),
#  ('a technique use', 5),
#  ('the project Scope', 5),
#  ('requirement traceability matrix', 5),
#  ('the practice standard', 5),
#  ('the wbs dictionary', 5),
#  ('the organization s change control process', 5),
#  ('the logical relationship', 5),
#  ('the duration estimate', 5),
#  ('the plan value', 5),
#  ('the datum date', 5),
#  ('the project charter', 4),
#  ('the low level', 4),
#  ('a work package', 4),
#  ('the create wbs process', 4),
#  ('a control account', 4),
#  ('the earn value', 4),
#  ('the actual result', 4),
#  ('the project schedule model', 4),
#  ('the project progress', 4),
#  ('speci c milestone', 4),
#  ('a logical relationship', 4),
#  ('which a successor activity', 4),
#  ('sequence the activity', 4),
#  ('project schedule network diagram', 4),
#  ('project management information system pmis describe', 4),
#  ('project management information system', 4),
#  ('identi ed risk', 4),
#  ('the contingency reserve', 4),
#  ('schedule compression technique', 4),
#  ('component work package', 4),
#  ('the remain work', 4),
#  ('the project budget', 4),
#  ('organization s culture', 3),
#  ('the project sponsor', 3),
#  ('select project team member', 3),
#  ('the collect requirement process', 3),
#  ('subject matter expert', 3),
#  ('a high level', 3),
#  ('the project life cycle', 3),
#  ('the project management team', 3),
#  ('project Scope statement', 3),
#  ('the project objective', 3),
#  ('this process include', 3),
#  ('the work package', 3),
#  ('the full project Scope', 3),
#  ('any specific project', 3),
#  ('the only way', 3),
#  ('the approve version', 3),
#  ('formal change control procedure', 3),
#  ('the control account', 3),
#  ('monitor the status', 3),
#  ('trend analysis examine project performance', 3),
#  ('a revise cost baseline', 3),
#  ('performance measurement baseline', 3),
#  ('the performance variance', 3),
#  ('the scheduling methodology', 3),
#  ('schedule variance sv', 3),
#  ('publish commercial information', 3),
#  ('the project activity', 3),
#  ('the milestone list', 3),
#  ('the same time', 3),
#  ('a project schedule network diagram', 3),
#  ('additional detail support', 3),
#  ('the long path', 3),
#  ('user story feature', 3),
#  ('the resource requirement', 3),
#  ('earn value analysis', 3),
#  ('the cost estimate', 3),
#  ('the determine budget process', 3),
#  ('the work complete', 3),
#  ('u m eac forecast', 3),
#  ('the work plan', 3),
#  ('the plan Scope management process', 2),
#  ('the detailed project Scope statement', 2),
#  ('the complete project deliverable', 2),
#  ('the requirement management plan', 2),
#  ('a practice guide', 2),
#  ('the product Scope', 2),
#  ('an assessment process', 2),
#  ('an expect outcome', 2),
#  ('the business system', 2),
#  ('the nal product', 2),
#  ('the business need', 2),
#  ('the requirement documentation', 2),
#  ('a unique identi er', 2),
#  ('the de ne Scope process include', 2),
#  ('be identi ed', 2),
#  ('a hierarchical decomposition', 2),
#  ('the total Scope', 2),
#  ('the require deliverable', 2),
#  ('the second level', 2),
#  ('a particular application area', 2),
#  ('the project work', 2),
#  ('u n description', 2),
#  ('the control quality process', 2),
#  ('work performance information', 2),
#  ('the perform integrate change control process', 2),
#  ('work performance datum', 2),
#  ('the control Scope process include', 2),
#  ('the plan schedule management process', 2),
#  ('the scheduling tool', 2),
#  ('organizational procedure link', 2),
#  ('the work breakdown structure', 2),
#  ('an agree upon amount', 2),
#  ('value management evm rule', 2),
#  ('the original schedule baseline', 2),
#  ('project management information system pmis', 2),
#  ('informal activity plan relate policy', 2),
#  ('the near term', 2),
#  ('the schedule activity', 2),
#  ('use project management software', 2),
#  ('a necessary sequence', 2),
#  ('all schedule activity', 2),
#  ('the sequence activity process', 2),
#  ('which the activity', 2),
#  ('a dependent activity', 2),
#  ('a construction project', 2),
#  ('the project team determine', 2),
#  ('the project management team determine', 2),
#  ('time a successor activity', 2),
#  ('a technical writing team', 2),
#  ('a path convergence', 2),
#  ('a path divergence', 2),
#  ('the sequencing activity', 2),
#  ('project team assignment', 2),
#  ('uence the duration', 2),
#  ('the estimate activity duration process', 2),
#  ('a total project', 2),
#  ('other estimating method', 2),
#  ('the expect duration', 2),
#  ('the activity s duration', 2),
#  ('this unknown amount', 2),
#  ('a xed number', 2),
#  ('more precise information', 2),
#  ('the project become available', 2),
#  ('the project budget withhold', 2),
#  ('management control purpose', 2),
#  ('the unknown unknown', 2),
#  ('the product owner', 2),
#  ('the likely number', 2),
#  ('the duration estimate vary', 2),
#  ('the estimate i.e.', 2),
#  ('any know constraint', 2),
#  ('possible estimate e.g.', 2),
#  ('the con dence level', 2),
#  ('the nal estimate', 2),
#  ('the activity attribute', 2),
#  ('an iterative process', 2),
#  ('the project schedule network diagram', 2),
#  ('the develop schedule process', 2),
#  ('schedule network analysis', 2),
#  ('a schedule slip', 2),
#  ('a single point', 2),
#  ('the critical path method', 2),
#  ('the logical network path', 2),
#  ('the critical path s', 2),
#  ('the total oat', 2),
#  ('a schedule constraint', 2),
#  ('positive total oat', 2),
#  ('hrs activity b sue', 2),
#  ('the schedule duration', 2),
#  ('agile release planning', 2),
#  ('a time scale', 2),
#  ('new product z period calendar unit calendar unit calendar unit complete component complete component finish new product z activity description project schedule time frame period period period period activity identifier',
#   2),
#  ('.m project schedule time frame period period period period activity identifier',
#   2),
#  ('new product z period work package', 2),
#  ('milestone schedule datum date datum date detailed schedule', 2),
#  ('.t datum date ss fs', 2),
#  ('component design component', 2),
#  ('component test component complete component work package', 2),
#  ('one project calendar', 2),
#  ('different work period', 2),
#  ('schedule management plan', 2),
#  ('develop the schedule model', 2),
#  ('the resource leveling analysis', 2),
#  ('the control schedule process', 2),
#  ('graphical analysis technique', 2),
#  ('future performance goal', 2),
#  ('currency exchange rate', 2),
#  ('resource cost rate information', 2),
#  ('that track skill', 2),
#  ('human resource cost', 2),
#  ('publish seller price list', 2),
#  ('the project cost', 2),
#  ('u n procedure', 2),
#  ('a cost estimate', 2),
#  ('special category such', 2),
#  ('the activity level', 2),
#  ('large scale project', 2),
#  ('the entire project', 2),
#  ('the work package cost estimate', 2),
#  ('the management reserve', 2),
#  ('both the cost', 2),
#  ('the approve cost baseline', 2),
#  ('project cost control', 2),
#  ('work perform express', 2),
#  ('the budget authorize', 2),
#  ('the ev measure', 2),
#  ('the realize cost incur', 2),
#  ('the work perform', 2),
#  ('accomplish the work', 2),
#  ('which the project', 2),
#  ('the plan delivery date', 2),
#  ('the earn value ev', 2),
#  ('the eva schedule variance', 2),
#  ('the cost performance index cpi', 2),
#  ('the cost ef ciency', 2),
#  ('no long viable', 2),
#  ('the forecasted eac', 2),
#  ('etc work perform', 2),
#  ('the budget rate', 2),
#  ('the etc work', 2),
#  ('performance index tcpi', 2),
#  ('the cost performance', 2),
#  ('the remain resource', 2),
#  ('a speci ed management goal', 2),
#  ('the outstanding work', 2),
#  ('the same point', 2),
#  ('the budget amount', 2),
#  ('plan cost neutral', 2),
#  ('plan cost negative', 2),
#  ('plan cost great', 2),
#  ('plan Scope management', 1),
#  ('create a Scope management plan', 1),
#  ('program management plan', 1),
#  ('the project Scope begin', 1),
#  ('the late approve subsidiary plan', 1),
#  ('historical information contain', 1),
#  ('the organizational process asset', 1),
#  ('any other relevant enterprise environmental factor', 1),
#  ('the Scope management process', 1),
#  ('a Scope management plan', 1),
#  ('prepare a project Scope statement', 1),
#  ('a business analysis plan', 1),
#  ('guration management activity such', 1),
#  ('the authorization level require', 1),
#  ('requirement prioritization process', 1),
#  ('the requirement attribute capture', 1),
#  ('the traceability matrix', 1),
#  ('manage stakeholder need', 1),
#  ('the pmbok guide', 1),
#  ('address product requirement', 1),
#  ('industry speci c. note', 1),
#  ('active stakeholder involvement', 1),
#  ('the care take', 1),
#  ('impose speci cation', 1),
#  ('the quanti ed', 1),
#  ('these requirement need', 1),
#  ('project execution begin', 1),
#  ('the assumption log identi ed assumption', 1),
#  ('other factor influence requirement', 1),
#  ('effective requirement collection technique', 1),
#  ('adaptive product development methodology', 1),
#  ('the stakeholder register', 1),
#  ('datum gathering technique', 1),
#  ('multiple idea relate', 1),
#  ('record the response', 1),
#  ('an individual basis', 1),
#  ('the desire product deliverable', 1),
#  ('obtain con dential information', 1),
#  ('prequali ed stakeholder', 1),
#  ('a propose product', 1),
#  ('a train moderator', 1),
#  ('an interactive discussion design', 1),
#  ('a large number', 1),
#  ('a quick turnaround', 1),
#  ('the organization compare', 1),
#  ('a collective decision making technique', 1),
#  ('u n unanimity', 1),
#  ('a single course', 1),
#  ('u n majority', 1),
#  ('a group size', 1),
#  ('an uneven number', 1),
#  ('u n plurality', 1),
#  ('the large block', 1),
#  ('a group decide', 1),
#  ('autocratic decision making', 1),
#  ('one individual take responsibility', 1),
#  ('multicriteria decision analysis', 1),
#  ('a decision matrix', 1),
#  ('a systematic analytical approach', 1),
#  ('datum representation technique', 1),
#  ('af nity diagram', 1),
#  ('mind mapping consolidate idea create', 1),
#  ('individual brainstorming session', 1),
#  ('a single map', 1),
#  ('the context diagram', 1),
#  ('a Scope model', 1),
#  ('show a business system process', 1),
#  ('context diagram show input', 1),
#  ('context diagram hire manager internal associate internal full time', 1),
#  ('part time contractor recruit agency job seeker', 1),
#  ('talent management system', 1),
#  ('abc company external job website external user internal user external user internal user internal user internal datum flow external user',
#   1),
#  ('external datum flow external job', 1),
#  ('external user profile internal job', 1),
#  ('internal user profile', 1),
#  ('obtain early feedback', 1),
#  ('provide a model', 1),
#  ('the expect product', 1),
#  ('small scale product', 1),
#  ('computer generate d', 1),
#  ('prototype allow stakeholder', 1),
#  ('a prototyping technique show sequence', 1),
#  ('storyboard use mock', 1),
#  ('show navigation path', 1),
#  ('other user interface', 1),
#  ('the requirement document', 1),
#  ('a simple document list all', 1),
#  ('the requirement categorize', 1),
#  ('an executive summary', 1),
#  ('the former refer', 1),
#  ('further re nement', 1),
#  ('these classi cation include', 1),
#  ('the high level need', 1),
#  ('the business issue', 1),
#  ('these describe feature', 1),
#  ('u n functional requirement', 1),
#  ('u n nonfunctional requirement', 1),
#  ('nonfunctional requirement supplement functional requirement', 1),
#  ('the environmental condition', 1),
#  ('these describe temporary capability', 1),
#  ('the desire future state', 1),
#  ('the project need', 1),
#  ('the successful completion', 1),
#  ('a project deliverable', 1),
#  ('other project requirement', 1),
#  ('a requirement traceability matrix help', 1),
#  ('each requirement add business value', 1),
#  ('high level requirement', 1),
#  ('more detailed requirement', 1),
#  ('these attribute help', 1),
#  ('ne key information', 1),
#  ('typical attribute use', 1),
#  ('a textual description', 1),
#  ('current status such', 1),
#  ('a requirement traceability matrix', 1),
#  ('its associate attribute', 1),
#  ('a requirement traceability matrix requirement traceability matrix requirement description',
#   1),
#  ('i d business need', 1),
#  ('objective project objective associate', 1),
#  ('wb deliverable product design product development test case program portfolio project name',
#   1),
#  ('develop a detailed description', 1),
#  ('the assumption log identi es assumption', 1),
#  ('other factor influence', 1),
#  ('requirement documentation identi es requirement', 1),
#  ('a project Scope statement', 1),
#  ('the objective identi ed', 1),
#  ('other relevant aspect', 1),
#  ('each application area', 1),
#  ('translate high level product', 1),
#  ('product analysis technique', 1),
#  ('the entire Scope', 1),
#  ('a common understanding', 1),
#  ('explicit scope exclusion', 1),
#  ('manage stakeholder expectation', 1),
#  ('more detailed planning', 1),
#  ('the project team s work', 1),
#  ('which the project Scope statement', 1),
#  ('ne the work', 1),
#  ('the overall project Scope', 1),
#  ('product Scope description', 1),
#  ('project management report', 1),
#  ('a summary level', 1),
#  ('contain a certain degree', 1),
#  ('high level information', 1),
#  ('the project Scope statement contain', 1),
#  ('a detailed description', 1),
#  ('the Scope component', 1),
#  ('the key element', 1),
#  ('project charter project purpose measurable project objective', 1),
#  ('related success criterion high level requirement high level project description',
#   1),
#  ('key deliverable overall project risk', 1),
#  ('financial resource key stakeholder list project approval requirement i.e.',
#   1),
#  ('what constitute success', 1),
#  ('the project project exit criterion i.e.', 1),
#  ('phase assign project manager', 1),
#  ('authority level name', 1),
#  ('other person s', 1),
#  ('the project charter project Scope statement project Scope description', 1),
#  ('elaborate project deliverable acceptance criterion project exclusion table',
#   1),
#  ('the wbs organize', 1),
#  ('ne the total Scope', 1),
#  ('the work speci ed', 1),
#  ('the current approve project Scope statement', 1),
#  ('the plan work', 1),
#  ('call work package', 1),
#  ('group the activity', 1),
#  ('be the result', 1),
#  ('a project management plan component include', 1),
#  ('industry speci c wbs standard', 1),
#  ('external reference source', 1),
#  ('create the wbs', 1),
#  ('the work define', 1),
#  ('the total project work', 1),
#  ('the follow activity', 1),
#  ('the upper wbs level', 1),
#  ('low level detailed component', 1),
#  ('identi cation code', 1),
#  ('the wbs component', 1),
#  ('the work package level', 1),
#  ('value management system project', 1),
#  ('system requirement development', 1),
#  ('current system audit', 1),
#  ('requirement change identification', 1),
#  ('a wbs structure', 1),
#  ('the popular method', 1),
#  ('organization speci c guideline', 1),
#  ('the wbs structure', 1),
#  ('project deliverable insert', 1),
#  ('the third level', 1),
#  ('use major deliverable', 1),
#  ('the support contract wb', 1),
#  ('the contract work', 1),
#  ('phase planning software product release', 1),
#  ('detail design construct integration', 1),
#  ('test project management product requirement software software software software',
#   1),
#  ('user documentation user documentation', 1),
#  ('user documentation user documentation administration', 1),
#  ('program material training program material training program material training program material',
#   1),
#  ('system engineering management support pm activity aircraft system project management equipment',
#   1),
#  ('facility training service', 1),
#  ('technical order engineering data management data datum air vehicle organizational level se intermediate level se depot level se support equipment airframe engine communication system navigation system fire control system base building maintenance facility facility',
#   1),
#  ('operational test developmental test test test', 1),
#  ('evaluation the wbs', 1),
#  ('major deliverable decomposition', 1),
#  ('the upper level', 1),
#  ('wbs component require', 1),
#  ('its most fundamental component', 1),
#  ('the wbs component represent veri able product', 1),
#  ('an agile approach', 1),
#  ('an organizational chart', 1),
#  ('a hierarchical breakdown', 1),
#  ('the low level wbs component', 1),
#  ('the correspond high level deliverable', 1),
#  ('some deliverable need', 1),
#  ('the next level', 1),
#  ('the wbs represent', 1),
#  ('the project management work', 1),
#  ('the high level', 1),
#  ('no extra work', 1),
#  ('the percent rule', 1),
#  ('speci c information', 1),
#  ('work breakdown structure second edition', 1),
#  ('this standard contain industry', 1),
#  ('a Scope statement', 1),
#  ('its associate wb dictionary', 1),
#  ('the Scope baseline include', 1),
#  ('detailed de nition', 1),
#  ('these identi er', 1),
#  ('a management control point', 1),
#  ('a single control account', 1),
#  ('a planning package', 1),
#  ('a work breakdown structure component', 1),
#  ('know work content', 1),
#  ('detailed schedule activity', 1),
#  ('a later stage', 1),
#  ('u n code', 1),
#  ('account identi er', 1),
#  ('u n assumption', 1),
#  ('u n responsible organization', 1),
#  ('u n schedule milestone', 1),
#  ('u n associate schedule activity', 1),
#  ('u n resource require', 1),
#  ('u n cost estimate', 1),
#  ('u n quality requirement', 1),
#  ('u n acceptance criterion', 1),
#  ('u n agreement information', 1),
#  ('u n assumption log', 1),
#  ('u n requirement documentation', 1),
#  ('it bring objectivity', 1),
#  ('the acceptance process', 1),
#  ('validate each deliverable', 1),
#  ('the ef ciency', 1),
#  ('the information present', 1),
#  ('the quality report', 1),
#  ('all quality assurance issue manage', 1),
#  ('the requirement traceability matrix contain information', 1),
#  ('the acceptance criterion', 1),
#  ('formal documentation receive', 1),
#  ('formal stakeholder acceptance', 1),
#  ('the close project', 1),
#  ('the complete deliverable', 1),
#  ('the change request describe', 1),
#  ('the method use', 1),
#  ('the requirement traceability matrix help', 1),
#  ('change request receive', 1),
#  ('deliverable veri ed', 1),
#  ('control related policy', 1),
#  ('the threshold amount', 1),
#  ('project Scope control', 1),
#  ('the change receive', 1),
#  ('the identi ed Scope variance', 1),
#  ('the future Scope performance', 1),
#  ('scope management plan', 1),
#  ('a revise Scope baseline', 1),
#  ('a revise schedule baseline', 1),
#  ('corrective action choose', 1),
#  ('team resource availability', 1),
#  ('physical resource availability', 1),
#  ('tailor the organization s set', 1),
#  ('standardized estimate datum', 1),
#  ('informal schedule development', 1),
#  ('which schedule methodology', 1),
#  ('detailed the schedule need', 1),
#  ('roll wave planning', 1),
#  ('an appropriate balance', 1),
#  ('appropriate control threshold', 1),
#  ('project schedule model development', 1),
#  ('time box period', 1),
#  ('which the team work', 1),
#  ('time boxing help', 1),
#  ('essential feature rst', 1),
#  ('the acceptable range use', 1),
#  ('determine realistic activity duration estimate', 1),
#  ('project schedule model maintenance', 1),
#  ('the process use', 1),
#  ('monitor schedule performance', 1),
#  ('other physical measurement rule', 1),
#  ('u n rule', 1),
#  ('establish percent complete', 1),
#  ('u n evm technique e.g.', 1),
#  ('more speci c information', 1),
#  ('earn value management', 1),
#  ('u n schedule performance measurement such', 1),
#  ('schedule performance index spi use', 1),
#  ('the various schedule report', 1),
#  ('de ne activity', 1),
#  ('the project deliverable', 1),
#  ('enterprise environmental factor', 1),
#  ('uence the de ne activity process', 1),
#  ('the de ne activity process', 1),
#  ('repository contain historical information regard activity list use', 1),
#  ('previous similar project', 1),
#  ('a standard activity list', 1),
#  ('an activity list', 1),
#  ('a previous project', 1),
#  ('develop the activity', 1),
#  ('an iterative planning technique', 1),
#  ('which the work', 1),
#  ('progressive elaboration applicable', 1),
#  ('use an agile', 1),
#  ('early strategic planning', 1),
#  ('the know level', 1),
#  ('the upcoming event', 1),
#  ('an activity identi er', 1),
#  ('suf cient detail', 1),
#  ('project team member', 1),
#  ('identify multiple component associate', 1),
#  ('the initial stage', 1),
#  ('the unique activity identi', 1),
#  ('er i d', 1),
#  ('wbs i d', 1),
#  ('the plan schedule activity', 1),
#  ('a milestone list identi', 1),
#  ('all project milestone', 1),
#  ('the initial schedule baseline', 1),
#  ('other significant schedule milestone', 1),
#  ('ne the logical sequence', 1),
#  ('the great ef ciency', 1),
#  ('all project constraint', 1),
#  ('one successor activity', 1),
#  ('an appropriate logical relationship', 1),
#  ('a realistic project schedule', 1),
#  ('achievable project schedule', 1),
#  ('the sequence activity process concentrate', 1),
#  ('convert the project activity', 1),
#  ('a rst step', 1),
#  ('uence the sequencing', 1),
#  ('the way activity', 1),
#  ('uence the way activity', 1),
#  ('organization work authorization system', 1),
#  ('develop logical relationship', 1),
#  ('relate activity attribute information', 1),
#  ('additional descriptive information useful', 1),
#  ('repository contain historical information', 1),
#  ('the sequencing process', 1),
#  ('the precedence diagram method pdm', 1),
#  ('construct a schedule model', 1),
#  ('a successor activity', 1),
#  ('the operating system', 1),
#  ('a pc successor', 1),
#  ('the pc hardware', 1),
#  ('a document predecessor', 1),
#  ('edit the document successor', 1),
#  ('level concrete successor', 1),
#  ('pour foundation predecessor begin', 1),
#  ('a new account payable system successor', 1),
#  ('the old account payable system', 1),
#  ('the sf relationship', 1),
#  ('a complete list', 1),
#  ('the pdm relationship type', 1),
#  ('two logical relationship', 1),
#  ('the same activity', 1),
#  ('the high impact', 1),
#  ('precedence diagram method pdm relationship type activity', 1),
#  ('a activity b activity', 1),
#  ('a activity b activity b activity', 1),
#  ('a activity b finish', 1),
#  ('the follow attribute', 1),
#  ('the follow way', 1),
#  ('mandatory external dependency', 1),
#  ('mandatory internal dependency', 1),
#  ('discretionary external dependency', 1),
#  ('discretionary internal dependency', 1),
#  ('involve physical limitation', 1),
#  ('an electronic project', 1),
#  ('assign schedule constraint', 1),
#  ('some unusual aspect', 1),
#  ('a speci c sequence', 1),
#  ('other acceptable sequence', 1),
#  ('the electrical work', 1),
#  ('nishe the plumbing work', 1),
#  ('the overall project risk', 1),
#  ('arbitrary total oat value', 1),
#  ('non project activity', 1),
#  ('the testing activity', 1),
#  ('a software project', 1),
#  ('an external source', 1),
#  ('governmental environmental hearing', 1),
#  ('a precedence relationship', 1),
#  ('an internal mandatory dependency', 1),
#  ('the schedule punch list completion', 1),
#  ('a week lead', 1),
#  ('a negative value', 1),
#  ('lag complete punch list write draft landscape building lot edit draft ss day',
#   1),
#  ('a large document day', 1),
#  ('a day lag', 1),
#  ('the nomenclature ss start', 1),
#  ('their relate assumption', 1),
#  ('the different type', 1),
#  ('a b c d e', 1),
#  ('k l ff fs ss ss', 1),
#  ('a graphical representation', 1),
#  ('the project schedule activity', 1),
#  ('full project detail', 1),
#  ('a summary narrative', 1),
#  ('the basic approach use', 1),
#  ('any unusual activity sequence', 1),
#  ('multiple predecessor activity', 1),
#  ('multiple successor activity', 1),
#  ('the schedule date', 1),
#  ('estimate activity duration', 1),
#  ('estimate the number', 1),
#  ('time each activity', 1),
#  ('uence the duration estimate', 1),
#  ('the appropriate people', 1),
#  ('resource breakdown structure', 1),
#  ('the resource breakdown structure', 1),
#  ('a hierarchical structure', 1),
#  ('the identi ed resource', 1),
#  ('the resource calendar', 1),
#  ('schedule activity due', 1),
#  ('speci c resource', 1),
#  ('speci c attribute', 1),
#  ('resource calendar specify', 1),
#  ('long identi ed project resource', 1),
#  ('the estimate activity resource requirement', 1),
#  ('which the resource assign', 1),
#  ('low skilled resource', 1),
#  ('a long duration estimate', 1),
#  ('project document update', 1),
#  ('plan risk response', 1),
#  ('duration estimate database', 1),
#  ('other reference datum', 1),
#  ('historical duration information', 1),
#  ('estimate the duration', 1),
#  ('a project use historical datum', 1),
#  ('a similar activity', 1),
#  ('analogous estimating use parameter', 1),
#  ('estimate the same parameter', 1),
#  ('a future project', 1),
#  ('a gross value', 1),
#  ('a limited amount', 1),
#  ('less time consume', 1),
#  ('analogous duration estimate', 1),
#  ('the previous activity', 1),
#  ('the project team member', 1),
#  ('the need expertise', 1),
#  ('an estimating technique', 1),
#  ('which an algorithm', 1),
#  ('parametric estimating use', 1),
#  ('a statistical relationship', 1),
#  ('other variable e.g.', 1),
#  ('a design project', 1),
#  ('a cable installation', 1),
#  ('the assign resource', 1),
#  ('the duration require', 1),
#  ('underlie datum build', 1),
#  ('parametric schedule estimate', 1),
#  ('single point duration estimate', 1),
#  ('consider estimation uncertainty', 1),
#  ('use three point estimate help', 1),
#  ('ne an approximate range', 1),
#  ('an activity s duration', 1),
#  ('most likely tm', 1),
#  ('the resource likely', 1),
#  ('the activity duration base', 1),
#  ('the good case scenario', 1),
#  ('the duration base', 1),
#  ('the bad case scenario', 1),
#  ('the assumed distribution', 1),
#  ('the three estimate', 1),
#  ('insuf cient historical datum', 1),
#  ('use judgmental datum', 1),
#  ('duration estimate base', 1),
#  ('an assumed distribution', 1),
#  ('an expect duration', 1),
#  ('estimate project duration', 1),
#  ('the low level component', 1),
#  ('the detail duration', 1),
#  ('a total quantity', 1),
#  ('the estimate requirement', 1),
#  ('compression technique describe', 1),
#  ('different tool manual versus', 1),
#  ('an optimal approach', 1),
#  ('accomplish project work', 1),
#  ('management reserve need', 1),
#  ('the estimate duration', 1),
#  ('the know unknown', 1),
#  ('the estimate activity duration', 1),
#  ('the individual activity', 1),
#  ('the schedule documentation', 1),
#  ('a speci ed amount', 1),
#  ('the overall project duration requirement', 1),
#  ('low level task', 1),
#  ('the duration iteration', 1),
#  ('the rst day', 1),
#  ('the scrum team', 1),
#  ('an iteration backlog', 1),
#  ('assume a day work week', 1),
#  ('a high probability', 1),
#  ('uence this estimate', 1),
#  ('activity duration estimate produce', 1),
#  ('develop the duration estimate', 1),
#  ('resource skill level', 1),
#  ('analyze activity sequence', 1),
#  ('complete project activity', 1),
#  ('an acceptable project schedule', 1),
#  ('the well available information', 1),
#  ('an approve project schedule', 1),
#  ('ne the project milestone', 1),
#  ('the staff con rm', 1),
#  ('nish date present', 1),
#  ('no con ict', 1),
#  ('a realistic schedule', 1),
#  ('more speci c information regard scheduling', 1),
#  ('the detail use', 1),
#  ('the activity list identi', 1),
#  ('the quantitative assessment', 1),
#  ('the project team assignment specify', 1),
#  ('the resource calendar contain information', 1),
#  ('the activity resource requirement', 1),
#  ('all identi ed risk', 1),
#  ('risk information relevant', 1),
#  ('mean risk impact', 1),
#  ('the develop schedule process include', 1),
#  ('the policy govern schedule model development', 1),
#  ('project calendar s', 1),
#  ('the overarching technique use', 1),
#  ('several other technique such', 1),
#  ('critical path method describe', 1),
#  ('resource optimization technique describe', 1),
#  ('model technique describe', 1),
#  ('multiple path converge', 1),
#  ('multiple path diverge', 1),
#  ('high risk activity', 1),
#  ('long lead item', 1),
#  ('a viable schedule model', 1),
#  ('the minimum project duration', 1),
#  ('this schedule network analysis technique', 1),
#  ('the early start', 1),
#  ('late nish date', 1),
#  ('any resource limitation', 1),
#  ('perform a forward', 1),
#  ('backward pass analysis', 1),
#  ('the schedule network', 1),
#  ('a c d', 1),
#  ('the short possible project duration', 1),
#  ('the least total oat', 1),
#  ('the result early', 1),
#  ('the time period', 1),
#  ('the parameter enter', 1),
#  ('other know constraint', 1),
#  ('any network path', 1),
#  ('a schedule activity', 1),
#  ('its early start date', 1),
#  ('delay the project nish date', 1),
#  ('a critical path', 1),
#  ('zero total oat', 1),
#  ('the precedence diagram method sequence', 1),
#  ('negative total oat depend', 1),
#  ('the constraint apply', 1),
#  ('the backward pass', 1),
#  ('the early nish date', 1),
#  ('forward pass calculation', 1),
#  ('negative total oat', 1),
#  ('the late date', 1),
#  ('negative oat analysis', 1),
#  ('possible accelerate way', 1),
#  ('a delay schedule', 1),
#  ('many software package', 1),
#  ('the parameter use', 1),
#  ('other schedule constraint', 1),
#  ('example the free oat', 1),
#  ('critical path link', 1),
#  ('critical path link activity node start', 1),
#  ('a c b d activity', 1),
#  ('early start duration', 1),
#  ('finish late start total float', 1),
#  ('a b d path', 1),
#  ('a c d critical path key note', 1),
#  ('the accepted convention', 1),
#  ('the project start', 1),
#  ('critical path method', 1),
#  ('plan resource use', 1),
#  ('resource optimization technique', 1),
#  ('the schedule model due', 1),
#  ('balance the demand', 1),
#  ('the available supply', 1),
#  ('the same time period', 1),
#  ('a constant level', 1),
#  ('the original critical path', 1),
#  ('a schedule model such', 1),
#  ('certain predefine resource limit', 1),
#  ('the completion date', 1),
#  ('resource leveling start activity', 1),
#  ('hrs day day day', 1),
#  ('activity a tom', 1),
#  ('hrs day day day activity', 1),
#  ('resource leveling activity', 1),
#  ('the situation represent', 1),
#  ('a schedule network analysis', 1),
#  ('the different scenario', 1),
#  ('delay a major component delivery', 1),
#  ('speci c engineering duration', 1),
#  ('the permit process', 1),
#  ('prepare schedule reserve', 1),
#  ('the combine effect', 1),
#  ('their potential impact', 1),
#  ('achieve project objective', 1),
#  ('the most common simulation technique', 1),
#  ('monte carlo analysis see', 1),
#  ('possible schedule outcome', 1),
#  ('the total project', 1),
#  ('calculate multiple work package duration', 1),
#  ('scenario use probability distribution', 1),
#  ('a probability distribution', 1),
#  ('achieve a certain target date i.e.', 1),
#  ('project nish date', 1),
#  ('the target date', 1),
#  ('complete the project', 1),
#  ('project finish date', 1),
#  ('example probability distribution', 1),
#  ('a target milestone', 1),
#  ('monte carlo simulation', 1),
#  ('reduce the project Scope', 1),
#  ('other schedule objective', 1),
#  ('a helpful technique', 1),
#  ('the negative oat analysis', 1),
#  ('the least oat', 1),
#  ('the least incremental cost', 1),
#  ('a viable alternative', 1),
#  ('a schedule compression technique', 1),
#  ('the architectural drawing', 1),
#  ('increase coordination effort', 1),
#  ('the activity concern', 1),
#  ('increase quality risk', 1),
#  ('schedule compression comparison normal crash', 1),
#  ('high risk high cost', 1),
#  ('build a schedule model', 1),
#  ('nish date base', 1),
#  ('a high level summary timeline', 1),
#  ('the release schedule', 1),
#  ('the product roadmap', 1),
#  ('the product vision', 1),
#  ('the product s evolution', 1),
#  ('a releasable product base', 1),
#  ('feature represent value', 1),
#  ('information the customer', 1),
#  ('iteration planning release release release release plan iteration plan iteration iteration iteration iteration iteration n feature',
#   1),
#  ('a user story feature', 1),
#  ('a user story hour hour hour hour task', 1),
#  ('a task b task c task d product vision drive product roadmap product roadmap drive release plan',
#   1),
#  ('the iteration iteration plan schedule feature development task estimate',
#   1),
#  ('user story estimate', 1),
#  ('a schedule baseline', 1),
#  ('the appropriate stakeholder', 1),
#  ('baseline start date', 1),
#  ('baseline nish date', 1),
#  ('the approve baseline date', 1),
#  ('the actual start', 1),
#  ('that present link activity', 1),
#  ('a plan start date', 1),
#  ('plan nish date', 1),
#  ('an early stage', 1),
#  ('a target project schedule model', 1),
#  ('a define target start', 1),
#  ('the master schedule', 1),
#  ('a project schedule model', 1),
#  ('the follow format', 1),
#  ('comprehensive summary activity', 1),
#  ('multiple interdependent work package', 1),
#  ('bar chart report', 1),
#  ('the summary schedule portion', 1),
#  ('the schedule start', 1),
#  ('key external interface', 1),
#  ('the milestone schedule portion', 1),
#  ('node diagram format show activity', 1),
#  ('a pure logic diagram', 1),
#  ('a time scale schedule network diagram format', 1),
#  ('a logic bar chart', 1),
#  ('the detailed schedule', 1),
#  ('activity date information', 1),
#  ('both the project network logic', 1),
#  ('critical path schedule activity', 1),
#  ('a time scale logic diagram', 1),
#  ('the same line', 1),
#  ('figure show schedule presentation', 1),
#  ('a sample project', 1),
#  ('a simple project schedule model', 1),
#  ('figure re ect schedule presentation', 1),
#  ('a milestone schedule', 1),
#  ('a milestone chart', 1),
#  ('a summary schedule', 1),
#  ('a bar chart', 1),
#  ('a detailed schedule', 1),
#  ('a project schedule', 1),
#  ('bar chart diagram', 1),
#  ('the different level', 1),
#  ('project schedule time frame period period period period activity identifier',
#   1),
#  ('period activity description', 1),
#  ('new product z develop', 1),
#  ('product z work package', 1),
#  ('datum date ss fs', 1),
#  ('test integrate component', 1),
#  ('product z deliver product z finish new product z figure', 1),
#  ('project schedule presentation example', 1),
#  ('the schedule datum', 1),
#  ('the schedule data', 1),
#  ('the schedule milestone', 1),
#  ('all identi ed assumption', 1),
#  ('additional datum varie', 1),
#  ('a resource histogram', 1),
#  ('cash ow projection', 1),
#  ('other relevant information', 1),
#  ('a project calendar identi es working day', 1),
#  ('it distinguish time period', 1),
#  ('the project calendar', 1),
#  ('any revised resource requirement', 1),
#  ('any other revision generate', 1),
#  ('the activity dependency', 1),
#  ('schedule status review', 1),
#  ('the contractor report', 1),
#  ('the schedule forecast', 1),
#  ('project schedule refer', 1),
#  ('the most recent version', 1),
#  ('the indicate date', 1),
#  ('informal schedule control relate policy', 1),
#  ('schedule control tool', 1),
#  ('schedule performance measurement such', 1),
#  ('schedule performance index spi', 1),
#  ('the iteration backlog', 1),
#  ('an ideal burndown base', 1),
#  ('the work commit', 1),
#  ('iteration planning see', 1),
#  ('a forecast trend line', 1),
#  ...]

# %%
unique_noun = []
for item in sorted_counter_noun:
    unique_noun.append(item[0])

# %%
unique_noun
# Out:
# ['the cost baseline',
#  'the project management plan',
#  'the project schedule',
#  'the organizational process asset influence',
#  'the key benefit',
#  'a change request',
#  'the schedule baseline',
#  'the schedule model',
#  'the enterprise environmental factor influence',
#  'the Scope baseline',
#  'the risk register',
#  'the project team',
#  'the critical path',
#  'the performance measurement baseline',
#  'the Scope management plan',
#  'the project manager',
#  'the assumption log',
#  'a realistic basis',
#  'the schedule management plan',
#  'individual project risk',
#  'a predecessor activity',
#  'the cost management plan',
#  'the estimate cost process',
#  'the actual cost',
#  'the requirement traceability matrix',
#  'the project Scope statement',
#  'each work package',
#  'datum analysis technique',
#  'the activity list',
#  'a schedule model',
#  'a give point',
#  'a data analysis technique',
#  'lesson learn register',
#  'a technique use',
#  'the project Scope',
#  'requirement traceability matrix',
#  'the practice standard',
#  'the wbs dictionary',
#  'the organization s change control process',
#  'the logical relationship',
#  'the duration estimate',
#  'the plan value',
#  'the datum date',
#  'the project charter',
#  'the low level',
#  'a work package',
#  'the create wbs process',
#  'a control account',
#  'the earn value',
#  'the actual result',
#  'the project schedule model',
#  'the project progress',
#  'speci c milestone',
#  'a logical relationship',
#  'which a successor activity',
#  'sequence the activity',
#  'project schedule network diagram',
#  'project management information system pmis describe',
#  'project management information system',
#  'identi ed risk',
#  'the contingency reserve',
#  'schedule compression technique',
#  'component work package',
#  'the remain work',
#  'the project budget',
#  'organization s culture',
#  'the project sponsor',
#  'select project team member',
#  'the collect requirement process',
#  'subject matter expert',
#  'a high level',
#  'the project life cycle',
#  'the project management team',
#  'project Scope statement',
#  'the project objective',
#  'this process include',
#  'the work package',
#  'the full project Scope',
#  'any specific project',
#  'the only way',
#  'the approve version',
#  'formal change control procedure',
#  'the control account',
#  'monitor the status',
#  'trend analysis examine project performance',
#  'a revise cost baseline',
#  'performance measurement baseline',
#  'the performance variance',
#  'the scheduling methodology',
#  'schedule variance sv',
#  'publish commercial information',
#  'the project activity',
#  'the milestone list',
#  'the same time',
#  'a project schedule network diagram',
#  'additional detail support',
#  'the long path',
#  'user story feature',
#  'the resource requirement',
#  'earn value analysis',
#  'the cost estimate',
#  'the determine budget process',
#  'the work complete',
#  'u m eac forecast',
#  'the work plan',
#  'the plan Scope management process',
#  'the detailed project Scope statement',
#  'the complete project deliverable',
#  'the requirement management plan',
#  'a practice guide',
#  'the product Scope',
#  'an assessment process',
#  'an expect outcome',
#  'the business system',
#  'the nal product',
#  'the business need',
#  'the requirement documentation',
#  'a unique identi er',
#  'the de ne Scope process include',
#  'be identi ed',
#  'a hierarchical decomposition',
#  'the total Scope',
#  'the require deliverable',
#  'the second level',
#  'a particular application area',
#  'the project work',
#  'u n description',
#  'the control quality process',
#  'work performance information',
#  'the perform integrate change control process',
#  'work performance datum',
#  'the control Scope process include',
#  'the plan schedule management process',
#  'the scheduling tool',
#  'organizational procedure link',
#  'the work breakdown structure',
#  'an agree upon amount',
#  'value management evm rule',
#  'the original schedule baseline',
#  'project management information system pmis',
#  'informal activity plan relate policy',
#  'the near term',
#  'the schedule activity',
#  'use project management software',
#  'a necessary sequence',
#  'all schedule activity',
#  'the sequence activity process',
#  'which the activity',
#  'a dependent activity',
#  'a construction project',
#  'the project team determine',
#  'the project management team determine',
#  'time a successor activity',
#  'a technical writing team',
#  'a path convergence',
#  'a path divergence',
#  'the sequencing activity',
#  'project team assignment',
#  'uence the duration',
#  'the estimate activity duration process',
#  'a total project',
#  'other estimating method',
#  'the expect duration',
#  'the activity s duration',
#  'this unknown amount',
#  'a xed number',
#  'more precise information',
#  'the project become available',
#  'the project budget withhold',
#  'management control purpose',
#  'the unknown unknown',
#  'the product owner',
#  'the likely number',
#  'the duration estimate vary',
#  'the estimate i.e.',
#  'any know constraint',
#  'possible estimate e.g.',
#  'the con dence level',
#  'the nal estimate',
#  'the activity attribute',
#  'an iterative process',
#  'the project schedule network diagram',
#  'the develop schedule process',
#  'schedule network analysis',
#  'a schedule slip',
#  'a single point',
#  'the critical path method',
#  'the logical network path',
#  'the critical path s',
#  'the total oat',
#  'a schedule constraint',
#  'positive total oat',
#  'hrs activity b sue',
#  'the schedule duration',
#  'agile release planning',
#  'a time scale',
#  'new product z period calendar unit calendar unit calendar unit complete component complete component finish new product z activity description project schedule time frame period period period period activity identifier',
#  '.m project schedule time frame period period period period activity identifier',
#  'new product z period work package',
#  'milestone schedule datum date datum date detailed schedule',
#  '.t datum date ss fs',
#  'component design component',
#  'component test component complete component work package',
#  'one project calendar',
#  'different work period',
#  'schedule management plan',
#  'develop the schedule model',
#  'the resource leveling analysis',
#  'the control schedule process',
#  'graphical analysis technique',
#  'future performance goal',
#  'currency exchange rate',
#  'resource cost rate information',
#  'that track skill',
#  'human resource cost',
#  'publish seller price list',
#  'the project cost',
#  'u n procedure',
#  'a cost estimate',
#  'special category such',
#  'the activity level',
#  'large scale project',
#  'the entire project',
#  'the work package cost estimate',
#  'the management reserve',
#  'both the cost',
#  'the approve cost baseline',
#  'project cost control',
#  'work perform express',
#  'the budget authorize',
#  'the ev measure',
#  'the realize cost incur',
#  'the work perform',
#  'accomplish the work',
#  'which the project',
#  'the plan delivery date',
#  'the earn value ev',
#  'the eva schedule variance',
#  'the cost performance index cpi',
#  'the cost ef ciency',
#  'no long viable',
#  'the forecasted eac',
#  'etc work perform',
#  'the budget rate',
#  'the etc work',
#  'performance index tcpi',
#  'the cost performance',
#  'the remain resource',
#  'a speci ed management goal',
#  'the outstanding work',
#  'the same point',
#  'the budget amount',
#  'plan cost neutral',
#  'plan cost negative',
#  'plan cost great',
#  'plan Scope management',
#  'create a Scope management plan',
#  'program management plan',
#  'the project Scope begin',
#  'the late approve subsidiary plan',
#  'historical information contain',
#  'the organizational process asset',
#  'any other relevant enterprise environmental factor',
#  'the Scope management process',
#  'a Scope management plan',
#  'prepare a project Scope statement',
#  'a business analysis plan',
#  'guration management activity such',
#  'the authorization level require',
#  'requirement prioritization process',
#  'the requirement attribute capture',
#  'the traceability matrix',
#  'manage stakeholder need',
#  'the pmbok guide',
#  'address product requirement',
#  'industry speci c. note',
#  'active stakeholder involvement',
#  'the care take',
#  'impose speci cation',
#  'the quanti ed',
#  'these requirement need',
#  'project execution begin',
#  'the assumption log identi ed assumption',
#  'other factor influence requirement',
#  'effective requirement collection technique',
#  'adaptive product development methodology',
#  'the stakeholder register',
#  'datum gathering technique',
#  'multiple idea relate',
#  'record the response',
#  'an individual basis',
#  'the desire product deliverable',
#  'obtain con dential information',
#  'prequali ed stakeholder',
#  'a propose product',
#  'a train moderator',
#  'an interactive discussion design',
#  'a large number',
#  'a quick turnaround',
#  'the organization compare',
#  'a collective decision making technique',
#  'u n unanimity',
#  'a single course',
#  'u n majority',
#  'a group size',
#  'an uneven number',
#  'u n plurality',
#  'the large block',
#  'a group decide',
#  'autocratic decision making',
#  'one individual take responsibility',
#  'multicriteria decision analysis',
#  'a decision matrix',
#  'a systematic analytical approach',
#  'datum representation technique',
#  'af nity diagram',
#  'mind mapping consolidate idea create',
#  'individual brainstorming session',
#  'a single map',
#  'the context diagram',
#  'a Scope model',
#  'show a business system process',
#  'context diagram show input',
#  'context diagram hire manager internal associate internal full time',
#  'part time contractor recruit agency job seeker',
#  'talent management system',
#  'abc company external job website external user internal user external user internal user internal user internal datum flow external user',
#  'external datum flow external job',
#  'external user profile internal job',
#  'internal user profile',
#  'obtain early feedback',
#  'provide a model',
#  'the expect product',
#  'small scale product',
#  'computer generate d',
#  'prototype allow stakeholder',
#  'a prototyping technique show sequence',
#  'storyboard use mock',
#  'show navigation path',
#  'other user interface',
#  'the requirement document',
#  'a simple document list all',
#  'the requirement categorize',
#  'an executive summary',
#  'the former refer',
#  'further re nement',
#  'these classi cation include',
#  'the high level need',
#  'the business issue',
#  'these describe feature',
#  'u n functional requirement',
#  'u n nonfunctional requirement',
#  'nonfunctional requirement supplement functional requirement',
#  'the environmental condition',
#  'these describe temporary capability',
#  'the desire future state',
#  'the project need',
#  'the successful completion',
#  'a project deliverable',
#  'other project requirement',
#  'a requirement traceability matrix help',
#  'each requirement add business value',
#  'high level requirement',
#  'more detailed requirement',
#  'these attribute help',
#  'ne key information',
#  'typical attribute use',
#  'a textual description',
#  'current status such',
#  'a requirement traceability matrix',
#  'its associate attribute',
#  'a requirement traceability matrix requirement traceability matrix requirement description',
#  'i d business need',
#  'objective project objective associate',
#  'wb deliverable product design product development test case program portfolio project name',
#  'develop a detailed description',
#  'the assumption log identi es assumption',
#  'other factor influence',
#  'requirement documentation identi es requirement',
#  'a project Scope statement',
#  'the objective identi ed',
#  'other relevant aspect',
#  'each application area',
#  'translate high level product',
#  'product analysis technique',
#  'the entire Scope',
#  'a common understanding',
#  'explicit scope exclusion',
#  'manage stakeholder expectation',
#  'more detailed planning',
#  'the project team s work',
#  'which the project Scope statement',
#  'ne the work',
#  'the overall project Scope',
#  'product Scope description',
#  'project management report',
#  'a summary level',
#  'contain a certain degree',
#  'high level information',
#  'the project Scope statement contain',
#  'a detailed description',
#  'the Scope component',
#  'the key element',
#  'project charter project purpose measurable project objective',
#  'related success criterion high level requirement high level project description',
#  'key deliverable overall project risk',
#  'financial resource key stakeholder list project approval requirement i.e.',
#  'what constitute success',
#  'the project project exit criterion i.e.',
#  'phase assign project manager',
#  'authority level name',
#  'other person s',
#  'the project charter project Scope statement project Scope description',
#  'elaborate project deliverable acceptance criterion project exclusion table',
#  'the wbs organize',
#  'ne the total Scope',
#  'the work speci ed',
#  'the current approve project Scope statement',
#  'the plan work',
#  'call work package',
#  'group the activity',
#  'be the result',
#  'a project management plan component include',
#  'industry speci c wbs standard',
#  'external reference source',
#  'create the wbs',
#  'the work define',
#  'the total project work',
#  'the follow activity',
#  'the upper wbs level',
#  'low level detailed component',
#  'identi cation code',
#  'the wbs component',
#  'the work package level',
#  'value management system project',
#  'system requirement development',
#  'current system audit',
#  'requirement change identification',
#  'a wbs structure',
#  'the popular method',
#  'organization speci c guideline',
#  'the wbs structure',
#  'project deliverable insert',
#  'the third level',
#  'use major deliverable',
#  'the support contract wb',
#  'the contract work',
#  'phase planning software product release',
#  'detail design construct integration',
#  'test project management product requirement software software software software',
#  'user documentation user documentation',
#  'user documentation user documentation administration',
#  'program material training program material training program material training program material',
#  'system engineering management support pm activity aircraft system project management equipment',
#  'facility training service',
#  'technical order engineering data management data datum air vehicle organizational level se intermediate level se depot level se support equipment airframe engine communication system navigation system fire control system base building maintenance facility facility',
#  'operational test developmental test test test',
#  'evaluation the wbs',
#  'major deliverable decomposition',
#  'the upper level',
#  'wbs component require',
#  'its most fundamental component',
#  'the wbs component represent veri able product',
#  'an agile approach',
#  'an organizational chart',
#  'a hierarchical breakdown',
#  'the low level wbs component',
#  'the correspond high level deliverable',
#  'some deliverable need',
#  'the next level',
#  'the wbs represent',
#  'the project management work',
#  'the high level',
#  'no extra work',
#  'the percent rule',
#  'speci c information',
#  'work breakdown structure second edition',
#  'this standard contain industry',
#  'a Scope statement',
#  'its associate wb dictionary',
#  'the Scope baseline include',
#  'detailed de nition',
#  'these identi er',
#  'a management control point',
#  'a single control account',
#  'a planning package',
#  'a work breakdown structure component',
#  'know work content',
#  'detailed schedule activity',
#  'a later stage',
#  'u n code',
#  'account identi er',
#  'u n assumption',
#  'u n responsible organization',
#  'u n schedule milestone',
#  'u n associate schedule activity',
#  'u n resource require',
#  'u n cost estimate',
#  'u n quality requirement',
#  'u n acceptance criterion',
#  'u n agreement information',
#  'u n assumption log',
#  'u n requirement documentation',
#  'it bring objectivity',
#  'the acceptance process',
#  'validate each deliverable',
#  'the ef ciency',
#  'the information present',
#  'the quality report',
#  'all quality assurance issue manage',
#  'the requirement traceability matrix contain information',
#  'the acceptance criterion',
#  'formal documentation receive',
#  'formal stakeholder acceptance',
#  'the close project',
#  'the complete deliverable',
#  'the change request describe',
#  'the method use',
#  'the requirement traceability matrix help',
#  'change request receive',
#  'deliverable veri ed',
#  'control related policy',
#  'the threshold amount',
#  'project Scope control',
#  'the change receive',
#  'the identi ed Scope variance',
#  'the future Scope performance',
#  'scope management plan',
#  'a revise Scope baseline',
#  'a revise schedule baseline',
#  'corrective action choose',
#  'team resource availability',
#  'physical resource availability',
#  'tailor the organization s set',
#  'standardized estimate datum',
#  'informal schedule development',
#  'which schedule methodology',
#  'detailed the schedule need',
#  'roll wave planning',
#  'an appropriate balance',
#  'appropriate control threshold',
#  'project schedule model development',
#  'time box period',
#  'which the team work',
#  'time boxing help',
#  'essential feature rst',
#  'the acceptable range use',
#  'determine realistic activity duration estimate',
#  'project schedule model maintenance',
#  'the process use',
#  'monitor schedule performance',
#  'other physical measurement rule',
#  'u n rule',
#  'establish percent complete',
#  'u n evm technique e.g.',
#  'more speci c information',
#  'earn value management',
#  'u n schedule performance measurement such',
#  'schedule performance index spi use',
#  'the various schedule report',
#  'de ne activity',
#  'the project deliverable',
#  'enterprise environmental factor',
#  'uence the de ne activity process',
#  'the de ne activity process',
#  'repository contain historical information regard activity list use',
#  'previous similar project',
#  'a standard activity list',
#  'an activity list',
#  'a previous project',
#  'develop the activity',
#  'an iterative planning technique',
#  'which the work',
#  'progressive elaboration applicable',
#  'use an agile',
#  'early strategic planning',
#  'the know level',
#  'the upcoming event',
#  'an activity identi er',
#  'suf cient detail',
#  'project team member',
#  'identify multiple component associate',
#  'the initial stage',
#  'the unique activity identi',
#  'er i d',
#  'wbs i d',
#  'the plan schedule activity',
#  'a milestone list identi',
#  'all project milestone',
#  'the initial schedule baseline',
#  'other significant schedule milestone',
#  'ne the logical sequence',
#  'the great ef ciency',
#  'all project constraint',
#  'one successor activity',
#  'an appropriate logical relationship',
#  'a realistic project schedule',
#  'achievable project schedule',
#  'the sequence activity process concentrate',
#  'convert the project activity',
#  'a rst step',
#  'uence the sequencing',
#  'the way activity',
#  'uence the way activity',
#  'organization work authorization system',
#  'develop logical relationship',
#  'relate activity attribute information',
#  'additional descriptive information useful',
#  'repository contain historical information',
#  'the sequencing process',
#  'the precedence diagram method pdm',
#  'construct a schedule model',
#  'a successor activity',
#  'the operating system',
#  'a pc successor',
#  'the pc hardware',
#  'a document predecessor',
#  'edit the document successor',
#  'level concrete successor',
#  'pour foundation predecessor begin',
#  'a new account payable system successor',
#  'the old account payable system',
#  'the sf relationship',
#  'a complete list',
#  'the pdm relationship type',
#  'two logical relationship',
#  'the same activity',
#  'the high impact',
#  'precedence diagram method pdm relationship type activity',
#  'a activity b activity',
#  'a activity b activity b activity',
#  'a activity b finish',
#  'the follow attribute',
#  'the follow way',
#  'mandatory external dependency',
#  'mandatory internal dependency',
#  'discretionary external dependency',
#  'discretionary internal dependency',
#  'involve physical limitation',
#  'an electronic project',
#  'assign schedule constraint',
#  'some unusual aspect',
#  'a speci c sequence',
#  'other acceptable sequence',
#  'the electrical work',
#  'nishe the plumbing work',
#  'the overall project risk',
#  'arbitrary total oat value',
#  'non project activity',
#  'the testing activity',
#  'a software project',
#  'an external source',
#  'governmental environmental hearing',
#  'a precedence relationship',
#  'an internal mandatory dependency',
#  'the schedule punch list completion',
#  'a week lead',
#  'a negative value',
#  'lag complete punch list write draft landscape building lot edit draft ss day',
#  'a large document day',
#  'a day lag',
#  'the nomenclature ss start',
#  'their relate assumption',
#  'the different type',
#  'a b c d e',
#  'k l ff fs ss ss',
#  'a graphical representation',
#  'the project schedule activity',
#  'full project detail',
#  'a summary narrative',
#  'the basic approach use',
#  'any unusual activity sequence',
#  'multiple predecessor activity',
#  'multiple successor activity',
#  'the schedule date',
#  'estimate activity duration',
#  'estimate the number',
#  'time each activity',
#  'uence the duration estimate',
#  'the appropriate people',
#  'resource breakdown structure',
#  'the resource breakdown structure',
#  'a hierarchical structure',
#  'the identi ed resource',
#  'the resource calendar',
#  'schedule activity due',
#  'speci c resource',
#  'speci c attribute',
#  'resource calendar specify',
#  'long identi ed project resource',
#  'the estimate activity resource requirement',
#  'which the resource assign',
#  'low skilled resource',
#  'a long duration estimate',
#  'project document update',
#  'plan risk response',
#  'duration estimate database',
#  'other reference datum',
#  'historical duration information',
#  'estimate the duration',
#  'a project use historical datum',
#  'a similar activity',
#  'analogous estimating use parameter',
#  'estimate the same parameter',
#  'a future project',
#  'a gross value',
#  'a limited amount',
#  'less time consume',
#  'analogous duration estimate',
#  'the previous activity',
#  'the project team member',
#  'the need expertise',
#  'an estimating technique',
#  'which an algorithm',
#  'parametric estimating use',
#  'a statistical relationship',
#  'other variable e.g.',
#  'a design project',
#  'a cable installation',
#  'the assign resource',
#  'the duration require',
#  'underlie datum build',
#  'parametric schedule estimate',
#  'single point duration estimate',
#  'consider estimation uncertainty',
#  'use three point estimate help',
#  'ne an approximate range',
#  'an activity s duration',
#  'most likely tm',
#  'the resource likely',
#  'the activity duration base',
#  'the good case scenario',
#  'the duration base',
#  'the bad case scenario',
#  'the assumed distribution',
#  'the three estimate',
#  'insuf cient historical datum',
#  'use judgmental datum',
#  'duration estimate base',
#  'an assumed distribution',
#  'an expect duration',
#  'estimate project duration',
#  'the low level component',
#  'the detail duration',
#  'a total quantity',
#  'the estimate requirement',
#  'compression technique describe',
#  'different tool manual versus',
#  'an optimal approach',
#  'accomplish project work',
#  'management reserve need',
#  'the estimate duration',
#  'the know unknown',
#  'the estimate activity duration',
#  'the individual activity',
#  'the schedule documentation',
#  'a speci ed amount',
#  'the overall project duration requirement',
#  'low level task',
#  'the duration iteration',
#  'the rst day',
#  'the scrum team',
#  'an iteration backlog',
#  'assume a day work week',
#  'a high probability',
#  'uence this estimate',
#  'activity duration estimate produce',
#  'develop the duration estimate',
#  'resource skill level',
#  'analyze activity sequence',
#  'complete project activity',
#  'an acceptable project schedule',
#  'the well available information',
#  'an approve project schedule',
#  'ne the project milestone',
#  'the staff con rm',
#  'nish date present',
#  'no con ict',
#  'a realistic schedule',
#  'more speci c information regard scheduling',
#  'the detail use',
#  'the activity list identi',
#  'the quantitative assessment',
#  'the project team assignment specify',
#  'the resource calendar contain information',
#  'the activity resource requirement',
#  'all identi ed risk',
#  'risk information relevant',
#  'mean risk impact',
#  'the develop schedule process include',
#  'the policy govern schedule model development',
#  'project calendar s',
#  'the overarching technique use',
#  'several other technique such',
#  'critical path method describe',
#  'resource optimization technique describe',
#  'model technique describe',
#  'multiple path converge',
#  'multiple path diverge',
#  'high risk activity',
#  'long lead item',
#  'a viable schedule model',
#  'the minimum project duration',
#  'this schedule network analysis technique',
#  'the early start',
#  'late nish date',
#  'any resource limitation',
#  'perform a forward',
#  'backward pass analysis',
#  'the schedule network',
#  'a c d',
#  'the short possible project duration',
#  'the least total oat',
#  'the result early',
#  'the time period',
#  'the parameter enter',
#  'other know constraint',
#  'any network path',
#  'a schedule activity',
#  'its early start date',
#  'delay the project nish date',
#  'a critical path',
#  'zero total oat',
#  'the precedence diagram method sequence',
#  'negative total oat depend',
#  'the constraint apply',
#  'the backward pass',
#  'the early nish date',
#  'forward pass calculation',
#  'negative total oat',
#  'the late date',
#  'negative oat analysis',
#  'possible accelerate way',
#  'a delay schedule',
#  'many software package',
#  'the parameter use',
#  'other schedule constraint',
#  'example the free oat',
#  'critical path link',
#  'critical path link activity node start',
#  'a c b d activity',
#  'early start duration',
#  'finish late start total float',
#  'a b d path',
#  'a c d critical path key note',
#  'the accepted convention',
#  'the project start',
#  'critical path method',
#  'plan resource use',
#  'resource optimization technique',
#  'the schedule model due',
#  'balance the demand',
#  'the available supply',
#  'the same time period',
#  'a constant level',
#  'the original critical path',
#  'a schedule model such',
#  'certain predefine resource limit',
#  'the completion date',
#  'resource leveling start activity',
#  'hrs day day day',
#  'activity a tom',
#  'hrs day day day activity',
#  'resource leveling activity',
#  'the situation represent',
#  'a schedule network analysis',
#  'the different scenario',
#  'delay a major component delivery',
#  'speci c engineering duration',
#  'the permit process',
#  'prepare schedule reserve',
#  'the combine effect',
#  'their potential impact',
#  'achieve project objective',
#  'the most common simulation technique',
#  'monte carlo analysis see',
#  'possible schedule outcome',
#  'the total project',
#  'calculate multiple work package duration',
#  'scenario use probability distribution',
#  'a probability distribution',
#  'achieve a certain target date i.e.',
#  'project nish date',
#  'the target date',
#  'complete the project',
#  'project finish date',
#  'example probability distribution',
#  'a target milestone',
#  'monte carlo simulation',
#  'reduce the project Scope',
#  'other schedule objective',
#  'a helpful technique',
#  'the negative oat analysis',
#  'the least oat',
#  'the least incremental cost',
#  'a viable alternative',
#  'a schedule compression technique',
#  'the architectural drawing',
#  'increase coordination effort',
#  'the activity concern',
#  'increase quality risk',
#  'schedule compression comparison normal crash',
#  'high risk high cost',
#  'build a schedule model',
#  'nish date base',
#  'a high level summary timeline',
#  'the release schedule',
#  'the product roadmap',
#  'the product vision',
#  'the product s evolution',
#  'a releasable product base',
#  'feature represent value',
#  'information the customer',
#  'iteration planning release release release release plan iteration plan iteration iteration iteration iteration iteration n feature',
#  'a user story feature',
#  'a user story hour hour hour hour task',
#  'a task b task c task d product vision drive product roadmap product roadmap drive release plan',
#  'the iteration iteration plan schedule feature development task estimate',
#  'user story estimate',
#  'a schedule baseline',
#  'the appropriate stakeholder',
#  'baseline start date',
#  'baseline nish date',
#  'the approve baseline date',
#  'the actual start',
#  'that present link activity',
#  'a plan start date',
#  'plan nish date',
#  'an early stage',
#  'a target project schedule model',
#  'a define target start',
#  'the master schedule',
#  'a project schedule model',
#  'the follow format',
#  'comprehensive summary activity',
#  'multiple interdependent work package',
#  'bar chart report',
#  'the summary schedule portion',
#  'the schedule start',
#  'key external interface',
#  'the milestone schedule portion',
#  'node diagram format show activity',
#  'a pure logic diagram',
#  'a time scale schedule network diagram format',
#  'a logic bar chart',
#  'the detailed schedule',
#  'activity date information',
#  'both the project network logic',
#  'critical path schedule activity',
#  'a time scale logic diagram',
#  'the same line',
#  'figure show schedule presentation',
#  'a sample project',
#  'a simple project schedule model',
#  'figure re ect schedule presentation',
#  'a milestone schedule',
#  'a milestone chart',
#  'a summary schedule',
#  'a bar chart',
#  'a detailed schedule',
#  'a project schedule',
#  'bar chart diagram',
#  'the different level',
#  'project schedule time frame period period period period activity identifier',
#  'period activity description',
#  'new product z develop',
#  'product z work package',
#  'datum date ss fs',
#  'test integrate component',
#  'product z deliver product z finish new product z figure',
#  'project schedule presentation example',
#  'the schedule datum',
#  'the schedule data',
#  'the schedule milestone',
#  'all identi ed assumption',
#  'additional datum varie',
#  'a resource histogram',
#  'cash ow projection',
#  'other relevant information',
#  'a project calendar identi es working day',
#  'it distinguish time period',
#  'the project calendar',
#  'any revised resource requirement',
#  'any other revision generate',
#  'the activity dependency',
#  'schedule status review',
#  'the contractor report',
#  'the schedule forecast',
#  'project schedule refer',
#  'the most recent version',
#  'the indicate date',
#  'informal schedule control relate policy',
#  'schedule control tool',
#  'schedule performance measurement such',
#  'schedule performance index spi',
#  'the iteration backlog',
#  'an ideal burndown base',
#  'the work commit',
#  'iteration planning see',
#  'a forecast trend line',
#  ...]

# %%
len(unique_noun)
# Out:
# 298

# %% [markdown]
# ## 4. Extract verbs and noun with spaCy

# %%
data_to_process.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 1                   . . . project charter
# 2           . . . project management plan
# 3  . . . enterprise environmental factors
# 4     . . . organizational process assets
#
#                                                  def  \
# 0  plan Scope management is the process of creati...
# 1
# 2
# 3  the enterprise environmental factors influence...
# 4  the organizational process assets influence th...
#
#                                            lemma_def  \
# 0  plan Scope management be the process of create...
# 1
# 2
# 3  the enterprise environmental factor influence ...
# 4  the organizational process asset influence the...
#
#                                       lemma_sentence  \
# 0  [plan Scope management be the process of creat...
# 1                                                 []
# 2                                                 []
# 3  [the enterprise environmental factor influence...
# 4  [the organizational process asset influence th...
#
#                                                 noun  \
# 0  [plan Scope management, the process, create a ...
# 1                                                 []
# 2                                                 []
# 3  [the enterprise environmental factor influence...
# 4  [the organizational process asset influence, t...
#
#                                                 verb
# 0  [be, document, will be, be, provide, will be m...
# 1  [be, document, will be, be, provide, will be m...
# 2  [be, document, will be, be, provide, will be m...
# 3                                          [include]
# 4                                   [include, learn]

# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
for i in range(len(data_to_process['lemma_sentence'][0])):
    text = data_to_process['lemma_sentence'][0][i]
    text = ' '.join([word for word in text.split() if word not in stop])
    doc = nlp(text)

    # Analyze syntax
    print(f"text {i+1}:",text)
    print('---------------------------------------')
    print(f"Noun phrases {i+1}:", [chunk.text for chunk in doc.noun_chunks])
    print('---------------------------------------')
    print(f"Verbs {i+1}: ", [token.lemma_ for token in doc if token.pos_ == "VERB"])
# Out:
# text 1: plan Scope management be process create Scope management plan document project product Scope will be define , validate , control .
# ---------------------------------------
# Noun phrases 1: ['plan Scope management', 'process', 'Scope management plan document project product Scope']
# ---------------------------------------
# Verbs 1:  ['create']
# text 2: key benefit process be provide guidance direction Scope will be manage throughout project .
# ---------------------------------------
# Noun phrases 2: ['key benefit process', 'guidance direction Scope', 'project']
# ---------------------------------------
# Verbs 2:  ['provide', 'manage']
# text 3: process be perform predefine point project .
# ---------------------------------------
# Noun phrases 3: ['process', 'predefine point project']
# ---------------------------------------
# Verbs 3:  ['perform']
# text 4: Scope management plan be component project program management plan describe Scope will be define , develop , monitor , control , validate .
# ---------------------------------------
# Noun phrases 4: ['Scope management plan', 'component project program management plan', 'Scope']
# ---------------------------------------
# Verbs 4:  ['describe', 'develop', 'monitor']
# text 5: development Scope management plan detailing project Scope begin analysis information contain project charter , late approve subsidiary plan project management plan , historical information contain organizational process asset relevant enterprise environmental factor
# ---------------------------------------
# Noun phrases 5: ['development Scope management plan', 'project Scope', 'analysis information', 'project charter', 'late approve subsidiary plan project management plan', 'historical information', 'organizational process', 'relevant enterprise environmental factor']
# ---------------------------------------
# Verbs 5:  ['detail', 'begin', 'contain', 'approve', 'contain', 'asset']

# %%
data_to_process['noun_spacy'] = [[] for _ in range(len(data_to_process))]
data_to_process['verb_spacy'] = [[] for _ in range(len(data_to_process))]

for i in range(0,len(data_to_process['lemma_sentence'])):
    noun_spacy = []
    verb_spacy = []
    for j in range(len(data_to_process['lemma_sentence'][i])):
        text = data_to_process['lemma_sentence'][i][j]
        text = ' '.join([word for word in text.split() if word not in stop])
        doc = nlp(text)

        NP = [chunk.text for chunk in doc.noun_chunks]
        noun_spacy += NP
        VB = [token.lemma_ for token in doc if token.pos_ == "VERB"]
        verb_spacy += VB
    data_to_process['noun_spacy'][i] = noun_spacy 
    data_to_process['verb_spacy'][i] = verb_spacy

# %%
data_to_process.head()
# Out:
#                                   concept  \
# 0                 . plan scope management
# 1                   . . . project charter
# 2           . . . project management plan
# 3  . . . enterprise environmental factors
# 4     . . . organizational process assets
#
#                                                  def  \
# 0  plan Scope management is the process of creati...
# 1
# 2
# 3  the enterprise environmental factors influence...
# 4  the organizational process assets influence th...
#
#                                            lemma_def  \
# 0  plan Scope management be the process of create...
# 1
# 2
# 3  the enterprise environmental factor influence ...
# 4  the organizational process asset influence the...
#
#                                       lemma_sentence  \
# 0  [plan Scope management be the process of creat...
# 1                                                 []
# 2                                                 []
# 3  [the enterprise environmental factor influence...
# 4  [the organizational process asset influence th...
#
#                                                 noun  \
# 0  [plan Scope management, the process, create a ...
# 1                                                 []
# 2                                                 []
# 3  [the enterprise environmental factor influence...
# 4  [the organizational process asset influence, t...
#
#                                                 verb  \
# 0  [be, document, will be, be, provide, will be m...
# 1  [be, document, will be, be, provide, will be m...
# 2  [be, document, will be, be, provide, will be m...
# 3                                          [include]
# 4                                   [include, learn]
#
#                                           noun_spacy  \
# 0  [plan Scope management, process, Scope managem...
# 1                                                 []
# 2                                                 []
# 3  [enterprise environmental factor influence pla...
# 4  [organizational process asset influence plan S...
#
#                                           verb_spacy
# 0  [create, provide, manage, perform, describe, d...
# 1                                                 []
# 2                                                 []
# 3                                          [include]
# 4                                   [include, learn]

# %%
print(data_to_process['lemma_sentence'][0])
# Out:
# ['plan Scope management be the process of create a Scope management plan that document how the project and product Scope will be define , validate , and control .', 'the key benefit of this process be that it provide guidance and direction on how Scope will be manage throughout the project .', 'this process be perform once or at predefine point in the project .', 'the Scope management plan be a component of the project or program management plan that describe how the Scope will be define , develop , monitor , control , and validate .', 'the development of the Scope management plan and the detailing of the project Scope begin with the analysis of information contain in the project charter , the late approve subsidiary plan of the project management plan , historical information contain in the organizational process asset and any other relevant enterprise environmental factor']

# %%
print(data_to_process['noun'][0])
# Out:
# ['plan Scope management', 'the process', 'create a Scope management plan', 'that', 'the project', 'product Scope', 'define', 'validate', 'control', 'the key benefit', 'this process', 'it', 'guidance', 'direction', 'Scope', 'the project', 'this process', 'predefine point', 'the project', 'the Scope management plan', 'a component', 'the project', 'program management plan', 'that', 'the Scope', 'define', 'monitor', 'control', 'validate', 'the development', 'the Scope management plan', 'the detailing', 'the project Scope begin', 'the analysis', 'information contain', 'the project charter', 'the late approve subsidiary plan', 'the project management plan', 'historical information contain', 'the organizational process asset', 'any other relevant enterprise environmental factor']

# %%
print(data_to_process['noun_spacy'][0])
# Out:
# ['plan Scope management', 'process', 'Scope management plan document project product Scope', 'key benefit process', 'guidance direction Scope', 'project', 'process', 'predefine point project', 'Scope management plan', 'component project program management plan', 'Scope', 'development Scope management plan', 'project Scope', 'analysis information', 'project charter', 'late approve subsidiary plan project management plan', 'historical information', 'organizational process', 'relevant enterprise environmental factor']

# %%
print(data_to_process['verb'][0])
# Out:
# ['be', 'document', 'will be', 'be', 'provide', 'will be manage', 'be perform', 'be', 'describe', 'will be', 'develop']

# %%
print(data_to_process['verb_spacy'][0])
# Out:
# ['create', 'provide', 'manage', 'perform', 'describe', 'develop', 'monitor', 'detail', 'begin', 'contain', 'approve', 'contain', 'asset']

# %%
len(data_to_process['noun_spacy'][0]),len(data_to_process['noun'][0])
# Out:
# (19, 41)

# %%
data_to_process['def'][0]
# Out:
# 'plan Scope management is the process of creating a Scope management plan that documents how the project and product Scope will be defined, validated, and controlled. the key benefit of this process is that it provides guidance and direction on how Scope will be managed throughout the project. this process is performed once or at predefined points in the project. the Scope management plan is a component of the project or program management plan that describes how the Scope will be defined, developed, monitored, controlled, and validated. the development of the Scope management plan and the detailing of the project Scope begin with the analysis of information contained in the project charter  , the latest approved subsidiary plans of the project management plan  , historical information contained in the organizational process assets  and any other relevant enterprise environmental factors  '

# %%
verb_list_spacy = []
for i in range(0, len(data_to_process['verb_spacy'])-1):
    verb_list_spacy +=  data_to_process['verb_spacy'][i]

# %%
from collections import Counter
counter = Counter(verb_list_spacy)
sorted_counter_verb = counter.most_common()
sorted_counter_verb
# Out:
# [('include', 174),
#  ('describe', 139),
#  ('use', 80),
#  ('provide', 46),
#  ('be', 46),
#  ('require', 40),
#  ('perform', 39),
#  ('learn', 39),
#  ('develop', 37),
#  ('determine', 37),
#  ('have', 36),
#  ('start', 35),
#  ('need', 26),
#  ('remain', 24),
#  ('consider', 23),
#  ('contain', 22),
#  ('register', 21),
#  ('update', 18),
#  ('indicate', 18),
#  ('manage', 17),
#  ('represent', 17),
#  ('estimate', 17),
#  ('monitor', 16),
#  ('approve', 16),
#  ('refer', 16),
#  ('make', 16),
#  ('create', 15),
#  ('establish', 15),
#  ('expect', 15),
#  ('show', 15),
#  ('relate', 14),
#  ('accept', 13),
#  ('apply', 13),
#  ('improve', 13),
#  ('give', 13),
#  ('identify', 12),
#  ('allow', 12),
#  ('change', 12),
#  ('know', 12),
#  ('begin', 11),
#  ('take', 11),
#  ('meet', 11),
#  ('define', 11),
#  ('carry', 11),
#  ('exist', 11),
#  ('cost', 11),
#  ('compare', 10),
#  ('ensure', 10),
#  ('deliver', 10),
#  ('decompose', 10),
#  ('reduce', 9),
#  ('impact', 9),
#  ('become', 8),
#  ('bring', 8),
#  ('agree', 8),
#  ('evaluate', 8),
#  ('see', 8),
#  ('add', 8),
#  ('authorize', 8),
#  ('integrate', 8),
#  ('adjust', 8),
#  ('limit', 7),
#  ('maintain', 7),
#  ('involve', 7),
#  ('decide', 7),
#  ('build', 7),
#  ('work', 7),
#  ('organize', 7),
#  ('increase', 7),
#  ('finish', 7),
#  ('occur', 7),
#  ('calculate', 7),
#  ('analyze', 6),
#  ('affect', 6),
#  ('go', 6),
#  ('produce', 6),
#  ('specify', 6),
#  ('publish', 6),
#  ('depend', 6),
#  ('bac', 6),
#  ('collect', 5),
#  ('impose', 5),
#  ('obtain', 5),
#  ('reach', 5),
#  ('result', 5),
#  ('construct', 5),
#  ('forecast', 5),
#  ('hold', 5),
#  ('extend', 5),
#  ('assume', 5),
#  ('schedule', 5),
#  ('predict', 5),
#  ('achieve', 5),
#  ('capture', 4),
#  ('generate', 4),
#  ('receive', 4),
#  ('range', 4),
#  ('example', 4),
#  ('set', 4),
#  ('cient', 4),
#  ('plan', 4),
#  ('understand', 4),
#  ('rise', 4),
#  ('nish', 4),
#  ('buy', 4),
#  ('cause', 4),
#  ('es', 3),
#  ('document', 3),
#  ('form', 3),
#  ('attribute', 3),
#  ('assign', 3),
#  ('wb', 3),
#  ('imply', 3),
#  ('lead', 3),
#  ('put', 3),
#  ('employ', 3),
#  ('reserve', 3),
#  ('eliminate', 3),
#  ('exceed', 3),
#  ('look', 3),
#  ('display', 3),
#  ('detail', 2),
#  ('attend', 2),
#  ('prepare', 2),
#  ('process', 2),
#  ('log', 2),
#  ('ask', 2),
#  ('conduct', 2),
#  ('prioritize', 2),
#  ('post', 2),
#  ('prototype', 2),
#  ('discuss', 2),
#  ('mean', 2),
#  ('avoid', 2),
#  ('le', 2),
#  ('control', 2),
#  ('elaborate', 2),
#  ('serve', 2),
#  ('vary', 2),
#  ('verify', 2),
#  ('incorporate', 2),
#  ('ef', 2),
#  ('dif', 2),
#  ('choose', 2),
#  ('combine', 2),
#  ('constraint', 2),
#  ('reveal', 2),
#  ('optimize', 2),
#  ('come', 2),
#  ('ff', 2),
#  ('write', 2),
#  ('recommend', 2),
#  ('characterize', 2),
#  ('delay', 2),
#  ('draft', 2),
#  ('sequence', 2),
#  ('measure', 2),
#  ('withhold', 2),
#  ('commit', 2),
#  ('continue', 2),
#  ('necessitate', 2),
#  ('accelerate', 2),
#  ('call', 2),
#  ('appear', 2),
#  ('earn', 2),
#  ('corrective', 2),
#  ('review', 2),
#  ('cover', 2),
#  ('aggregate', 2),
#  ('base', 2),
#  ('realize', 2),
#  ('fall', 2),
#  ('complete', 2),
#  ('asset', 1),
#  ('enable', 1),
#  ('frame', 1),
#  ('address', 1),
#  ('note', 1),
#  ('talk', 1),
#  ('prequali', 1),
#  ('propose', 1),
#  ('accumulate', 1),
#  ('disperse', 1),
#  ('benchmarke', 1),
#  ('classify', 1),
#  ('consolidate', 1),
#  ('depict', 1),
#  ('hire', 1),
#  ('legend', 1),
#  ('flow', 1),
#  ('storyboarde', 1),
#  ('categorize', 1),
#  ('help', 1),
#  ('cancel', 1),
#  ('translate', 1),
#  ('constitute', 1),
#  ('gather', 1),
#  ('c', 1),
#  ('divide', 1),
#  ('correspond', 1),
#  ('arrive', 1),
#  ('wait', 1),
#  ('leave', 1),
#  ('project', 1),
#  ('identi', 1),
#  ('sign', 1),
#  ('acknowledge', 1),
#  ('defect', 1),
#  ('detect', 1),
#  ('correlate', 1),
#  ('release', 1),
#  ('minimize', 1),
#  ('list', 1),
#  ('evolve', 1),
#  ('order', 1),
#  ('connect', 1),
#  ('convert', 1),
#  ('uence', 1),
#  ('link', 1),
#  ('operate', 1),
#  ('assemble', 1),
#  ('shut', 1),
#  ('modi', 1),
#  ('test', 1),
#  ('offset', 1),
#  ('insert', 1),
#  ('differentiate', 1),
#  ('end', 1),
#  ('resource', 1),
#  ('signi', 1),
#  ('rely', 1),
#  ('underlie', 1),
#  ('automate', 1),
#  ('rent', 1),
#  ('weigh', 1),
#  ('xe', 1),
#  ('break', 1),
#  ('scrum', 1),
#  ('sustain', 1),
#  ('overarch', 1),
#  ('slip', 1),
#  ('converge', 1),
#  ('pass', 1),
#  ('enter', 1),
#  ('implement', 1),
#  ('keep', 1),
#  ('oppose', 1),
#  ('happen', 1),
#  ('compute', 1),
#  ('introduce', 1),
#  ('pay', 1),
#  ('shorten', 1),
#  ('crash', 1),
#  ('overlap', 1),
#  ('feature', 1),
#  ('structure', 1),
#  ('amount', 1),
#  ('supply', 1),
#  ('distinguish', 1),
#  ('revise', 1),
#  ('reprioritize', 1),
#  ('baseline', 1),
#  ('assess', 1),
#  ('fund', 1),
#  ('acquire', 1),
#  ('check', 1),
#  ('share', 1),
#  ('ect', 1),
#  ('narrow', 1),
#  ('view', 1),
#  ('intend', 1),
#  ('anticipate', 1),
#  ('simplify', 1),
#  ('facilitate', 1),
#  ('vote', 1),
#  ('incur', 1),
#  ('reschedule', 1),
#  ('finance', 1),
#  ('seek', 1),
#  ('exclude', 1),
#  ('illustrate', 1),
#  ('tie', 1),
#  ('track', 1),
#  ('act', 1),
#  ('prevent', 1),
#  ('inform', 1),
#  ('tend', 1),
#  ('decrease', 1),
#  ('equal', 1),
#  ('differ', 1),
#  ('reissue', 1),
#  ('encounter', 1),
#  ('remove', 1),
#  ('replace', 1),
#  ('stay', 1),
#  ('procee', 1),
#  ('communicate', 1),
#  ('feedback', 1)]

# %%
most_important_verb_spacy = []
for item in sorted_counter_verb:
    if 5 < item[1]:
        most_important_verb_spacy.append(item[0])

# %%
most_important_verb_spacy
# Out:
# ['include',
#  'describe',
#  'use',
#  'provide',
#  'be',
#  'require',
#  'perform',
#  'learn',
#  'develop',
#  'determine',
#  'have',
#  'start',
#  'need',
#  'remain',
#  'consider',
#  'contain',
#  'register',
#  'update',
#  'indicate',
#  'manage',
#  'represent',
#  'estimate',
#  'monitor',
#  'approve',
#  'refer',
#  'make',
#  'create',
#  'establish',
#  'expect',
#  'show',
#  'relate',
#  'accept',
#  'apply',
#  'improve',
#  'give',
#  'identify',
#  'allow',
#  'change',
#  'know',
#  'begin',
#  'take',
#  'meet',
#  'define',
#  'carry',
#  'exist',
#  'cost',
#  'compare',
#  'ensure',
#  'deliver',
#  'decompose',
#  'reduce',
#  'impact',
#  'become',
#  'bring',
#  'agree',
#  'evaluate',
#  'see',
#  'add',
#  'authorize',
#  'integrate',
#  'adjust',
#  'limit',
#  'maintain',
#  'involve',
#  'decide',
#  'build',
#  'work',
#  'organize',
#  'increase',
#  'finish',
#  'occur',
#  'calculate',
#  'analyze',
#  'affect',
#  'go',
#  'produce',
#  'specify',
#  'publish',
#  'depend',
#  'bac']

# %%
noun_list_spacy = []
for i in range(0, len(data_to_process['noun_spacy'])-1):
    noun_list_spacy +=  data_to_process['noun_spacy'][i]

# %%
noun_list_spacy
# Out:
# ['plan Scope management',
#  'process',
#  'Scope management plan document project product Scope',
#  'key benefit process',
#  'guidance direction Scope',
#  'project',
#  'process',
#  'predefine point project',
#  'Scope management plan',
#  'component project program management plan',
#  'Scope',
#  'development Scope management plan',
#  'project Scope',
#  'analysis information',
#  'project charter',
#  'late approve subsidiary plan project management plan',
#  'historical information',
#  'organizational process',
#  'relevant enterprise environmental factor',
#  'enterprise environmental factor influence plan Scope management process',
#  'organization culture',
#  'infrastructure',
#  'personnel administration',
#  'marketplace condition',
#  'organizational process asset influence plan Scope management process',
#  'policy procedure',
#  'historical information lesson',
#  'repository',
#  'data analysis technique',
#  'use process',
#  'alternative analysis',
#  'requirement',
#  'elaborate project product Scope',
#  'product',
#  'validate Scope',
#  'control Scope',
#  'project team',
#  'project meeting',
#  'Scope management plan',
#  'attendee',
#  'project manager',
#  'project sponsor',
#  'select project team member',
#  'select stakeholder',
#  'anyone responsibility Scope management process',
#  'Scope management plan',
#  'component project management plan',
#  'Scope',
#  'component Scope management plan',
#  'process',
#  'project Scope statement',
#  'process',
#  'creation',
#  'detailed project Scope statement',
#  'process',
#  'Scope baseline',
#  'speci',
#  'formal acceptance complete project deliverable',
#  'Scope management plan',
#  'highly detail',
#  'base',
#  'requirement management plan',
#  'component project management plan',
#  'analyze',
#  'document',
#  'accord business analysis practitioner',
#  'practice guide',
#  'organization',
#  'business analysis plan',
#  'component requirement management plan',
#  'requirement activity',
#  'plan',
#  'track',
#  'report',
#  'change',
#  'impact',
#  'analyze',
#  'trace',
#  'track',
#  'report',
#  'authorization level',
#  'approve change',
#  'rationale use',
#  'traceability structure ect requirement attribute',
#  'traceability matrix',
#  'requirement',
#  'stakeholder',
#  'requirement meet objective',
#  'key benefit process',
#  'basis de ne product Scope project Scope',
#  'process',
#  'predefine point project',
#  'pmbok guide',
#  'speci',
#  'product requirement',
#  'industry',
#  'business analysis practitioner',
#  'practice guide',
#  'depth information product requirement',
#  'project success',
#  'directly uence active stakeholder involvement discovery decomposition',
#  'project product requirement care',
#  'determine',
#  'requirement product',
#  'service',
#  'result project',
#  'requirement',
#  'condition capability',
#  'present product',
#  'service',
#  'result satisfy agreement',
#  'speci cation',
#  'requirement',
#  'quanti ed document',
#  'expectation sponsor',
#  'customer',
#  'stakeholder',
#  'requirement',
#  'record enough detail',
#  'Scope baseline',
#  'project execution',
#  'requirement',
#  'foundation wbs',
#  'procurement',
#  'base requirement',
#  'example project document',
#  'input process',
#  'assumption log',
#  'assumption log identi ed assumption product',
#  'project , environment , stakeholder , factor influence requirement',
#  'lesson',
#  'lesson',
#  'register',
#  'use',
#  'information effective requirement collection technique',
#  'especially project',
#  'iterative adaptive product development methodology',
#  'stakeholder register',
#  'use',
#  'stakeholder',
#  'information requirement',
#  'requirement expectation stakeholder',
#  'project',
#  'enterprise environmental factor influence',
#  'requirement process',
#  'organization culture',
#  'infrastructure',
#  'personnel administration',
#  'marketplace condition',
#  'organizational process asset influence',
#  'requirement process',
#  'policy procedure',
#  'historical information lesson',
#  'repository information previous project',
#  'datum gathering technique',
#  'use process',
#  'brainstorming',
#  'technique use',
#  'project product requirement',
#  'interview',
#  'interview',
#  'prepared spontaneous question record response',
#  'interview',
#  'individual basis interviewer interviewee',
#  'multiple interviewer multiple interviewee',
#  'interview',
#  'experienced project participant',
#  'sponsor',
#  'executive',
#  'subject matter',
#  'expert aid',
#  'de ne feature function desire product deliverable',
#  'interview',
#  'con dential information',
#  'focus group',
#  'focus group',
#  'prequali ed stakeholder subject matter expert',
#  'expectation attitude',
#  'service',
#  'result',
#  'train moderator guide group interactive discussion design',
#  'conversational one one interview',
#  'questionnaire survey',
#  'questionnaire survey',
#  'set question design',
#  'information',
#  'large number respondent',
#  'questionnaire survey',
#  'appropriate varied audience',
#  'quick turnaround',
#  'respondent',
#  'statistical analysis',
#  'benchmarking involve',
#  'actual plan product , process , practice comparable organization',
#  'good practice',
#  'idea improvement',
#  'basis measure performance',
#  'organization',
#  'benchmarking',
#  'decision',
#  'technique',
#  'collect requirement process',
#  'vote',
#  'voting',
#  'collective decision making technique assessment process',
#  'multiple alternative',
#  'outcome',
#  'future action',
#  'technique',
#  'generate',
#  'product requirement',
#  'example vote technique',
#  'u',
#  'unanimity',
#  'decision',
#  'everyone',
#  'single course action',
#  'u',
#  'majority',
#  'decision',
#  'support',
#  'member group',
#  'group size',
#  'decision',
#  'tie',
#  'u',
#  'plurality',
#  'decision',
#  'large block group',
#  'even majority',
#  'method',
#  'number option nominate',
#  'autocratic decision making',
#  'one individual',
#  'responsibility',
#  'decision group',
#  'multicriteria decision analysis',
#  'technique use decision matrix',
#  'systematic analytical approach',
#  'criterion',
#  'risk level',
#  'uncertainty',
#  'valuation',
#  'rank',
#  'many idea',
#  'datum representation technique',
#  'use process',
#  'affinity diagram',
#  'nity diagram',
#  'large number idea',
#  'classi ed group review analysis',
#  'mind mapping',
#  'mind mapping',
#  'idea',
#  'individual brainstorming session single map ect commonality difference understanding',
#  'new idea',
#  'context diagram',
#  'example Scope model',
#  'context diagrams',
#  'product Scope',
#  'business system process',
#  'equipment',
#  'computer system',
#  'people system actor interact',
#  'figure',
#  'context diagram',
#  'input business system',
#  'actor',
#  'input',
#  'output business system',
#  'output',
#  'figure',
#  'context diagram',
#  'abc company external job website',
#  'external user internal user external user internal user',
#  'internal user',
#  'internal datum',
#  'external user',
#  'external datum',
#  'external job',
#  'external user profile internal job',
#  'internal user profile',
#  'prototyping be method',
#  'early feedback requirement provide model',
#  'product',
#  'example prototype',
#  'small scale product',
#  'computer',
#  'mock',
#  'simulation',
#  'prototype',
#  'stakeholder experiment model nal product',
#  'limit',
#  'abstract representation requirement',
#  'prototype support concept progressive elaboration iterative cycle mock creation',
#  'user experimentation',
#  'feedback generation',
#  'prototype revision',
#  'enough feedback cycle',
#  'requirement obtain prototype',
#  'suf ciently complete move design build phase',
#  'prototyping technique show sequence navigation series image illustration',
#  'variety project variety industry',
#  'advertising',
#  'instructional design',
#  'agile software development project',
#  'software development',
#  ', storyboard use',
#  'mock',
#  'navigation path web page',
#  'screen',
#  'user interface',
#  'requirement documentation',
#  'individual requirement meet business need project',
#  'requirement',
#  'high level',
#  'progressively detailed information requirement',
#  'requirement',
#  'unambiguous measurable testable , traceable , complete , consistent , acceptable key stakeholder',
#  'format requirement document',
#  'simple document list requirement categorize stakeholder priority',
#  'elaborate form',
#  'executive summary',
#  'detailed description',
#  'attachment',
#  'many organization',
#  'requirement different type',
#  'business technical solution',
#  'former refer stakeholder',
#  'latter need',
#  'requirement be group classi cation',
#  'nement detail requirement',
#  'classi cation',
#  'business requirement',
#  'high level',
#  'need organization whole',
#  'business issue opportunity',
#  'reason project',
#  'stakeholder requirement',
#  'stakeholder stakeholder group',
#  'solution requirement',
#  'feature',
#  'function',
#  'characteristic product',
#  'service',
#  'result',
#  'business stakeholder requirement',
#  'solution requirement',
#  'far group functional nonfunctional requirement',
#  'functional requirement',
#  'functional requirement',
#  'behavior product',
#  'example',
#  'action , process , datum , interaction product execute',
#  'u n nonfunctional requirement',
#  'nonfunctional requirement supplement functional requirement',
#  'environmental condition quality',
#  'product',
#  'example',
#  'reliability',
#  'security',
#  'performance',
#  'safety',
#  'level service',
#  'supportability',
#  'retention purge',
#  'transition readiness requirement',
#  'temporary capability',
#  'data conversion training requirement',
#  'transition current',
#  'state desire',
#  'future state',
#  'project requirement',
#  'action',
#  'process',
#  'condition project',
#  'example',
#  'milestone date',
#  'contractual obligation',
#  'constraint',
#  'quality requirement',
#  'condition criterion',
#  'validate successful completion project deliverable ful llment project requirement',
#  'example',
#  'test',
#  'certi cation',
#  'validation',
#  'requirement traceability matrix',
#  'grid link product requirement origin deliverable satisfy',
#  'implementation requirement traceability matrix help',
#  'requirement',
#  'business value link business project objective',
#  'track requirement',
#  'project life cycle',
#  'requirement approve requirement documentation',
#  'end project',
#  'structure manage change product Scope',
#  'trace requirement',
#  'limit',
#  'business need',
#  'opportunity',
#  'goal',
#  'project objective',
#  'project Scope',
#  'product design',
#  'product development',
#  'test strategy test scenario',
#  'high level requirement detailed requirement',
#  'associate requirement',
#  'record requirement traceability matrix',
#  'help de ne key information requirement',
#  'typical attribute',
#  'requirement traceability matrix',
#  'unique identi er , textual description requirement',
#  'rationale inclusion',
#  'owner , source , priority , version , current status',
#  'defer',
#  'status date',
#  'additional attribute',
#  'requirement',
#  'stakeholder satisfaction',
#  'stability',
#  'complexity',
#  'acceptance criterion',
#  'figure',
#  'example requirement traceability matrix associate attribute',
#  'figure',
#  'example',
#  'requirement traceability matrix requirement traceability matrix requirement description',
#  'business need , opportunity , goal , objective project objective associate',
#  'wb deliverable product design product development test case program portfolio project name',
#  'cost center',
#  'project description',
#  'Scope',
#  'be process',
#  'detailed description project product',
#  'key benefit process',
#  'product',
#  'service',
#  'boundary acceptance criterion',
#  'example project document',
#  'input process',
#  'assumption log',
#  'assumption log identi es assumption constraint product',
#  'project',
#  'environment',
#  'stakeholder',
#  'factor influence project product Scope',
#  'requirement documentation',
#  'requirement documentation identi es requirement',
#  'Scope',
#  'risk register',
#  'risk register contain response strategy',
#  'project Scope',
#  'change project product Scope',
#  'risk',
#  'enterprise environmental factor influence de ne Scope process',
#  'organization culture',
#  'infrastructure',
#  'personnel administration',
#  'marketplace condition',
#  'organizational process asset influence de ne Scope process',
#  'policy , procedure , template project Scope statement',
#  'project',
#  'previous project',
#  'lesson',
#  'previous phase project',
#  'data analysis technique',
#  'alternative analysis',
#  'alternative analysis',
#  'requirement objective identi ed charter',
#  'product analysis',
#  'de ne product service',
#  'question product service form answer describe use',
#  'characteristic , relevant aspect',
#  'application area',
#  'method translate high level product service description meaningful deliverable',
#  'requirement',
#  'high level decompose level detail',
#  'design nal product',
#  'example product analysis technique',
#  'product breakdown',
#  'requirement analysis',
#  'system analysis',
#  'system engineering',
#  'value analysis',
#  'value engineering',
#  'project Scope statement',
#  'description project Scope',
#  'major deliverable',
#  'assumption',
#  'constraint',
#  'project Scope statement document entire Scope',
#  'project product Scope',
#  'project deliverable detail',
#  'common understanding project Scope',
#  'project stakeholder',
#  'explicit scope exclusion assist',
#  'stakeholder expectation',
#  'enable project team',
#  'detailed planning',
#  'guide',
#  'project team work execution',
#  'baseline',
#  'request',
#  'additional work',
#  'outside project boundary',
#  'degree level detail project Scope statement de ne work',
#  'work',
#  'exclude',
#  'help',
#  'project management team',
#  'overall project Scope',
#  'detailed project Scope statement',
#  'either directly reference document',
#  'follow',
#  'product Scope description',
#  'progressively elaborate characteristic product',
#  'service',
#  'result',
#  'project charter requirement documentation',
#  'unique verifiable product',
#  'result',
#  'capability perform service',
#  'complete process',
#  'phase',
#  'project',
#  'deliverable',
#  'ancillary result',
#  'project management report documentation',
#  'summary level',
#  'great detail',
#  'acceptance criterion',
#  'set condition',
#  'project exclusion',
#  'exclude project',
#  'state',
#  'stakeholder expectation',
#  'project charter project Scope statement',
#  'certain degree redundancy',
#  'project charter',
#  'high level information',
#  'project Scope statement',
#  'detailed description Scope component',
#  'component',
#  'project',
#  'table',
#  'key element document',
#  'project charter project purpose measurable project objective related success criterion high level requirement high level project description',
#  'boundary , key deliverable overall project risk summary milestone schedule preapprove financial resource key stakeholder list project approval requirement',
#  'success',
#  'project',
#  'sign project project exit criterion',
#  'condition',
#  'order close cancel project phase assign project manager',
#  'responsibility , authority level name authority sponsor person',
#  'project charter project Scope statement project Scope description',
#  'project deliverable acceptance criterion project exclusion table',
#  'element project charter project Scope statement',
#  'project document',
#  'update result',
#  'carry process',
#  'assumption log',
#  'assumption log',
#  'additional assumption constraint',
#  'identi ed process',
#  'requirement documentation',
#  'requirement documentation',
#  'additional changed requirement',
#  'requirement traceability matrix',
#  'requirement traceability matrix',
#  'ect update requirement documentation',
#  'additional information',
#  'new stakeholder',
#  'result process',
#  'wbs',
#  'process',
#  'subdividing project deliverable project',
#  'key benefit process',
#  'framework',
#  'process',
#  'predefine point project',
#  'wbs',
#  'hierarchical decomposition',
#  'total Scope work',
#  'project team',
#  'accomplish project',
#  'objective create',
#  'de ne total Scope project',
#  'work',
#  'speci ed current approve project Scope statement',
#  'plan work',
#  'low level wbs component',
#  'call work package',
#  'work package',
#  'group activity work',
#  'schedule estimate',
#  'control',
#  'context',
#  'work',
#  'work product deliverable',
#  'result activity activity',
#  'project management plan component',
#  'limit Scope management plan',
#  'Scope management plan document wbs',
#  'project Scope statement',
#  'example project document',
#  'input process',
#  'project Scope statement',
#  'project Scope statement',
#  'work',
#  'exclude',
#  'requirement documentation',
#  'detailed requirement',
#  'individual requirement meet business need project',
#  'enterprise environmental factor influence',
#  'wbs process',
#  'industry',
#  'speci',
#  'relevant nature project',
#  'industry',
#  'speci c standard',
#  'external reference source',
#  'wbs',
#  'organizational process asset influence',
#  'wbs process',
#  'policy',
#  'procedure',
#  'template wbs',
#  'project',
#  'previous project',
#  'lesson',
#  'previous project',
#  'decomposition',
#  'technique use',
#  'subdivide project Scope project',
#  'deliverable small , manageable part',
#  'work package',
#  'work',
#  'low level wbs cost duration be estimate manage',
#  'level decomposition',
#  'degree control',
#  'project',
#  'level detail work package',
#  'size complexity project',
#  'decomposition total project work work package',
#  'follow activity',
#  'deliverable related work',
#  'structure',
#  'wbs',
#  'upper wbs level low level detailed component',
#  'assign identi cation code wbs component',
#  'degree decomposition deliverable',
#  'portion',
#  'branch',
#  'work package level',
#  'show figure',
#  'figure',
#  'work package',
#  'value management system project',
#  'assessment',
#  'standard development',
#  'system engineering',
#  'project management wbs',
#  'full project Scope specific project',
#  'wbs type project',
#  'component identification',
#  'gap assessment',
#  'alternative identification',
#  'system requirement development',
#  'alternative development',
#  'requirement determination',
#  'current system audit',
#  'component analysis',
#  'requirement change identification',
#  'alternative analysis',
#  'structure',
#  'various approach',
#  'popular method',
#  'top approach',
#  'organization',
#  'speci c guideline',
#  'wbs template',
#  'bottom approach',
#  'wbs structure',
#  'number form',
#  'product project deliverable insert third level',
#  'show figure',
#  'major deliverable second level decomposition',
#  'show figure',
#  'organization outside project team',
#  'contract work',
#  'seller',
#  'support contract wb part contract work',
#  'figure',
#  'wb',
#  'phase planning software product release',
#  'detail design',
#  'user documentation user documentation user',
#  'wbs',
#  'full project Scope specific project',
#  'wbs type project',
#  'system engineering management support pm activity aircraft system project management equipment training facility training service training train technical order engineering data management data datum air vehicle organizational level',
#  'se intermediate level se depot level se support equipment airframe engine communication system navigation system fire control system base building maintenance facility facility mock operational test developmental test test test evaluation wbs',
#  'full project Scope specific project',
#  'wbs type project',
#  'figure',
#  'sample wb major deliverable decomposition upper level wbs component',
#  'subdivide work',
#  'deliverable subcomponent fundamental component',
#  'wbs component',
#  'veri',
#  'able product',
#  'service',
#  'result',
#  'agile approach',
#  'use',
#  'user story',
#  'wbs',
#  'structure outline',
#  'organizational chart',
#  'identi',
#  'hierarchical breakdown',
#  'correctness decomposition',
#  'low level wbs component',
#  'necessary suf cient completion correspond high level deliverable',
#  'different deliverable',
#  'different level decomposition',
#  'work package',
#  'work deliverable need',
#  'additional level decomposition',
#  'work',
#  'great level detail',
#  'ability plan',
#  'control work',
#  'enhance',
#  'excessive decomposition',
#  'nonproductive management effort',
#  'inef cient',
#  'resource',
#  'decrease',
#  'ciency perform work',
#  'culty aggregate datum',
#  'different level wbs',
#  'decomposition',
#  'deliverable subcomponent',
#  'accomplish far future',
#  'project management team',
#  'detail wbs',
#  'technique',
#  'rolling wave planning',
#  'wbs',
#  'product project work',
#  'project management work',
#  'total work low level roll',
#  'high level',
#  'nothing',
#  'extra work',
#  'be sometimes call',
#  'percent rule',
#  'speci',
#  'c information regard wbs',
#  'practice standard work breakdown structure second edition',
#  'standard contain industry',
#  'speci',
#  'wbs template',
#  'tailor speci c project particular application area',
#  'Scope baseline',
#  'version Scope statement',
#  'wb dictionary',
#  'formal change control procedure',
#  'basis comparison',
#  'component project management plan',
#  'component Scope baseline',
#  'project Scope statement',
#  'project Scope statement',
#  'description project Scope',
#  'major deliverable',
#  'assumption',
#  'constraint',
#  'wbs',
#  'hierarchical decomposition',
#  'total Scope work',
#  'project team',
#  'accomplish project',
#  'objective create',
#  'descend level wbs',
#  'increasingly detailed de nition project work',
#  'work package',
#  'low level wbs',
#  'work package',
#  'unique identi',
#  'structure hierarchical summation cost',
#  'schedule',
#  'resource information form code account',
#  'work package',
#  'part control account',
#  'control account',
#  'management control point Scope',
#  'budget',
#  'schedule',
#  'compare earn value performance measurement',
#  'control account',
#  'two work package',
#  'work package',
#  'associate single control account',
#  'planning package',
#  'control account',
#  'one planning package',
#  'planning package',
#  'work breakdown structure component control account work package',
#  'work content',
#  'detailed schedule activity',
#  'document',
#  'detailed deliverable',
#  'activity',
#  'scheduling information component',
#  'document support wbs',
#  'information',
#  'create process',
#  'document',
#  'information',
#  'limit',
#  'u n code account identi er , u n description work',
#  'u',
#  'assumption constraint',
#  'u',
#  'responsible organization',
#  'u',
#  'schedule milestone',
#  'u n associate schedule activity',
#  'u n resource require',
#  'u n cost estimate',
#  'n quality requirement',
#  'u n acceptance criterion',
#  'u n technical reference',
#  'u n agreement information',
#  'project document',
#  'update result',
#  'carry process',
#  'u n assumption log',
#  'assumption log',
#  'additional assumption constraint',
#  'ed',
#  'wbs process',
#  'u n requirement documentation',
#  'requirement documentation',
#  'approve change result',
#  'wbs process',
#  'validate Scope',
#  'process',
#  'key benefit process',
#  'objectivity acceptance process',
#  'probability nal product',
#  'service',
#  'result',
#  'acceptance validate deliverable',
#  'process',
#  'project need',
#  'project document',
#  'input process',
#  'lesson',
#  'register',
#  'lesson',
#  'early project',
#  'later phase project',
#  'ciency effectiveness validate deliverable',
#  'quality report',
#  'information present quality report',
#  'quality assurance issue',
#  'escalate team',
#  'recommendation improvement',
#  'summary nding control quality process',
#  'information',
#  'prior product acceptance',
#  'requirement documentation',
#  'requirement',
#  'actual result',
#  'change',
#  'corrective action',
#  'preventive action',
#  'requirement traceability matrix',
#  'requirement traceability matrix',
#  'information requirement',
#  'veri',
#  'ed',
#  'complete check correctness control quality process',
#  'deliverable meet acceptance criterion',
#  'approve customer sponsor',
#  'formal documentation',
#  'customer sponsor',
#  'formal stakeholder acceptance project deliverable',
#  'forward close project phase process',
#  'work performance information',
#  'information project progress',
#  'accept reason',
#  'information',
#  'document',
#  'communicate stakeholder',
#  'complete deliverable',
#  'document',
#  'reason',
#  'deliverable',
#  'change request',
#  'repair',
#  'change request describe',
#  'process review disposition perform',
#  'change control process',
#  'project document',
#  'update result',
#  'carry process',
#  'lesson',
#  'lesson',
#  'update information challenge encounter',
#  'well approach work',
#  'requirement documentation',
#  'requirement documentation',
#  'actual result validation activity',
#  'particular interest',
#  'actual result',
#  'well requirement requirement',
#  'requirement traceability matrix',
#  'requirement traceability matrix',
#  'result validation',
#  'method use outcome',
#  'control Scope',
#  'process',
#  'status project product Scope',
#  'change Scope baseline',
#  'key benefit process',
#  'Scope baseline',
#  'project',
#  'process',
#  'project',
#  'project document',
#  'input process',
#  'lesson',
#  'lesson',
#  'early project',
#  'later phase project',
#  'Scope control',
#  'requirement documentation',
#  'requirement documentation',
#  'detect deviation',
#  'Scope project product',
#  'requirement traceability matrix',
#  'requirement traceability matrix help',
#  'impact change deviation Scope baseline project objective',
#  'status requirement',
#  'control',
#  'work performance datum',
#  'number change request',
#  'number request',
#  'number deliverable veri ed',
#  'organizational process asset influence control Scope process',
#  'formal informal Scope',
#  'related policy',
#  'procedure',
#  'guideline',
#  'monitoring report method template',
#  'use',
#  'datum analysis technique',
#  'control Scope process',
#  'variance analysis',
#  'variance analysis',
#  'baseline actual result determine variance',
#  'threshold amount',
#  'corrective preventive action',
#  'trend',
#  'analysis',
#  'trend analysis examine project performance time determine performance',
#  'important aspect project Scope control',
#  'determine cause degree variance relative Scope baseline',
#  'corrective preventive action',
#  'work performance information produce',
#  'contextualize information project product Scope',
#  'compare Scope baseline',
#  'category change',
#  'identi ed Scope variance cause',
#  'impact schedule cost',
#  'future Scope performance',
#  'change project management plan',
#  'organization change control process',
#  'change request',
#  'component',
#  'change request project management plan',
#  'scope management plan',
#  'Scope management plan',
#  'update ect change',
#  'Scope',
#  'scope baseline',
#  'Scope baseline',
#  'change Scope',
#  'scope variance',
#  'severe revise Scope baseline',
#  'realistic basis performance measurement',
#  'schedule baseline',
#  'change schedule baseline',
#  'change Scope',
#  'resource',
#  ...]

# %%
from collections import Counter
counter = Counter(noun_list_spacy)
sorted_counter = counter.most_common()
sorted_counter
# Out:
# [('project', 40),
#  ('lesson', 31),
#  ('process', 29),
#  ('figure', 23),
#  ('work', 23),
#  ('cost estimate', 22),
#  ('speci', 19),
#  ('use', 18),
#  ('resource', 18),
#  ('cost baseline', 17),
#  ('project document', 16),
#  ('activity', 16),
#  ('project schedule', 16),
#  ('contingency reserve', 16),
#  ('risk register', 15),
#  ('activity attribute', 15),
#  ('key benefit process', 14),
#  ('plan', 14),
#  ('assumption log', 14),
#  ('work package', 14),
#  ('schedule', 14),
#  ('requirement documentation', 13),
#  ('example', 13),
#  ('dependency', 13),
#  ('duration estimate', 13),
#  ('alternative analysis', 12),
#  ('requirement', 12),
#  ('input process', 12),
#  ('u', 12),
#  ('duration', 12),
#  ('management reserve', 12),
#  ('schedule model', 12),
#  ('service', 11),
#  ('requirement traceability matrix', 11),
#  ('budget', 11),
#  ('.m', 11),
#  ('information', 10),
#  ('activity list', 10),
#  ('project team', 9),
#  ('document', 9),
#  ('update result', 9),
#  ('carry process', 9),
#  ('schedule baseline', 9),
#  ('schedule management plan', 9),
#  ('ac', 9),
#  ('use process', 8),
#  ('project Scope statement', 8),
#  ('result', 8),
#  ('decision', 8),
#  ('constraint', 8),
#  ('wbs', 8),
#  ('procedure', 8),
#  ('analysis', 8),
#  ('realistic basis performance measurement', 8),
#  ('resource requirement', 8),
#  ('equation', 8),
#  ('project manager', 7),
#  ('later phase project', 7),
#  ('change request', 7),
#  ('guideline', 7),
#  ('logical relationship', 7),
#  ('milestone list', 7),
#  ('cost', 7),
#  ('critical path', 7),
#  ('historical information lesson', 6),
#  ('repository', 6),
#  ('component project management plan', 6),
#  ('technique', 6),
#  ('component', 6),
#  ('policy', 6),
#  ('ed', 6),
#  ('datum analysis technique', 6),
#  ('variance analysis', 6),
#  ('change Scope', 6),
#  ('predecessor activity', 6),
#  ('sequence', 6),
#  ('lead lag', 6),
#  ('project schedule network diagram', 6),
#  ('estimate', 6),
#  ('resource calendar', 6),
#  ('nish date', 6),
#  ('delay', 6),
#  ('point time', 6),
#  ('Scope management plan', 5),
#  ('Scope', 5),
#  ('data analysis technique', 5),
#  ('product', 5),
#  ('Scope baseline', 5),
#  ('stakeholder', 5),
#  ('example project document', 5),
#  ('interview', 5),
#  ('limit', 5),
#  ('risk', 5),
#  ('project management team', 5),
#  ('control account', 5),
#  ('change project management plan', 5),
#  ('organization change control process', 5),
#  ('change request project management plan', 5),
#  ('change cost baseline', 5),
#  ('basis estimate', 5),
#  ('schedule activity', 5),
#  ('milestone', 5),
#  ('sequence activity', 5),
#  ('individual project risk', 5),
#  ('mandatory dependency', 5),
#  ('discretionary dependency', 5),
#  ('project management information system', 5),
#  ('activity duration', 5),
#  ('resource leveling', 5),
#  ('cost management plan', 5),
#  ('measure', 5),
#  ('actual cost', 5),
#  ('cpi', 5),
#  ('eac', 5),
#  ('predefine point project', 4),
#  ('organizational process asset influence', 4),
#  ('high level', 4),
#  ('action', 4),
#  ('previous project', 4),
#  ('assumption', 4),
#  ('control', 4),
#  ('wbs process', 4),
#  ('show figure', 4),
#  ('early project', 4),
#  ('corrective preventive action', 4),
#  ('change schedule baseline', 4),
#  ('performance measurement baseline', 4),
#  ('update technique', 4),
#  ('date', 4),
#  ('assumption constraint record assumption log', 4),
#  ('schedule date', 4),
#  ('logical relationship successor activity', 4),
#  ('project management information system pmis describe', 4),
#  ('project calendar', 4),
#  ('documentation', 4),
#  ('complete activity', 4),
#  ('hrs tom', 4),
#  ('scenario analysis', 4),
#  ('component work package', 4),
#  ('.t', 4),
#  ('.d', 4),
#  ('.b', 4),
#  ('earn value analysis', 4),
#  ('forecast', 4),
#  ('usually datum date', 4),
#  ('project Scope', 3),
#  ('organization culture', 3),
#  ('infrastructure', 3),
#  ('personnel administration', 3),
#  ('marketplace condition', 3),
#  ('project sponsor', 3),
#  ('select project team member', 3),
#  ('select stakeholder', 3),
#  ('analyze', 3),
#  ('organization', 3),
#  ('track', 3),
#  ('report', 3),
#  ('change', 3),
#  ('industry', 3),
#  ('enterprise environmental factor influence', 3),
#  ('technique use', 3),
#  ('questionnaire survey', 3),
#  ('method', 3),
#  ('context diagram', 3),
#  ('simulation', 3),
#  ('performance', 3),
#  ('baseline', 3),
#  ('request', 3),
#  ('follow', 3),
#  ('structure', 3),
#  ('full project Scope specific project', 3),
#  ('wbs type project', 3),
#  ('wb', 3),
#  ('agile approach', 3),
#  ('formal change control procedure', 3),
#  ('planning package', 3),
#  ('trend', 3),
#  ('cost variance', 3),
#  ('severe revise cost baseline', 3),
#  ('change performance measurement baseline', 3),
#  ('response approve change Scope', 3),
#  ('schedule performance', 3),
#  ('performance variance', 3),
#  ('severe change request', 3),
#  ('revise performance measurement baseline', 3),
#  ('release planning', 3),
#  ('meeting', 3),
#  ('project activity', 3),
#  ('predecessor successor relationship', 3),
#  ('lead lag logical relationship activity', 3),
#  ('scheduling methodology', 3),
#  ('fs', 3),
#  ('review', 3),
#  ('lead', 3),
#  ('I', 3),
#  ('project team assignment', 3),
#  ('detail', 3),
#  ('team', 3),
#  ('schedule reserve', 3),
#  ('quantitative assessment', 3),
#  ('support documentation', 3),
#  ('schedule process', 3),
#  ('schedule network analysis', 3),
#  ('critical path method', 3),
#  ('resource smoothing', 3),
#  ('hrs sue', 3),
#  ('fast tracking', 3),
#  ('chart', 3),
#  ('diagram', 3),
#  ('ect change', 3),
#  ('estimate cost', 3),
#  ('resource order', 3),
#  ('budget process', 3),
#  ('model', 3),
#  ('evm', 3),
#  ('earn value', 3),
#  ('cv', 3),
#  ('spi', 3),
#  ('value', 3),
#  ('eac forecast etc work', 3),
#  ('eac ac', 3),
#  ('project charter', 2),
#  ('historical information', 2),
#  ('policy procedure', 2),
#  ('validate Scope', 2),
#  ('control Scope', 2),
#  ('attendee', 2),
#  ('detailed project Scope statement', 2),
#  ('practice guide', 2),
#  ('impact', 2),
#  ('product requirement', 2),
#  ('determine', 2),
#  ('register', 2),
#  ('information requirement', 2),
#  ('requirement process', 2),
#  ('focus group', 2),
#  ('good practice', 2),
#  ('vote', 2),
#  ('multiple alternative', 2),
#  ('outcome', 2),
#  ('future action', 2),
#  ('mind mapping', 2),
#  ('equipment', 2),
#  ('mock', 2),
#  ('prototype', 2),
#  ('individual requirement meet business need project', 2),
#  ('solution requirement', 2),
#  ('functional requirement', 2),
#  ('test', 2),
#  ('project life cycle', 2),
#  ('opportunity', 2),
#  ('project objective', 2),
#  ('complexity', 2),
#  ('acceptance criterion', 2),
#  ('system engineering', 2),
#  ('description project Scope', 2),
#  ('major deliverable', 2),
#  ('stakeholder expectation', 2),
#  ('exclude', 2),
#  ('phase', 2),
#  ('deliverable', 2),
#  ('table', 2),
#  ('additional assumption constraint', 2),
#  ('additional changed requirement', 2),
#  ('ect update requirement documentation', 2),
#  ('additional information', 2),
#  ('hierarchical decomposition', 2),
#  ('total Scope work', 2),
#  ('accomplish project', 2),
#  ('objective create', 2),
#  ('low level wbs component', 2),
#  ('decomposition', 2),
#  ('wbs template', 2),
#  ('wbs component', 2),
#  ('veri', 2),
#  ('rolling wave planning', 2),
#  ('assumption constraint', 2),
#  ('schedule milestone', 2),
#  ('project need', 2),
#  ('actual result', 2),
#  ('corrective action', 2),
#  ('preventive action', 2),
#  ('change control process', 2),
#  ('trend analysis examine project performance time determine performance', 2),
#  ('schedule variance', 2),
#  ('organizational culture structure', 2),
#  ('scheduling software', 2),
#  ('planning meeting', 2),
#  ('iteration', 2),
#  ('level accuracy', 2),
#  ('amount contingency', 2),
#  ('unit measure', 2),
#  ('organizational procedure link', 2),
#  ('work breakdown structure', 2),
#  ('control thresholds', 2),
#  ('amount variation', 2),
#  ('threshold', 2),
#  ('rule performance measurement', 2),
#  ('report format', 2),
#  ('template', 2),
#  ('formal informal activity plan', 2),
#  ('term', 2),
#  ('time', 2),
#  ('successor activity', 2),
#  ('contract', 2),
#  ('project management software', 2),
#  ('necessary sequence event', 2),
#  ('government industry standard', 2),
#  ('relationship', 2),
#  ('illustrate figure', 2),
#  ('nishe', 2),
#  ('sf', 2),
#  ('construction project', 2),
#  ('order', 2),
#  ('external dependency', 2),
#  ('internal dependency', 2),
#  ('new ce building', 2),
#  ('landscaping', 2),
#  ('technical writing team', 2),
#  ('lag', 2),
#  ('path convergence', 2),
#  ('multiple activity', 2),
#  ('impact change relationship', 2),
#  ('project activity sequencing activity', 2),
#  ('speci c milestone', 2),
#  ('resource breakdown structure', 2),
#  ('activity resource requirement', 2),
#  ('assign activity', 2),
#  ('risk response', 2),
#  ('commercial information', 2),
#  ('analogous estimating', 2),
#  ('total project segment project', 2),
#  ('conjunction estimating method', 2),
#  ('parametric estimating', 2),
#  ('meter', 2),
#  ('hour', 2),
#  ('triangular distribution', 2),
#  ('reserve analysis', 2),
#  ('account unknown amount rework', 2),
#  ('precise information project', 2),
#  ('contingency', 2),
#  ('management control purpose', 2),
#  ('reserve unforeseen work', 2),
#  ('Scope project', 2),
#  ('address unknown unknown affect project', 2),
#  ('concern', 2),
#  ('day', 2),
#  ('week', 2),
#  ('amount type additional detail support duration estimate vary application area',
#   2),
#  ('clear complete understanding duration estimate', 2),
#  ('documentation basis estimate', 2),
#  ('documentation assumption', 2),
#  ('indication range possible estimate', 2),
#  ('con dence level nal estimate', 2),
#  ('iterative process', 2),
#  ('project schedule model', 2),
#  ('practice standard scheduling', 2),
#  ('calculate schedule', 2),
#  ('early project regard', 2),
#  ('type quantity resource', 2),
#  ('assess', 2),
#  ('long path', 2),
#  ('negative total oat', 2),
#  ('negative oat analysis', 2),
#  ('schedule constraint', 2),
#  ('be use', 2),
#  ('hrs activity b sue', 2),
#  ('hrs activity', 2),
#  ('c tom', 2),
#  ('effect', 2),
#  ('scenario', 2),
#  ('schedule compression technique', 2),
#  ('agile release planning', 2),
#  ('basis comparison actual result', 2),
#  ('bar chart', 2),
#  ('new product z period calendar unit calendar unit calendar unit', 2),
#  ('complete component complete component', 2),
#  ('new product z activity description project schedule time frame period period period period activity',
#   2),
#  ('complete integration component', 2),
#  ('new product z period work package', 2),
#  ('component activity description', 2),
#  ('milestone schedule datum date datum date detailed schedule', 2),
#  ('.g', 2),
#  ('.t datum date ss fs', 2),
#  ('component design component', 2),
#  ('schedule datum', 2),
#  ('one project calendar', 2),
#  ('way schedule', 2),
#  ('resource leveling analysis', 2),
#  ('control schedule', 2),
#  ('actual change', 2),
#  ('monitoring report method', 2),
#  ('actual start nish date', 2),
#  ('graphical analysis technique', 2),
#  ('valuable understand', 2),
#  ('cause degree variance relative schedule baseline', 2),
#  ('project future', 2),
#  ('market condition', 2),
#  ('available commercial database track skill human resource cost', 2),
#  ('standard cost material equipment', 2),
#  ('seller price list', 2),
#  ('another source information', 2),
#  ('control cost', 2),
#  ('additional detail', 2),
#  ('complete project work', 2),
#  ('cost nancing', 2),
#  ('interest charge', 2),
#  ('enterprise environmental factor influence estimate cost process', 2),
#  ('large scale project', 2),
#  ('multiple year multiple currency', 2),
#  ('estimate cost process', 2),
#  ('exchange rate', 2),
#  ('indirect cost', 2),
#  ('support detail cost estimate', 2),
#  ('work package cost estimate', 2),
#  ('accomplish expenditure', 2),
#  ('cost control', 2),
#  ('budget assign schedule work', 2),
#  ('cost incur work', 2),
#  ('amount project', 2),
#  ('plan delivery date', 2),
#  ('equal earn value', 2),
#  ('eva schedule variance', 2),
#  ('express difference earn value actual cost', 2),
#  ('equal ratio', 2),
#  ('cpi value', 2),
#  ('obvious bac', 2),
#  ('forecasted eac', 2),
#  ('eac ac bottom', 2),
#  ('etc work', 2),
#  ('fund', 2),
#  ('complete performance index tcpi', 2),
#  ('measure cost performance', 2),
#  ('speci ed management goal', 2),
#  ('tcpi', 2),
#  ('equation tcpi', 2),
#  ('level performance', 2),
#  ('complete point time', 2),
#  ('percentage', 2),
#  ('much cost', 2),
#  ('calculate use', 2),
#  ('efficiency', 2),
#  ('neutral plan', 2),
#  ('plan Scope management', 1),
#  ('Scope management plan document project product Scope', 1),
#  ('guidance direction Scope', 1),
#  ('component project program management plan', 1),
#  ('development Scope management plan', 1),
#  ('analysis information', 1),
#  ('late approve subsidiary plan project management plan', 1),
#  ('organizational process', 1),
#  ('relevant enterprise environmental factor', 1),
#  ('enterprise environmental factor influence plan Scope management process',
#   1),
#  ('organizational process asset influence plan Scope management process', 1),
#  ('elaborate project product Scope', 1),
#  ('project meeting', 1),
#  ('anyone responsibility Scope management process', 1),
#  ('component Scope management plan', 1),
#  ('creation', 1),
#  ('formal acceptance complete project deliverable', 1),
#  ('highly detail', 1),
#  ('base', 1),
#  ('requirement management plan', 1),
#  ('accord business analysis practitioner', 1),
#  ('business analysis plan', 1),
#  ('component requirement management plan', 1),
#  ('requirement activity', 1),
#  ('trace', 1),
#  ('authorization level', 1),
#  ('approve change', 1),
#  ('rationale use', 1),
#  ('traceability structure ect requirement attribute', 1),
#  ('traceability matrix', 1),
#  ('requirement meet objective', 1),
#  ('basis de ne product Scope project Scope', 1),
#  ('pmbok guide', 1),
#  ('business analysis practitioner', 1),
#  ('depth information product requirement', 1),
#  ('project success', 1),
#  ('directly uence active stakeholder involvement discovery decomposition', 1),
#  ('project product requirement care', 1),
#  ('requirement product', 1),
#  ('result project', 1),
#  ('condition capability', 1),
#  ('present product', 1),
#  ('result satisfy agreement', 1),
#  ('speci cation', 1),
#  ('quanti ed document', 1),
#  ('expectation sponsor', 1),
#  ('customer', 1),
#  ('record enough detail', 1),
#  ('project execution', 1),
#  ('foundation wbs', 1),
#  ('procurement', 1),
#  ('base requirement', 1),
#  ('assumption log identi ed assumption product', 1),
#  ('project , environment , stakeholder , factor influence requirement', 1),
#  ('information effective requirement collection technique', 1),
#  ('especially project', 1),
#  ('iterative adaptive product development methodology', 1),
#  ('stakeholder register', 1),
#  ('requirement expectation stakeholder', 1),
#  ('repository information previous project', 1),
#  ('datum gathering technique', 1),
#  ('brainstorming', 1),
#  ('project product requirement', 1),
#  ('prepared spontaneous question record response', 1),
#  ('individual basis interviewer interviewee', 1),
#  ('multiple interviewer multiple interviewee', 1),
#  ('experienced project participant', 1),
#  ('sponsor', 1),
#  ('executive', 1),
#  ('subject matter', 1),
#  ('expert aid', 1),
#  ('de ne feature function desire product deliverable', 1),
#  ('con dential information', 1),
#  ('prequali ed stakeholder subject matter expert', 1),
#  ('expectation attitude', 1),
#  ('train moderator guide group interactive discussion design', 1),
#  ('conversational one one interview', 1),
#  ('set question design', 1),
#  ('large number respondent', 1),
#  ('appropriate varied audience', 1),
#  ('quick turnaround', 1),
#  ('respondent', 1),
#  ('statistical analysis', 1),
#  ('benchmarking involve', 1),
#  ('actual plan product , process , practice comparable organization', 1),
#  ('idea improvement', 1),
#  ('basis measure performance', 1),
#  ('benchmarking', 1),
#  ('collect requirement process', 1),
#  ('voting', 1),
#  ('collective decision making technique assessment process', 1),
#  ('generate', 1),
#  ('example vote technique', 1),
#  ('unanimity', 1),
#  ('everyone', 1),
#  ('single course action', 1),
#  ('majority', 1),
#  ('support', 1),
#  ('member group', 1),
#  ('group size', 1),
#  ('tie', 1),
#  ('plurality', 1),
#  ('large block group', 1),
#  ('even majority', 1),
#  ('number option nominate', 1),
#  ('autocratic decision making', 1),
#  ('one individual', 1),
#  ('responsibility', 1),
#  ('decision group', 1),
#  ('multicriteria decision analysis', 1),
#  ('technique use decision matrix', 1),
#  ('systematic analytical approach', 1),
#  ('criterion', 1),
#  ('risk level', 1),
#  ('uncertainty', 1),
#  ('valuation', 1),
#  ('rank', 1),
#  ('many idea', 1),
#  ('datum representation technique', 1),
#  ('affinity diagram', 1),
#  ('nity diagram', 1),
#  ('large number idea', 1),
#  ('classi ed group review analysis', 1),
#  ('idea', 1),
#  ('individual brainstorming session single map ect commonality difference understanding',
#   1),
#  ('new idea', 1),
#  ('example Scope model', 1),
#  ('context diagrams', 1),
#  ('product Scope', 1),
#  ('business system process', 1),
#  ('computer system', 1),
#  ('people system actor interact', 1),
#  ('input business system', 1),
#  ('actor', 1),
#  ('input', 1),
#  ('output business system', 1),
#  ('output', 1),
#  ('abc company external job website', 1),
#  ('external user internal user external user internal user', 1),
#  ('internal user', 1),
#  ('internal datum', 1),
#  ('external user', 1),
#  ('external datum', 1),
#  ('external job', 1),
#  ('external user profile internal job', 1),
#  ('internal user profile', 1),
#  ('prototyping be method', 1),
#  ('early feedback requirement provide model', 1),
#  ('example prototype', 1),
#  ('small scale product', 1),
#  ('computer', 1),
#  ('stakeholder experiment model nal product', 1),
#  ('abstract representation requirement', 1),
#  ('prototype support concept progressive elaboration iterative cycle mock creation',
#   1),
#  ('user experimentation', 1),
#  ('feedback generation', 1),
#  ('prototype revision', 1),
#  ('enough feedback cycle', 1),
#  ('requirement obtain prototype', 1),
#  ('suf ciently complete move design build phase', 1),
#  ('prototyping technique show sequence navigation series image illustration',
#   1),
#  ('variety project variety industry', 1),
#  ('advertising', 1),
#  ('instructional design', 1),
#  ('agile software development project', 1),
#  ('software development', 1),
#  (', storyboard use', 1),
#  ('navigation path web page', 1),
#  ('screen', 1),
#  ('user interface', 1),
#  ('progressively detailed information requirement', 1),
#  ('unambiguous measurable testable , traceable , complete , consistent , acceptable key stakeholder',
#   1),
#  ('format requirement document', 1),
#  ('simple document list requirement categorize stakeholder priority', 1),
#  ('elaborate form', 1),
#  ('executive summary', 1),
#  ('detailed description', 1),
#  ('attachment', 1),
#  ('many organization', 1),
#  ('requirement different type', 1),
#  ('business technical solution', 1),
#  ('former refer stakeholder', 1),
#  ('latter need', 1),
#  ('requirement be group classi cation', 1),
#  ('nement detail requirement', 1),
#  ('classi cation', 1),
#  ('business requirement', 1),
#  ('need organization whole', 1),
#  ('business issue opportunity', 1),
#  ('reason project', 1),
#  ('stakeholder requirement', 1),
#  ('stakeholder stakeholder group', 1),
#  ('feature', 1),
#  ('function', 1),
#  ('characteristic product', 1),
#  ('business stakeholder requirement', 1),
#  ('far group functional nonfunctional requirement', 1),
#  ('behavior product', 1),
#  ('action , process , datum , interaction product execute', 1),
#  ('u n nonfunctional requirement', 1),
#  ('nonfunctional requirement supplement functional requirement', 1),
#  ('environmental condition quality', 1),
#  ('reliability', 1),
#  ('security', 1),
#  ('safety', 1),
#  ('level service', 1),
#  ('supportability', 1),
#  ('retention purge', 1),
#  ('transition readiness requirement', 1),
#  ('temporary capability', 1),
#  ('data conversion training requirement', 1),
#  ('transition current', 1),
#  ('state desire', 1),
#  ('future state', 1),
#  ('project requirement', 1),
#  ('condition project', 1),
#  ('milestone date', 1),
#  ('contractual obligation', 1),
#  ('quality requirement', 1),
#  ('condition criterion', 1),
#  ('validate successful completion project deliverable ful llment project requirement',
#   1),
#  ('certi cation', 1),
#  ('validation', 1),
#  ('grid link product requirement origin deliverable satisfy', 1),
#  ('implementation requirement traceability matrix help', 1),
#  ('business value link business project objective', 1),
#  ('track requirement', 1),
#  ('requirement approve requirement documentation', 1),
#  ('end project', 1),
#  ('structure manage change product Scope', 1),
#  ('trace requirement', 1),
#  ('business need', 1),
#  ('goal', 1),
#  ('product design', 1),
#  ('product development', 1),
#  ('test strategy test scenario', 1),
#  ('high level requirement detailed requirement', 1),
#  ('associate requirement', 1),
#  ('record requirement traceability matrix', 1),
#  ('help de ne key information requirement', 1),
#  ('typical attribute', 1),
#  ('unique identi er , textual description requirement', 1),
#  ('rationale inclusion', 1),
#  ('owner , source , priority , version , current status', 1),
#  ('defer', 1),
#  ('status date', 1),
#  ('additional attribute', 1),
#  ('stakeholder satisfaction', 1),
#  ('stability', 1),
#  ('example requirement traceability matrix associate attribute', 1),
#  ('requirement traceability matrix requirement traceability matrix requirement description',
#   1),
#  ('business need , opportunity , goal , objective project objective associate',
#   1),
#  ('wb deliverable product design product development test case program portfolio project name',
#   1),
#  ('cost center', 1),
#  ('project description', 1),
#  ('be process', 1),
#  ('detailed description project product', 1),
#  ('boundary acceptance criterion', 1),
#  ('assumption log identi es assumption constraint product', 1),
#  ('environment', 1),
#  ('factor influence project product Scope', 1),
#  ('requirement documentation identi es requirement', 1),
#  ('risk register contain response strategy', 1),
#  ('change project product Scope', 1),
#  ('enterprise environmental factor influence de ne Scope process', 1),
#  ('organizational process asset influence de ne Scope process', 1),
#  ('policy , procedure , template project Scope statement', 1),
#  ('previous phase project', 1),
#  ('requirement objective identi ed charter', 1),
#  ('product analysis', 1),
#  ('de ne product service', 1),
#  ('question product service form answer describe use', 1),
#  ('characteristic , relevant aspect', 1),
#  ('application area', 1),
#  ('method translate high level product service description meaningful deliverable',
#   1),
#  ('high level decompose level detail', 1),
#  ('design nal product', 1),
#  ('example product analysis technique', 1),
#  ('product breakdown', 1),
#  ('requirement analysis', 1),
#  ('system analysis', 1),
#  ('value analysis', 1),
#  ('value engineering', 1),
#  ('project Scope statement document entire Scope', 1),
#  ('project product Scope', 1),
#  ('project deliverable detail', 1),
#  ('common understanding project Scope', 1),
#  ('project stakeholder', 1),
#  ('explicit scope exclusion assist', 1),
#  ('enable project team', 1),
#  ('detailed planning', 1),
#  ('guide', 1),
#  ('project team work execution', 1),
#  ('additional work', 1),
#  ('outside project boundary', 1),
#  ('degree level detail project Scope statement de ne work', 1),
#  ('help', 1),
#  ('overall project Scope', 1),
#  ('either directly reference document', 1),
#  ('product Scope description', 1),
#  ('progressively elaborate characteristic product', 1),
#  ('project charter requirement documentation', 1),
#  ('unique verifiable product', 1),
#  ('capability perform service', 1),
#  ('complete process', 1),
#  ('ancillary result', 1),
#  ('project management report documentation', 1),
#  ('summary level', 1),
#  ('great detail', 1),
#  ('set condition', 1),
#  ('project exclusion', 1),
#  ('exclude project', 1),
#  ('state', 1),
#  ('project charter project Scope statement', 1),
#  ('certain degree redundancy', 1),
#  ('high level information', 1),
#  ('detailed description Scope component', 1),
#  ('key element document', 1),
#  ('project charter project purpose measurable project objective related success criterion high level requirement high level project description',
#   1),
#  ('boundary , key deliverable overall project risk summary milestone schedule preapprove financial resource key stakeholder list project approval requirement',
#   1),
#  ('success', 1),
#  ('sign project project exit criterion', 1),
#  ('condition', 1),
#  ('order close cancel project phase assign project manager', 1),
#  ('responsibility , authority level name authority sponsor person', 1),
#  ('project charter project Scope statement project Scope description', 1),
#  ('project deliverable acceptance criterion project exclusion table', 1),
#  ('element project charter project Scope statement', 1),
#  ('identi ed process', 1),
#  ('new stakeholder', 1),
#  ('result process', 1),
#  ('subdividing project deliverable project', 1),
#  ('framework', 1),
#  ('de ne total Scope project', 1),
#  ('speci ed current approve project Scope statement', 1),
#  ('plan work', 1),
#  ('call work package', 1),
#  ('group activity work', 1),
#  ('schedule estimate', 1),
#  ('context', 1),
#  ('work product deliverable', 1),
#  ('result activity activity', 1),
#  ('project management plan component', 1),
#  ('limit Scope management plan', 1),
#  ('Scope management plan document wbs', 1),
#  ('detailed requirement', 1),
#  ('relevant nature project', 1),
#  ('speci c standard', 1),
#  ('external reference source', 1),
#  ('template wbs', 1),
#  ('subdivide project Scope project', 1),
#  ('deliverable small , manageable part', 1),
#  ('low level wbs cost duration be estimate manage', 1),
#  ('level decomposition', 1),
#  ('degree control', 1),
#  ('level detail work package', 1),
#  ('size complexity project', 1),
#  ('decomposition total project work work package', 1),
#  ('follow activity', 1),
#  ('deliverable related work', 1),
#  ('upper wbs level low level detailed component', 1),
#  ('assign identi cation code wbs component', 1),
#  ('degree decomposition deliverable', 1),
#  ('portion', 1),
#  ('branch', 1),
#  ('work package level', 1),
#  ('value management system project', 1),
#  ('assessment', 1),
#  ('standard development', 1),
#  ('project management wbs', 1),
#  ('component identification', 1),
#  ('gap assessment', 1),
#  ('alternative identification', 1),
#  ('system requirement development', 1),
#  ('alternative development', 1),
#  ('requirement determination', 1),
#  ('current system audit', 1),
#  ('component analysis', 1),
#  ('requirement change identification', 1),
#  ('various approach', 1),
#  ('popular method', 1),
#  ('top approach', 1),
#  ('speci c guideline', 1),
#  ('bottom approach', 1),
#  ('wbs structure', 1),
#  ('number form', 1),
#  ('product project deliverable insert third level', 1),
#  ('major deliverable second level decomposition', 1),
#  ('organization outside project team', 1),
#  ('contract work', 1),
#  ('seller', 1),
#  ('support contract wb part contract work', 1),
#  ('phase planning software product release', 1),
#  ('detail design', 1),
#  ('user documentation user documentation user', 1),
#  ('system engineering management support pm activity aircraft system project management equipment training facility training service training train technical order engineering data management data datum air vehicle organizational level',
#   1),
#  ('se intermediate level se depot level se support equipment airframe engine communication system navigation system fire control system base building maintenance facility facility mock operational test developmental test test test evaluation wbs',
#   1),
#  ('sample wb major deliverable decomposition upper level wbs component', 1),
#  ('subdivide work', 1),
#  ('deliverable subcomponent fundamental component', 1),
#  ('able product', 1),
#  ('user story', 1),
#  ('structure outline', 1),
#  ('organizational chart', 1),
#  ('identi', 1),
#  ('hierarchical breakdown', 1),
#  ('correctness decomposition', 1),
#  ('necessary suf cient completion correspond high level deliverable', 1),
#  ('different deliverable', 1),
#  ('different level decomposition', 1),
#  ('work deliverable need', 1),
#  ('additional level decomposition', 1),
#  ('great level detail', 1),
#  ('ability plan', 1),
#  ('control work', 1),
#  ('enhance', 1),
#  ('excessive decomposition', 1),
#  ('nonproductive management effort', 1),
#  ('inef cient', 1),
#  ('decrease', 1),
#  ('ciency perform work', 1),
#  ('culty aggregate datum', 1),
#  ('different level wbs', 1),
#  ('deliverable subcomponent', 1),
#  ('accomplish far future', 1),
#  ('detail wbs', 1),
#  ('product project work', 1),
#  ('project management work', 1),
#  ('total work low level roll', 1),
#  ('nothing', 1),
#  ('extra work', 1),
#  ('be sometimes call', 1),
#  ('percent rule', 1),
#  ('c information regard wbs', 1),
#  ('practice standard work breakdown structure second edition', 1),
#  ('standard contain industry', 1),
#  ('tailor speci c project particular application area', 1),
#  ('version Scope statement', 1),
#  ('wb dictionary', 1),
#  ('basis comparison', 1),
#  ('component Scope baseline', 1),
#  ('descend level wbs', 1),
#  ('increasingly detailed de nition project work', 1),
#  ('low level wbs', 1),
#  ('unique identi', 1),
#  ('structure hierarchical summation cost', 1),
#  ('resource information form code account', 1),
#  ('part control account', 1),
#  ('management control point Scope', 1),
#  ('compare earn value performance measurement', 1),
#  ('two work package', 1),
#  ('associate single control account', 1),
#  ('one planning package', 1),
#  ('work breakdown structure component control account work package', 1),
#  ('work content', 1),
#  ('detailed schedule activity', 1),
#  ('detailed deliverable', 1),
#  ('scheduling information component', 1),
#  ('document support wbs', 1),
#  ('create process', 1),
#  ('u n code account identi er , u n description work', 1),
#  ('responsible organization', 1),
#  ('u n associate schedule activity', 1),
#  ('u n resource require', 1),
#  ('u n cost estimate', 1),
#  ('n quality requirement', 1),
#  ('u n acceptance criterion', 1),
#  ('u n technical reference', 1),
#  ('u n agreement information', 1),
#  ('u n assumption log', 1),
#  ('u n requirement documentation', 1),
#  ('approve change result', 1),
#  ('objectivity acceptance process', 1),
#  ('probability nal product', 1),
#  ('acceptance validate deliverable', 1),
#  ('ciency effectiveness validate deliverable', 1),
#  ('quality report', 1),
#  ('information present quality report', 1),
#  ('quality assurance issue', 1),
#  ('escalate team', 1),
#  ('recommendation improvement', 1),
#  ('summary nding control quality process', 1),
#  ('prior product acceptance', 1),
#  ('complete check correctness control quality process', 1),
#  ('deliverable meet acceptance criterion', 1),
#  ('approve customer sponsor', 1),
#  ('formal documentation', 1),
#  ('customer sponsor', 1),
#  ('formal stakeholder acceptance project deliverable', 1),
#  ('forward close project phase process', 1),
#  ('work performance information', 1),
#  ('information project progress', 1),
#  ('accept reason', 1),
#  ('communicate stakeholder', 1),
#  ('complete deliverable', 1),
#  ('reason', 1),
#  ('repair', 1),
#  ('change request describe', 1),
#  ('process review disposition perform', 1),
#  ('update information challenge encounter', 1),
#  ('well approach work', 1),
#  ('actual result validation activity', 1),
#  ('particular interest', 1),
#  ('well requirement requirement', 1),
#  ('result validation', 1),
#  ('method use outcome', 1),
#  ('status project product Scope', 1),
#  ('change Scope baseline', 1),
#  ('Scope control', 1),
#  ('detect deviation', 1),
#  ('Scope project product', 1),
#  ('requirement traceability matrix help', 1),
#  ('impact change deviation Scope baseline project objective', 1),
#  ('status requirement', 1),
#  ('work performance datum', 1),
#  ('number change request', 1),
#  ('number request', 1),
#  ('number deliverable veri ed', 1),
#  ('organizational process asset influence control Scope process', 1),
#  ('formal informal Scope', 1),
#  ('related policy', 1),
#  ('monitoring report method template', 1),
#  ('control Scope process', 1),
#  ('baseline actual result determine variance', 1),
#  ('threshold amount', 1),
#  ('important aspect project Scope control', 1),
#  ('determine cause degree variance relative Scope baseline', 1),
#  ('work performance information produce', 1),
#  ('contextualize information project product Scope', 1),
#  ('compare Scope baseline', 1),
#  ('category change', 1),
#  ('identi ed Scope variance cause', 1),
#  ('impact schedule cost', 1),
#  ('future Scope performance', 1),
#  ('scope management plan', 1),
#  ('update ect change', 1),
#  ('scope baseline', 1),
#  ('scope variance', 1),
#  ('severe revise Scope baseline', 1),
#  ('severe revise schedule baseline', 1),
#  ('effective control Scope', 1),
#  ('variance corrective action', 1),
#  ('enterprise environmental factor influence plan schedule management process',
#   1),
#  ('team resource availability skill physical resource availability', 1),
#  ('guideline criterion tailor organization', 1),
#  ('standard process procedure satisfy', 1),
#  ('speci c need project', 1),
#  ('commercial database', 1),
#  ('standardized estimate datum', 1),
#  ('organizational process asset influence plan schedule management process',
#   1),
#  ('formal informal schedule development', 1),
#  ('management control', 1),
#  ('template form', 1),
#  ('report tool', 1),
#  ('schedule methodology use', 1),
#  ('various method project', 1),
#  ('detailed schedule', 1),
#  ...]

# %%
len(verbs), len(verb_list_spacy)
# Out:
# (3560, 1912)

# %%
len(noun_list), len(noun_list_spacy)
# Out:
# (6560, 3738)

# %% [markdown]
# # Final DataFrame

# %% [markdown]
# # OWL File Creation

# %% [markdown]
# # Model Creation
